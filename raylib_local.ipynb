# %% [markdown]
# # Preliminaries and checkers

# %%
# !pip install gymnasium
# !pip install torch
# !pip install "ray[rllib]==2.38.0"
# !pip install "ray[rllib,torch]==2.38.0"
# !pip install "ray[all]==2.38.0"
# !pip install pygame
# !pip install matplotlib
# !pip install networkx
# Out:
# Requirement already satisfied: gymnasium in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: setuptools in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: ray==2.38.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (2.38.0)
# Requirement already satisfied: click>=7.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (8.1.7)
# Requirement already satisfied: filelock in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (3.13.1)
# Requirement already satisfied: jsonschema in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (1.0.3)
# Requirement already satisfied: packaging in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (24.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (5.28.3)
# Requirement already satisfied: pyyaml in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (6.0.1)
# Requirement already satisfied: aiosignal in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (1.4.0)
# Requirement already satisfied: requests in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib]==2.38.0) (2.32.3)
# Requirement already satisfied: pandas in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (2.2.2)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (16.1.0)
# Requirement already satisfied: fsspec in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (2024.6.1)
# Requirement already satisfied: dm-tree in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (0.1.8)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (0.28.1)
# Requirement already satisfied: lz4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (4.3.2)
# Requirement already satisfied: scikit-image in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (0.24.0)
# Requirement already satisfied: scipy in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (1.13.1)
# Requirement already satisfied: typer in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (0.13.1)
# Requirement already satisfied: rich in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib]==2.38.0) (13.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib]==2.38.0) (1.26.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib]==2.38.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib]==2.38.0) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib]==2.38.0) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib]==2.38.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from click>=7.0->ray==2.38.0->ray[rllib]==2.38.0) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib]==2.38.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib]==2.38.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib]==2.38.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib]==2.38.0) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas->ray[rllib]==2.38.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas->ray[rllib]==2.38.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas->ray[rllib]==2.38.0) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib]==2.38.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib]==2.38.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib]==2.38.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib]==2.38.0) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from rich->ray[rllib]==2.38.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from rich->ray[rllib]==2.38.0) (2.15.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib]==2.38.0) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib]==2.38.0) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib]==2.38.0) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib]==2.38.0) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib]==2.38.0) (0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from typer->ray[rllib]==2.38.0) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from markdown-it-py>=2.2.0->rich->ray[rllib]==2.38.0) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from python-dateutil>=2.8.2->pandas->ray[rllib]==2.38.0) (1.16.0)
# Requirement already satisfied: ray==2.38.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (2.38.0)
# Requirement already satisfied: click>=7.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (8.1.7)
# Requirement already satisfied: filelock in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (3.13.1)
# Requirement already satisfied: jsonschema in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (1.0.3)
# Requirement already satisfied: packaging in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (24.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (5.28.3)
# Requirement already satisfied: pyyaml in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (6.0.1)
# Requirement already satisfied: aiosignal in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (1.4.0)
# Requirement already satisfied: requests in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[rllib,torch]==2.38.0) (2.32.3)
# Requirement already satisfied: pandas in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (2.2.2)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (16.1.0)
# Requirement already satisfied: fsspec in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (2024.6.1)
# Requirement already satisfied: dm-tree in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (0.1.8)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (0.28.1)
# Requirement already satisfied: lz4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (4.3.2)
# Requirement already satisfied: scikit-image in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (0.24.0)
# Requirement already satisfied: scipy in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (1.13.1)
# Requirement already satisfied: typer in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (0.13.1)
# Requirement already satisfied: rich in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[rllib,torch]==2.38.0) (13.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib,torch]==2.38.0) (1.26.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib,torch]==2.38.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib,torch]==2.38.0) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib,torch]==2.38.0) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[rllib,torch]==2.38.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from click>=7.0->ray==2.38.0->ray[rllib,torch]==2.38.0) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib,torch]==2.38.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib,torch]==2.38.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib,torch]==2.38.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[rllib,torch]==2.38.0) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas->ray[rllib,torch]==2.38.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas->ray[rllib,torch]==2.38.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas->ray[rllib,torch]==2.38.0) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib,torch]==2.38.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib,torch]==2.38.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib,torch]==2.38.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[rllib,torch]==2.38.0) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from rich->ray[rllib,torch]==2.38.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from rich->ray[rllib,torch]==2.38.0) (2.15.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib,torch]==2.38.0) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib,torch]==2.38.0) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib,torch]==2.38.0) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib,torch]==2.38.0) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[rllib,torch]==2.38.0) (0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from typer->ray[rllib,torch]==2.38.0) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from markdown-it-py>=2.2.0->rich->ray[rllib,torch]==2.38.0) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from python-dateutil>=2.8.2->pandas->ray[rllib,torch]==2.38.0) (1.16.0)
# WARNING: ray 2.38.0 does not provide the extra 'torch'
# Requirement already satisfied: ray==2.38.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (2.38.0)
# Requirement already satisfied: click>=7.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (8.1.7)
# Requirement already satisfied: filelock in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (3.13.1)
# Requirement already satisfied: jsonschema in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (1.0.3)
# Requirement already satisfied: packaging in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (24.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (5.28.3)
# Requirement already satisfied: pyyaml in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (6.0.1)
# Requirement already satisfied: aiosignal in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (1.4.0)
# Requirement already satisfied: requests in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray==2.38.0->ray[all]==2.38.0) (2.32.3)
# Requirement already satisfied: pandas>=1.3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (2.2.2)
# Requirement already satisfied: pyOpenSSL in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (24.2.1)
# Requirement already satisfied: opencensus in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.11.4)
# Requirement already satisfied: colorful in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.5.6)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (20.28.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (1.26.4)
# Requirement already satisfied: starlette in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.41.3)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.28.1)
# Requirement already satisfied: scikit-image in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.24.0)
# Requirement already satisfied: fastapi in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.115.5)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (2.6.2.2)
# Requirement already satisfied: dm-tree in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.1.8)
# Requirement already satisfied: smart-open in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (5.2.1)
# Requirement already satisfied: lz4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (4.3.2)
# Requirement already satisfied: grpcio in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (1.68.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.14.1)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.4.0)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (16.1.0)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (3.10.5)
# Requirement already satisfied: typer in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.13.1)
# Requirement already satisfied: aiohttp-cors in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.7.0)
# Requirement already satisfied: opentelemetry-sdk in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (1.28.2)
# Requirement already satisfied: scipy in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (1.13.1)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (2.10.2)
# Requirement already satisfied: rich in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (13.7.1)
# Requirement already satisfied: fsspec in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (2024.6.1)
# Requirement already satisfied: opentelemetry-api in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (1.28.2)
# Requirement already satisfied: uvicorn[standard] in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (0.32.1)
# Requirement already satisfied: watchfiles in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (1.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (1.28.2)
# Requirement already satisfied: cupy-cuda12x in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from ray[all]==2.38.0) (13.3.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[all]==2.38.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[all]==2.38.0) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[all]==2.38.0) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from gymnasium==0.28.1->ray[all]==2.38.0) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from aiohttp>=3.7->ray[all]==2.38.0) (2.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from aiohttp>=3.7->ray[all]==2.38.0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from aiohttp>=3.7->ray[all]==2.38.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from aiohttp>=3.7->ray[all]==2.38.0) (1.11.0)
# Requirement already satisfied: colorama in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from click>=7.0->ray==2.38.0->ray[all]==2.38.0) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas>=1.3->ray[all]==2.38.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas>=1.3->ray[all]==2.38.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pandas>=1.3->ray[all]==2.38.0) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]==2.38.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]==2.38.0) (2.27.1)
# Collecting typing-extensions>=4.3.0 (from gymnasium==0.28.1->ray[all]==2.38.0)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]==2.38.0) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]==2.38.0) (3.10.0)
# Requirement already satisfied: fastrlock>=0.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from cupy-cuda12x->ray[all]==2.38.0) (0.8.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from starlette->ray[all]==2.38.0) (4.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[all]==2.38.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[all]==2.38.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from jsonschema->ray==2.38.0->ray[all]==2.38.0) (0.10.6)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opencensus->ray[all]==2.38.0) (0.1.3)
# Requirement already satisfied: six~=1.16 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opencensus->ray[all]==2.38.0) (1.16.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opencensus->ray[all]==2.38.0) (2.23.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-api->ray[all]==2.38.0) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-api->ray[all]==2.38.0) (7.0.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.28.2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-exporter-otlp->ray[all]==2.38.0) (1.28.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.28.2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-exporter-otlp->ray[all]==2.38.0) (1.28.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]==2.38.0) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]==2.38.0) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]==2.38.0) (1.28.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from opentelemetry-sdk->ray[all]==2.38.0) (0.49b2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[all]==2.38.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[all]==2.38.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[all]==2.38.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from requests->ray==2.38.0->ray[all]==2.38.0) (2024.8.30)
# Requirement already satisfied: cryptography<44,>=41.0.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pyOpenSSL->ray[all]==2.38.0) (43.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from rich->ray[all]==2.38.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from rich->ray[all]==2.38.0) (2.15.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[all]==2.38.0) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[all]==2.38.0) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[all]==2.38.0) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[all]==2.38.0) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from scikit-image->ray[all]==2.38.0) (0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from typer->ray[all]==2.38.0) (1.5.4)
# Requirement already satisfied: h11>=0.8 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]==2.38.0) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]==2.38.0) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]==2.38.0) (1.0.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]==2.38.0) (14.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from anyio<5,>=3.4.0->starlette->ray[all]==2.38.0) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from cryptography<44,>=41.0.5->pyOpenSSL->ray[all]==2.38.0) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api->ray[all]==2.38.0) (1.14.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]==2.38.0) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]==2.38.0) (2.36.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api->ray[all]==2.38.0) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from markdown-it-py>=2.2.0->rich->ray[all]==2.38.0) (0.1.0)
# Requirement already satisfied: pycparser in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL->ray[all]==2.38.0) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]==2.38.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]==2.38.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]==2.38.0) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]==2.38.0) (0.4.8)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
# Successfully installed typing-extensions-4.12.2
# Requirement already satisfied: pygame in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (2.6.1)
# Requirement already satisfied: matplotlib in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: networkx in c:\users\aniru\miniconda3\envs\env1\lib\site-packages (3.3)

# %%
# !pip uninstall "ray[rllib]==2.38.0"
# !pip uninstall "ray[rllib,torch]==2.38.0"
# !pip uninstall "ray[all]==2.38.0"

# %%
import ray
ray.init(ignore_reinit_error=True,num_gpus=1)
print(ray.cluster_resources())
# Out:
# 2024-12-02 15:52:01,005	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-12-02 15:52:08,904	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# {'accelerator_type:G': 1.0, 'node:__internal_head__': 1.0, 'CPU': 12.0, 'object_store_memory': 3984535142.0, 'node:127.0.0.1': 1.0, 'memory': 7969070286.0, 'GPU': 1.0}

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.current_device())
print(torch.version.cuda)
# Out:
# True
# 0
# 12.4

# %% [markdown]
# # Relevant and working codes

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.utils.framework import try_import_torch
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import sys
import torch
import os
from collections import deque
import time
import pygame
import xml.etree.ElementTree as ET
import re

# Set the CUDA_VISIBLE_DEVICES environment variable to the GPU index of the L4 (e.g., 0)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Replace "0" with the actual index of the L4 GPU based on `nvidia-smi`

pygame.init()
WIDTH, HEIGHT = 1200, 900
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Aircraft Movement on Taxiways")

# Parse the KML file
file_path = "5x5.kml"  # Update this path to your KML file
tree = ET.parse(file_path)
root = tree.getroot()
namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

# Lists to store the taxiways and gates
taxiways = []
gates = []

# Extract LineStrings (taxiways and runways) and Points (gates)
for placemark in root.findall('.//kml:Placemark', namespace):
    line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
    if line_string is not None:
        line_coords = line_string.text.strip().split()
        path = []
        for coord in line_coords:
            lon, lat, _ = map(float, coord.split(','))
            path.append((lon, lat))
        taxiway = {'path': path}
        name = placemark.find('kml:name', namespace)
        if name is not None:
            placemark_name = name.text.strip()
            taxiway['name'] = placemark_name
            match = re.search(r'\b(L1|L2|L3)\b', placemark_name)
            if match:
                taxiway['code'] = match.group(1)
            else:
                taxiway['code'] = ''
            if 'CENTRELINE' in placemark_name.upper():
                taxiway['is_runway'] = True
        taxiways.append(taxiway)
    point = placemark.find('.//kml:Point/kml:coordinates', namespace)
    if point is not None:
        coord = point.text.strip().split(',')
        lon, lat, _ = map(float, coord)
        gates.append({'position': (lon, lat)})

# Find the bounds of all coordinates
all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
all_gate_coords = [gate['position'] for gate in gates]
all_coords = all_taxiway_coords + all_gate_coords

lon_min = min(coord[0] for coord in all_coords)
lon_max = max(coord[0] for coord in all_coords)
lat_min = min(coord[1] for coord in all_coords)
lat_max = max(coord[1] for coord in all_coords)

margin = 0.05
lon_range = lon_max - lon_min
lat_range = lat_max - lat_min
lon_min -= lon_range * margin
lon_max += lon_range * margin
lat_min -= lat_range * margin
lat_max += lat_range * margin

def convert_coords(lon, lat):
    x = (lon - lon_min) / (lon_max - lon_min) * WIDTH
    y = HEIGHT - (lat - lat_min) / (lat_max - lat_min) * HEIGHT
    return pygame.math.Vector2(x, y)

for taxiway in taxiways:
    pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
    taxiway['pixel_path'] = pixel_path

for gate in gates:
    gate['pixel_position'] = convert_coords(*gate['position'])

def distance(p1, p2):
    return (p1 - p2).length()

G = nx.Graph()
node_id_counter = 0
node_positions = {}
for idx, taxiway in enumerate(taxiways):
    path = taxiway['pixel_path']
    taxiway_name = taxiway.get('name', '')
    taxiway_code = taxiway.get('code', '')
    taxiway_nodes = []
    for i, point in enumerate(path):
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=(point.x, point.y))
        G.nodes[node_id]['taxiway_name'] = taxiway_name
        G.nodes[node_id]['taxiway_code'] = taxiway_code
        if taxiway.get('is_runway'):
            G.nodes[node_id]['is_runway_node'] = True
        node_positions[node_id] = point
        taxiway_nodes.append(node_id)
        if i > 0:
            prev_node_id = taxiway_nodes[i - 1]
            G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
    taxiway['node_ids'] = taxiway_nodes

def connect_taxiway_endpoints():
    CONNECTION_THRESHOLD = 30
    for taxiway1 in taxiways:
        for taxiway2 in taxiways:
            if taxiway1 == taxiway2:
                continue
            endpoints1 = [taxiway1['node_ids'][0], taxiway1['node_ids'][-1]]
            endpoints2 = [taxiway2['node_ids'][0], taxiway2['node_ids'][-1]]
            for node1 in endpoints1:
                for node2 in endpoints2:
                    pos1 = pygame.math.Vector2(G.nodes[node1]['pos'])
                    pos2 = pygame.math.Vector2(G.nodes[node2]['pos'])
                    if distance(pos1, pos2) < CONNECTION_THRESHOLD:
                        if not G.has_edge(node1, node2):
                            G.add_edge(node1, node2, weight=distance(pos1, pos2))

connect_taxiway_endpoints()

def connect_runways_to_taxiways():
    CONNECTION_THRESHOLD = 30
    for runway in [t for t in taxiways if t.get('is_runway')]:
        for taxiway in [t for t in taxiways if not t.get('is_runway')]:
            for runway_node in runway['node_ids']:
                for taxiway_node in taxiway['node_ids']:
                    pos_runway = pygame.math.Vector2(G.nodes[runway_node]['pos'])
                    pos_taxiway = pygame.math.Vector2(G.nodes[taxiway_node]['pos'])
                    if distance(pos_runway, pos_taxiway) < CONNECTION_THRESHOLD:
                        if not G.has_edge(runway_node, taxiway_node):
                            G.add_edge(runway_node, taxiway_node, weight=distance(pos_runway, pos_taxiway))

connect_runways_to_taxiways()

flipped_positions = {node: (pos[0], -pos[1]) for node, pos in node_positions.items()}

# Ensure all edges have a weight of 1
for edge in G.edges():
    G[edge[0]][edge[1]]['weight'] = 1

# Custom Multi-Agent Environment for Shortest Path Finding (RLlib-compatible)
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, graph, num_agents=3):
        super().__init__()
        self.graph = graph
        self.total_agents = num_agents
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}

        # Use Discrete spaces to represent each agent's current node in the graph
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        nodes = np.array(list(self.graph.nodes)).flatten()
        for agent in self.agents:
            self.pos[agent] = np.random.choice(nodes)
            self.distance_travelled[agent] = 0
        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}  # Return observations as a dictionary
        return obs, {}

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        # Move each agent
        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            # Ensure next_node is a valid neighbor of the current node
            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += nx.get_edge_attributes(self.graph, 'weight').get((current_node, next_node), 1)
                rewards[agent] = -0.1  # Small negative reward to encourage shorter paths  # Encourage shorter paths

        # Detect collisions
        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 5  # Reduced penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 10
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        # Update done flags for all agents
        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True  # Mark as truncated to properly handle episode end

        # Check if all agents are done
        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}  # Return observations as a dictionary
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}  # Update infos to match the current observation keys

        return obs, rewards, dones, truncateds, infos

def render_pygame(env):
    screen.fill((255, 255, 255))  # Fill background with white

    # Draw taxiways
    for taxiway in taxiways:
        pixel_path = taxiway['pixel_path']
        if len(pixel_path) > 1:
            pygame.draw.lines(screen, (0, 0, 0), False, [(point.x, point.y) for point in pixel_path], 2)

    # Draw nodes
    for node in env.graph.nodes:
        pos = env.graph.nodes[node]['pos']
        pygame.draw.circle(screen, (0, 0, 255), (int(pos[0]), int(pos[1])), 5)

    # Draw agents
    colors = [(255, 0, 0), (0, 255, 0), (128, 0, 128)]
    for idx, agent in enumerate(env.agents):
        if env.pos[agent] is not None:
            pos = env.graph.nodes[env.pos[agent]]['pos']
            pygame.draw.circle(screen, colors[idx % len(colors)], (int(pos[0]), int(pos[1])), 10)

    pygame.display.flip()  # Update the display

# Adjust training config and PPO code accordingly

# Create environment
env = RoadIntersectionEnv(G, num_agents=3)

# RLlib Training Configuration with fixed typo
ray.init(ignore_reinit_error=True, num_gpus=1, log_to_driver=True)

from ray.tune.registry import register_env

def env_creator(env_config):
    return RoadIntersectionEnv(env_config['graph'], env_config['num_agents'])

register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

def policy_mapping_fn(agent_id, *args, **kwargs):
    return "shared_policy"

config = {
    "rllib_version": "2.38",
    "env": "RoadIntersectionEnv",
    "env_config": {
        "graph": G,
        "num_agents": 3
    },
    "framework": "torch",  # Switch to PyTorch framework
    "num_workers": 5,  # Adjust number of workers to utilize available CPU cores
    "num_envs_per_worker": 80,  # Set environments per worker to balance CPU usage
    "num_gpus": 1,  # Specify that GPU should be used
    "train_batch_size": 8000,  # Increased batch size for more data per update
    "sgd_minibatch_size": 128,  # Increase minibatch size for training
    "lr": 1e-4,  # Reduced learning rate for stability
    "gamma": 0.99,  # Discount factor for reward
    "log_level": "DEBUG",
    "multiagent": {
        "policies": {
            "shared_policy": (None, env.observation_space, env.action_space, {})
        },
        "policy_mapping_fn": policy_mapping_fn,
        "policies_to_train": ["shared_policy"],
    },
    "exploration_config": {  # Add exploration configuration
        "type": "EpsilonGreedy",
        "initial_epsilon": 1.0,
        "final_epsilon": 0.05,
        "epsilon_timesteps": 20000  # Increased exploration time for better learning
    },
    "monitor": True,  # Enable monitoring for visualization
    "metric": "episode_reward_mean",
    "mode": "max"
}

# Track training progress
rewards_history = deque(maxlen=100)
iterations = []
mean_rewards = []

# Train the model using PPO with more frequent checkpoints
analysis = tune.run(
    "PPO", 
    config=config,
    reuse_actors=True, 
    stop={"training_iteration": 25}, 
    verbose=1, 
    storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints", 
    checkpoint_at_end=True,
    checkpoint_freq=5  # Save checkpoints more frequently
)

# Save the model
try:
    print("Available metrics:", analysis.results_df.columns)
    if analysis.trials and analysis.get_best_trial(metric="training_iteration", mode="max") is not None:
        best_trial = analysis.get_best_trial(metric="training_iteration", mode="max")
        best_checkpoint = analysis.get_best_checkpoint(trial=best_trial, metric="training_iteration", mode="max")
    else:
        # Fallback if 'episode_reward_mean' is not available
        best_trial = analysis.get_best_trial(metric="training_iteration", mode="max")
        best_checkpoint = analysis.get_best_checkpoint(trial=best_trial, metric="training_iteration", mode="max")

    if best_checkpoint is not None:
        print(f"Best checkpoint: {best_checkpoint}")

        # Use the trained model
        obs = env.reset()[0]
        trainer = PPO(env="RoadIntersectionEnv", config=config)
        trainer.restore(best_checkpoint)

        done = {agent: False for agent in env.agents}
        done['__all__'] = False

        should_render = True  # Change to True to visualize

        while not done['__all__']:
            actions = {agent: trainer.compute_single_action(obs[agent], policy_id="shared_policy", explore=True) for agent in env.agents if not done[agent]}
            obs, rewards, done, truncateds, infos = env.step(actions)
            
            if should_render:
                render_pygame(env)

            # Track rewards for visualization
            episode_reward = sum(rewards.values())
            rewards_history.append(episode_reward)
            iterations.append(len(iterations) + 1)
            mean_reward = np.mean(rewards_history)
            mean_rewards.append(mean_reward)

        # # Plot training progress
        # plt.plot(iterations, mean_rewards)
        # plt.xlabel('Training Iteration')
        # plt.ylabel('Mean Episode Reward (last 100 episodes)')
        # plt.title('Training Progress')
        # plt.grid()
        # plt.show()
    else:
        print("No valid checkpoint found. Unable to restore the model.")
except KeyError as e:
    print(f"KeyError encountered: {e}. Unable to retrieve the required metric.")
    if best_checkpoint is not None:
        print(f"Best checkpoint: {best_checkpoint}")

        # Use the trained model
        obs = env.reset()[0]
        trainer = PPO(config=config)
        trainer.restore(best_checkpoint)

        done = {agent: False for agent in env.agents}
        done['__all__'] = False

        should_render = True  # Change to True to visualize

        while not done['__all__']:
            actions = {agent: trainer.compute_single_action(obs[agent], policy_id="shared_policy") for agent in env.agents if not done[agent]}
            obs, rewards, done, truncateds, info = env.step(actions)
            
            if should_render:
                render_pygame(env)

            # Track rewards for visualization
            episode_reward = sum(rewards.values())
            rewards_history.append(episode_reward)
            iterations.append(len(iterations) + 1)
            mean_reward = np.mean(rewards_history)
            mean_rewards.append(mean_reward)

        # # Plot training progress
        # plt.plot(iterations, mean_rewards)
        # plt.xlabel('Training Iteration')
        # plt.ylabel('Mean Episode Reward (last 100 episodes)')
        # plt.title('Training Progress')
        # plt.grid()
        # plt.show()
    else:
        print("No valid checkpoint found. Unable to restore the model.")
else:
    print("No valid trials found. Unable to retrieve the best checkpoint.")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-11-26 21:22:32</td></tr>
# <tr><td>Running for: </td><td>00:16:06.19        </td></tr>
# <tr><td>Memory:      </td><td>14.9/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 6.0/12 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status    </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_32856_00000</td><td>TERMINATED</td><td>127.0.0.1:21948</td><td style="text-align: right;">    25</td><td style="text-align: right;">         930.471</td><td style="text-align: right;">200000</td><td style="text-align: right;">                    5</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-11-26 21:06:25,961	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (PPO pid=21948) 2024-11-26 21:06:38,437	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (RolloutWorker pid=26688) 2024-11-26 21:06:53,717	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy
# (RolloutWorker pid=26688) 2024-11-26 21:06:53,718	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x0000022F8D307CB0>: Discrete(14) -> (14,)
# (RolloutWorker pid=26688) 2024-11-26 21:06:53,735	INFO policy.py:1243 -- Policy (worker=1) running on CPU.
# (RolloutWorker pid=26688) 2024-11-26 21:06:53,735	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices.
# (RolloutWorker pid=26688) 2024-11-26 21:06:57,397	INFO util.py:118 -- Using connectors:
# (RolloutWorker pid=26688) 2024-11-26 21:06:57,398	INFO util.py:119 --     AgentConnectorPipeline
# (RolloutWorker pid=26688)         ObsPreprocessorConnector
# (RolloutWorker pid=26688)         StateBufferConnector
# (RolloutWorker pid=26688)         ViewRequirementAgentConnector
# (RolloutWorker pid=26688) 2024-11-26 21:06:57,398	INFO util.py:120 --     ActionConnectorPipeline
# (RolloutWorker pid=26688)         ConvertToNumpyConnector
# (RolloutWorker pid=26688)         NormalizeActionsConnector
# (RolloutWorker pid=26688)         ImmutableActionsConnector
# (PPO pid=21948) 2024-11-26 21:06:57,539	INFO env_runner_group.py:314 -- Inferred observation/action spaces from remote worker (local worker has no env): {'shared_policy': (Discrete(14), Discrete(14)), '__env__': (Discrete(14), Discrete(14))}
# (PPO pid=21948) 2024-11-26 21:06:57,555	INFO policy.py:1243 -- Policy (worker=local) running on CPU.
# (PPO pid=21948) 2024-11-26 21:07:00,204	INFO rollout_worker.py:1748 -- Built policy map: <PolicyMap lru-caching-capacity=100 policy-IDs=['shared_policy']>
# (PPO pid=21948) 2024-11-26 21:07:00,204	INFO rollout_worker.py:1749 -- Built preprocessor map: {'shared_policy': None}
# (PPO pid=21948) 2024-11-26 21:07:00,204	INFO rollout_worker.py:545 -- Built filter map: defaultdict(<class 'ray.rllib.utils.filter.NoFilter'>, {})
# (PPO pid=21948) Trainable.setup took 21.079 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=21948) Install gputil for GPU system monitoring.
# (PPO pid=21948) 2024-11-26 21:06:57,543	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (PPO pid=21948) 2024-11-26 21:06:57,543	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x0000022E0F237170>: Discrete(14) -> (14,) [repeated 5x across cluster]
# (RolloutWorker pid=27012) 2024-11-26 21:06:53,909	INFO policy.py:1243 -- Policy (worker=4) running on CPU. [repeated 4x across cluster]
# (PPO pid=21948) 2024-11-26 21:06:57,555	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices. [repeated 5x across cluster]
# (RolloutWorker pid=26688) 2024-11-26 21:07:00,239	INFO rollout_worker.py:674 -- Generating sample batch of size 1600
# (RolloutWorker pid=26688) 2024-11-26 21:07:02,606	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688) { 'count': 1600,
# (RolloutWorker pid=26688)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((3594, 14), dtype=float32, min=-0.005, max=0.006, mean=0.0),
# (RolloutWorker pid=26688)                                          'action_logp': np.ndarray((3594,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'actions': np.ndarray((3594,), dtype=int64, min=0.0, max=13.0, mean=6.585),
# (RolloutWorker pid=26688)                                          'advantages': np.ndarray((3594,), dtype=float32, min=-0.57, max=0.001, mean=-0.072),
# (RolloutWorker pid=26688)                                          'agent_index': np.ndarray((3594,), dtype=int32, min=0.0, max=2.0, mean=0.991),
# (RolloutWorker pid=26688)                                          'eps_id': np.ndarray((3594,), dtype=int64, min=134421839206049.0, max=9.771471146349039e+17, mean=4.864938860859483e+17),
# (RolloutWorker pid=26688)                                          'infos': np.ndarray((3594,), dtype=object, head={}),
# (RolloutWorker pid=26688)                                          'new_obs': np.ndarray((3594, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'obs': np.ndarray((3594, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'rewards': np.ndarray((3594,), dtype=float64, min=-0.1, max=0.0, mean=-0.008),
# (RolloutWorker pid=26688)                                          't': np.ndarray((3594,), dtype=int32, min=0.0, max=19.0, mean=9.09),
# (RolloutWorker pid=26688)                                          'terminateds': np.ndarray((3594,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'truncateds': np.ndarray((3594,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'unroll_id': np.ndarray((3594,), dtype=int32, min=3.0, max=479.0, mean=237.356),
# (RolloutWorker pid=26688)                                          'value_targets': np.ndarray((3594,), dtype=float32, min=-0.57, max=0.003, mean=-0.072),
# (RolloutWorker pid=26688)                                          'values_bootstrapped': np.ndarray((3594,), dtype=float32, min=-0.003, max=0.003, mean=0.0),
# (RolloutWorker pid=26688)                                          'vf_preds': np.ndarray((3594,), dtype=float32, min=-0.003, max=0.003, mean=0.0)}},
# (RolloutWorker pid=26688)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=26688)
# (PPO pid=21948) 2024-11-26 21:07:00,204	INFO util.py:118 -- Using connectors: [repeated 5x across cluster]
# (PPO pid=21948) 2024-11-26 21:07:00,204	INFO util.py:119 --     AgentConnectorPipeline [repeated 5x across cluster]
# (PPO pid=21948)         ObsPreprocessorConnector [repeated 5x across cluster]
# (PPO pid=21948)         StateBufferConnector [repeated 5x across cluster]
# (PPO pid=21948)         ViewRequirementAgentConnector [repeated 5x across cluster]
# (PPO pid=21948) 2024-11-26 21:07:00,204	INFO util.py:120 --     ActionConnectorPipeline [repeated 5x across cluster]
# (PPO pid=21948)         ConvertToNumpyConnector [repeated 5x across cluster]
# (PPO pid=21948)         NormalizeActionsConnector [repeated 5x across cluster]
# (PPO pid=21948)         ImmutableActionsConnector [repeated 5x across cluster]
# (PPO pid=21948) 2024-11-26 21:07:02,634	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (PPO pid=21948) 2024-11-26 21:07:02,635	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:07:02,645	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.2,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 2.639055013656616,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.19590701162815094,
# (PPO pid=21948)                                         'kl': 4.976829131919658e-06,
# (PPO pid=21948)                                         'policy_loss': 0.07887719571590424,
# (PPO pid=21948)                                         'total_loss': 0.09047939628362656,
# (PPO pid=21948)                                         'vf_explained_var': 0.003508627414703369,
# (PPO pid=21948)                                         'vf_loss': 0.011601196601986885},
# (PPO pid=21948)                      'model': {},
# (PPO pid=21948)                      'num_agent_steps_trained': 128,
# (PPO pid=21948)                      'num_grad_updates_lifetime': 1}}
# (PPO pid=21948)
# (RolloutWorker pid=26688) 2024-11-26 21:08:19,411	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688) { 'count': 1600, [repeated 2x across cluster]
# (RolloutWorker pid=26688)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((3280, 14), dtype=float32, min=-0.502, max=3.102, mean=-0.058), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'action_logp': np.ndarray((3280,), dtype=float32, min=0.0, max=0.0, mean=0.0), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'actions': np.ndarray((3280,), dtype=int64, min=0.0, max=13.0, mean=6.561), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'advantages': np.ndarray((3280,), dtype=float32, min=-0.14, max=0.024, mean=0.001), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'agent_index': np.ndarray((3280,), dtype=int32, min=0.0, max=2.0, mean=0.963), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'eps_id': np.ndarray((3280,), dtype=int64, min=134421839206049.0, max=9.771471146349039e+17, mean=4.874560726250654e+17), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'infos': np.ndarray((3280,), dtype=object, head={}), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'new_obs': np.ndarray((3280, 14), dtype=float32, min=0.0, max=1.0, mean=0.071), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'obs': np.ndarray((3280, 14), dtype=float32, min=0.0, max=1.0, mean=0.071), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'rewards': np.ndarray((3280,), dtype=float64, min=-0.1, max=0.0, mean=-0.0), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          't': np.ndarray((3280,), dtype=int32, min=40.0, max=59.0, mean=49.5), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'terminateds': np.ndarray((3280,), dtype=bool, min=0.0, max=0.0, mean=0.0), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'truncateds': np.ndarray((3280,), dtype=bool, min=0.0, max=0.0, mean=0.0), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'unroll_id': np.ndarray((3280,), dtype=int32, min=644.0, max=807.0, mean=725.5), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'value_targets': np.ndarray((3280,), dtype=float32, min=-0.194, max=-0.04, mean=-0.062), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'values_bootstrapped': np.ndarray((3280,), dtype=float32, min=-0.099, max=-0.049, mean=-0.062), [repeated 2x across cluster]
# (RolloutWorker pid=26688)                                          'vf_preds': np.ndarray((3280,), dtype=float32, min=-0.105, max=-0.049, mean=-0.063)}}, [repeated 2x across cluster]
# (RolloutWorker pid=26688)   'type': 'MultiAgentBatch'} [repeated 2x across cluster]
# (PPO pid=21948) 2024-11-26 21:08:40,611	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:08:40,618	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 2433.0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.15000000000000002,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 1.3411966562271118,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.14334388077259064,
# (PPO pid=21948)                                         'kl': 0.06405651569366455,
# (PPO pid=21948)                                         'policy_loss': 0.047251686453819275,
# (PPO pid=21948)                                         'total_loss': 0.057280078530311584,
# (PPO pid=21948)                                         'vf_explained_var': 0.3947439193725586,
# (PPO pid=21948)                                         'vf_loss': 0.0004199105314910412},
# (PPO pid=21948)                      'model': {},
# (PPO pid=21948)                      'num_agent_steps_trained': 128,
# (PPO pid=21948)                      'num_grad_updates_lifetime': 10864}}
# (PPO pid=21948)
# (PPO pid=21948) { 'count': 128,
# (PPO pid=21948)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-0.502, max=3.102, mean=-0.065),
# (PPO pid=21948)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=6.398),
# (PPO pid=21948)                                          'advantages': np.ndarray((128,), dtype=float32, min=-5.851, max=0.767, mean=-0.055),
# (PPO pid=21948)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.055),
# (PPO pid=21948)                                          'eps_id': np.ndarray((128,), dtype=int64, min=3336850926833639.0, max=9.808559027422495e+17, mean=4.887624578508152e+17),
# (PPO pid=21948)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=21948)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'rewards': np.ndarray((128,), dtype=float64, min=-0.1, max=0.0, mean=-0.001),
# (PPO pid=21948)                                          't': np.ndarray((128,), dtype=int32, min=40.0, max=59.0, mean=48.898),
# (PPO pid=21948)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=644.0, max=842.0, mean=745.773),
# (PPO pid=21948)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.172, max=-0.042, mean=-0.062),
# (PPO pid=21948)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.099, max=-0.049, mean=-0.064),
# (PPO pid=21948)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.101, max=-0.049, mean=-0.064)}},
# (PPO pid=21948)   'type': 'MultiAgentBatch'}
# (PPO pid=21948) 2024-11-26 21:08:40,743	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=26688) 2024-11-26 21:08:54,892	INFO rollout_worker.py:674 -- Generating sample batch of size 1600
# (PPO pid=21948) 2024-11-26 21:09:54,864	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948) { 'count': 128,
# (PPO pid=21948)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-0.691, max=3.744, mean=-0.153),
# (PPO pid=21948)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.312),
# (PPO pid=21948)                                          'advantages': np.ndarray((128,), dtype=float32, min=-13.52, max=1.013, mean=-0.063),
# (PPO pid=21948)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=0.922),
# (PPO pid=21948)                                          'eps_id': np.ndarray((128,), dtype=int64, min=1.6897068889618044e+16, max=9.875734705639192e+17, mean=5.173573628032149e+17),
# (PPO pid=21948)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=21948)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'rewards': np.ndarray((128,), dtype=float64, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          't': np.ndarray((128,), dtype=int32, min=80.0, max=99.0, mean=89.555),
# (PPO pid=21948)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=973.0, max=1213.0, mean=1082.297),
# (PPO pid=21948)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.338, max=-0.036, mean=-0.059),
# (PPO pid=21948)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.087, max=-0.043, mean=-0.06),
# (PPO pid=21948)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.092, max=-0.043, mean=-0.06)}},
# (PPO pid=21948)   'type': 'MultiAgentBatch'}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:09:54,873	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 2425.0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.22500000000000003,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 1.0394835472106934,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.17199786007404327,
# (PPO pid=21948)                                         'kl': 0.007461990229785442,
# (PPO pid=21948)                                         'policy_loss': 0.058198295533657074,
# (PPO pid=21948)                                         'total_loss': 0.0607907772064209,
# (PPO pid=21948)                                         'vf_explained_var': 0.15693962574005127,
# (PPO pid=21948)                                         'vf_loss': 0.0009135329746641219},
# (PPO pid=21948)                      'model': {},
# (PPO pid=21948)                      'num_agent_steps_trained': 128,
# (PPO pid=21948)                      'num_grad_updates_lifetime': 18986}}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:09:54,912	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (PPO pid=21948) Checkpoint successfully created at: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_21-06-25/PPO_RoadIntersectionEnv_32856_00000_0_2024-11-26_21-06-25/checkpoint_000000)
# (RolloutWorker pid=26688) 2024-11-26 21:10:11,203	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688) { 'count': 1600,
# (RolloutWorker pid=26688)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((3280, 14), dtype=float32, min=-0.737, max=3.984, mean=-0.112),
# (RolloutWorker pid=26688)                                          'action_logp': np.ndarray((3280,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'actions': np.ndarray((3280,), dtype=int64, min=0.0, max=13.0, mean=6.773),
# (RolloutWorker pid=26688)                                          'advantages': np.ndarray((3280,), dtype=float32, min=-0.118, max=0.02, mean=0.002),
# (RolloutWorker pid=26688)                                          'agent_index': np.ndarray((3280,), dtype=int32, min=0.0, max=2.0, mean=0.963),
# (RolloutWorker pid=26688)                                          'eps_id': np.ndarray((3280,), dtype=int64, min=134421839206049.0, max=9.771471146349039e+17, mean=4.874560726250654e+17),
# (RolloutWorker pid=26688)                                          'infos': np.ndarray((3280,), dtype=object, head={}),
# (RolloutWorker pid=26688)                                          'new_obs': np.ndarray((3280, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'obs': np.ndarray((3280, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'rewards': np.ndarray((3280,), dtype=float64, min=-0.1, max=0.0, mean=-0.0),
# (RolloutWorker pid=26688)                                          't': np.ndarray((3280,), dtype=int32, min=100.0, max=119.0, mean=109.5),
# (RolloutWorker pid=26688)                                          'terminateds': np.ndarray((3280,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'truncateds': np.ndarray((3280,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'unroll_id': np.ndarray((3280,), dtype=int32, min=1136.0, max=1299.0, mean=1217.5),
# (RolloutWorker pid=26688)                                          'value_targets': np.ndarray((3280,), dtype=float32, min=-0.18, max=-0.034, mean=-0.053),
# (RolloutWorker pid=26688)                                          'values_bootstrapped': np.ndarray((3280,), dtype=float32, min=-0.085, max=-0.041, mean=-0.055),
# (RolloutWorker pid=26688)                                          'vf_preds': np.ndarray((3280,), dtype=float32, min=-0.087, max=-0.041, mean=-0.055)}},
# (RolloutWorker pid=26688)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688) 2024-11-26 21:10:46,123	INFO rollout_worker.py:674 -- Generating sample batch of size 1600
# (PPO pid=21948) 2024-11-26 21:11:08,904	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948) { 'count': 128,
# (PPO pid=21948)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-0.812, max=4.402, mean=-0.162),
# (PPO pid=21948)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.055),
# (PPO pid=21948)                                          'advantages': np.ndarray((128,), dtype=float32, min=-5.849, max=0.784, mean=-0.024),
# (PPO pid=21948)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.008),
# (PPO pid=21948)                                          'eps_id': np.ndarray((128,), dtype=int64, min=4850199063646316.0, max=9.875734705639192e+17, mean=5.272776904697268e+17),
# (PPO pid=21948)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=21948)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'rewards': np.ndarray((128,), dtype=float64, min=-0.1, max=0.0, mean=-0.001),
# (PPO pid=21948)                                          't': np.ndarray((128,), dtype=int32, min=120.0, max=139.0, mean=128.984),
# (PPO pid=21948)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=1304.0, max=1568.0, mean=1434.742),
# (PPO pid=21948)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.165, max=-0.034, mean=-0.052),
# (PPO pid=21948)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.083, max=-0.041, mean=-0.053),
# (PPO pid=21948)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.085, max=-0.041, mean=-0.053)}},
# (PPO pid=21948)   'type': 'MultiAgentBatch'}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:11:08,914	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 2371.0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.22500000000000003,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 0.9694442749023438,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.09037456661462784,
# (PPO pid=21948)                                         'kl': 0.003389958757907152,
# (PPO pid=21948)                                         'policy_loss': 0.008512422442436218,
# (PPO pid=21948)                                         'total_loss': 0.009712203405797482,
# (PPO pid=21948)                                         'vf_explained_var': 0.14962971210479736,
# (PPO pid=21948)                                         'vf_loss': 0.0004370503593236208},
# (PPO pid=21948)                      'model': {},
# (PPO pid=21948)                      'num_agent_steps_trained': 128,
# (PPO pid=21948)                      'num_grad_updates_lifetime': 27032}}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:11:09,509	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=26688) 2024-11-26 21:12:03,085	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688) { 'count': 1600,
# (RolloutWorker pid=26688)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((3240, 14), dtype=float32, min=-0.863, max=4.738, mean=-0.133),
# (RolloutWorker pid=26688)                                          'action_logp': np.ndarray((3240,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'actions': np.ndarray((3240,), dtype=int64, min=0.0, max=13.0, mean=6.98),
# (RolloutWorker pid=26688)                                          'advantages': np.ndarray((3240,), dtype=float32, min=-0.113, max=0.02, mean=0.001),
# (RolloutWorker pid=26688)                                          'agent_index': np.ndarray((3240,), dtype=int32, min=0.0, max=2.0, mean=0.969),
# (RolloutWorker pid=26688)                                          'eps_id': np.ndarray((3240,), dtype=int64, min=134421839206049.0, max=9.771471146349039e+17, mean=4.815719824873904e+17),
# (RolloutWorker pid=26688)                                          'infos': np.ndarray((3240,), dtype=object, head={}),
# (RolloutWorker pid=26688)                                          'new_obs': np.ndarray((3240, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'obs': np.ndarray((3240, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'rewards': np.ndarray((3240,), dtype=float64, min=-0.1, max=0.0, mean=-0.0),
# (RolloutWorker pid=26688)                                          't': np.ndarray((3240,), dtype=int32, min=160.0, max=179.0, mean=169.5),
# (RolloutWorker pid=26688)                                          'terminateds': np.ndarray((3240,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'truncateds': np.ndarray((3240,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'unroll_id': np.ndarray((3240,), dtype=int32, min=1628.0, max=1789.0, mean=1708.5),
# (RolloutWorker pid=26688)                                          'value_targets': np.ndarray((3240,), dtype=float32, min=-0.174, max=-0.033, mean=-0.05),
# (RolloutWorker pid=26688)                                          'values_bootstrapped': np.ndarray((3240,), dtype=float32, min=-0.077, max=-0.041, mean=-0.05),
# (RolloutWorker pid=26688)                                          'vf_preds': np.ndarray((3240,), dtype=float32, min=-0.082, max=-0.041, mean=-0.05)}},
# (RolloutWorker pid=26688)   'type': 'MultiAgentBatch'}
# (PPO pid=21948) 2024-11-26 21:12:23,423	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948) { 'count': 128,
# (PPO pid=21948)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-0.863, max=4.738, mean=-0.156),
# (PPO pid=21948)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.031),
# (PPO pid=21948)                                          'advantages': np.ndarray((128,), dtype=float32, min=-9.339, max=0.988, mean=-0.082),
# (PPO pid=21948)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=0.992),
# (PPO pid=21948)                                          'eps_id': np.ndarray((128,), dtype=int64, min=134421839206049.0, max=9.977362638793556e+17, mean=5.031501163535896e+17),
# (PPO pid=21948)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=21948)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'rewards': np.ndarray((128,), dtype=float64, min=-0.1, max=0.0, mean=-0.001),
# (PPO pid=21948)                                          't': np.ndarray((128,), dtype=int32, min=160.0, max=179.0, mean=168.781),
# (PPO pid=21948)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=1635.0, max=1935.0, mean=1770.133),
# (PPO pid=21948)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.233, max=-0.033, mean=-0.051),
# (PPO pid=21948)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.077, max=-0.041, mean=-0.05),
# (PPO pid=21948)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.082, max=-0.041, mean=-0.05)}},
# (PPO pid=21948)   'type': 'MultiAgentBatch'}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:12:23,433	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 2296.0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.11250000000000002,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 0.825404167175293,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.10539346933364868,
# (PPO pid=21948)                                         'kl': 0.015494976192712784,
# (PPO pid=21948)                                         'policy_loss': 0.07139763236045837,
# (PPO pid=21948)                                         'total_loss': 0.07374610006809235,
# (PPO pid=21948)                                         'vf_explained_var': 0.2136881947517395,
# (PPO pid=21948)                                         'vf_loss': 0.0006052778917364776},
# (PPO pid=21948)                      'model': {},
# (PPO pid=21948)                      'num_agent_steps_trained': 128,
# (PPO pid=21948)                      'num_grad_updates_lifetime': 35057}}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:12:24,539	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=26688) 2024-11-26 21:12:38,835	INFO rollout_worker.py:674 -- Generating sample batch of size 1600
# (PPO pid=21948) Checkpoint successfully created at: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_21-06-25/PPO_RoadIntersectionEnv_32856_00000_0_2024-11-26_21-06-25/checkpoint_000001)
# (PPO pid=21948) 2024-11-26 21:13:38,802	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948) { 'count': 128,
# (PPO pid=21948)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-0.948, max=5.409, mean=-0.174),
# (PPO pid=21948)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=6.469),
# (PPO pid=21948)                                          'advantages': np.ndarray((128,), dtype=float32, min=-5.399, max=0.591, mean=0.061),
# (PPO pid=21948)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.0),
# (PPO pid=21948)                                          'eps_id': np.ndarray((128,), dtype=int64, min=2.3302393398663916e+16, max=9.945016397022021e+17, mean=5.622861835108328e+17),
# (PPO pid=21948)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=21948)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'rewards': np.ndarray((128,), dtype=float64, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          't': np.ndarray((128,), dtype=int32, min=200.0, max=219.0, mean=209.109),
# (PPO pid=21948)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=1957.0, max=2294.0, mean=2126.375),
# (PPO pid=21948)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.157, max=-0.03, mean=-0.046),
# (PPO pid=21948)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.076, max=-0.036, mean=-0.048),
# (PPO pid=21948)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.076, max=-0.036, mean=-0.048)}},
# (PPO pid=21948)   'type': 'MultiAgentBatch'}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:13:38,811	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 2417.0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.11250000000000002,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 0.7367043495178223,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.05872640386223793,
# (PPO pid=21948)                                         'kl': 0.016008030623197556,
# (PPO pid=21948)                                         'policy_loss': -0.04373231902718544,
# (PPO pid=21948)                                         'total_loss': -0.041582655161619186,
# (PPO pid=21948)                                         'vf_explained_var': 0.14851391315460205,
# (PPO pid=21948)                                         'vf_loss': 0.00034875923302024603},
# (PPO pid=21948)                      'model': {},
# (PPO pid=21948)                      'num_agent_steps_trained': 128,
# (PPO pid=21948)                      'num_grad_updates_lifetime': 43188}}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:13:39,768	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=26688) 2024-11-26 21:13:54,900	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688) { 'count': 1600,
# (RolloutWorker pid=26688)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((3240, 14), dtype=float32, min=-0.999, max=5.549, mean=-0.141),
# (RolloutWorker pid=26688)                                          'action_logp': np.ndarray((3240,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'actions': np.ndarray((3240,), dtype=int64, min=0.0, max=13.0, mean=6.972),
# (RolloutWorker pid=26688)                                          'advantages': np.ndarray((3240,), dtype=float32, min=-0.106, max=0.016, mean=0.003),
# (RolloutWorker pid=26688)                                          'agent_index': np.ndarray((3240,), dtype=int32, min=0.0, max=2.0, mean=0.969),
# (RolloutWorker pid=26688)                                          'eps_id': np.ndarray((3240,), dtype=int64, min=134421839206049.0, max=9.771471146349039e+17, mean=4.815719824873904e+17),
# (RolloutWorker pid=26688)                                          'infos': np.ndarray((3240,), dtype=object, head={}),
# (RolloutWorker pid=26688)                                          'new_obs': np.ndarray((3240, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'obs': np.ndarray((3240, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'rewards': np.ndarray((3240,), dtype=float64, min=-0.1, max=0.0, mean=-0.0),
# (RolloutWorker pid=26688)                                          't': np.ndarray((3240,), dtype=int32, min=220.0, max=239.0, mean=229.5),
# (RolloutWorker pid=26688)                                          'terminateds': np.ndarray((3240,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'truncateds': np.ndarray((3240,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'unroll_id': np.ndarray((3240,), dtype=int32, min=2114.0, max=2275.0, mean=2194.5),
# (RolloutWorker pid=26688)                                          'value_targets': np.ndarray((3240,), dtype=float32, min=-0.166, max=-0.029, mean=-0.045),
# (RolloutWorker pid=26688)                                          'values_bootstrapped': np.ndarray((3240,), dtype=float32, min=-0.077, max=-0.035, mean=-0.048),
# (RolloutWorker pid=26688)                                          'vf_preds': np.ndarray((3240,), dtype=float32, min=-0.077, max=-0.035, mean=-0.048)}},
# (RolloutWorker pid=26688)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=26688) 2024-11-26 21:14:29,656	INFO rollout_worker.py:674 -- Generating sample batch of size 1600
# (PPO pid=21948) 2024-11-26 21:14:52,921	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948) { 'count': 128,
# (PPO pid=21948)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-1.15, max=6.094, mean=-0.203),
# (PPO pid=21948)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.672),
# (PPO pid=21948)                                          'advantages': np.ndarray((128,), dtype=float32, min=-4.596, max=0.835, mean=0.066),
# (PPO pid=21948)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.148),
# (PPO pid=21948)                                          'eps_id': np.ndarray((128,), dtype=int64, min=3.5940214481332532e+16, max=9.977362638793556e+17, mean=5.160118367765902e+17),
# (PPO pid=21948)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=21948)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'rewards': np.ndarray((128,), dtype=float64, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          't': np.ndarray((128,), dtype=int32, min=240.0, max=259.0, mean=249.414),
# (PPO pid=21948)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=2276.0, max=2647.0, mean=2452.773),
# (PPO pid=21948)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.136, max=-0.028, mean=-0.044),
# (PPO pid=21948)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.077, max=-0.034, mean=-0.045),
# (PPO pid=21948)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.077, max=-0.034, mean=-0.046)}},
# (PPO pid=21948)   'type': 'MultiAgentBatch'}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:14:52,931	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 2449.0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.16875,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 0.6506353616714478,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.06268223375082016,
# ...
# (RolloutWorker pid=26688) 2024-11-26 21:21:20,217	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688)
# (RolloutWorker pid=26688) { 'count': 1600,
# (RolloutWorker pid=26688)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((3240, 14), dtype=float32, min=-1.164, max=5.966, mean=-0.219),
# (RolloutWorker pid=26688)                                          'action_logp': np.ndarray((3240,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'actions': np.ndarray((3240,), dtype=int64, min=0.0, max=13.0, mean=6.99),
# (RolloutWorker pid=26688)                                          'advantages': np.ndarray((3240,), dtype=float32, min=-0.101, max=0.016, mean=0.001),
# (RolloutWorker pid=26688)                                          'agent_index': np.ndarray((3240,), dtype=int32, min=0.0, max=2.0, mean=0.969),
# (RolloutWorker pid=26688)                                          'eps_id': np.ndarray((3240,), dtype=int64, min=134421839206049.0, max=9.771471146349039e+17, mean=4.815719824873904e+17),
# (RolloutWorker pid=26688)                                          'infos': np.ndarray((3240,), dtype=object, head={}),
# (RolloutWorker pid=26688)                                          'new_obs': np.ndarray((3240, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'obs': np.ndarray((3240, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=26688)                                          'rewards': np.ndarray((3240,), dtype=float64, min=-0.1, max=0.0, mean=-0.0),
# (RolloutWorker pid=26688)                                          't': np.ndarray((3240,), dtype=int32, min=460.0, max=479.0, mean=469.5),
# (RolloutWorker pid=26688)                                          'terminateds': np.ndarray((3240,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'truncateds': np.ndarray((3240,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=26688)                                          'unroll_id': np.ndarray((3240,), dtype=int32, min=4058.0, max=4219.0, mean=4138.5),
# (RolloutWorker pid=26688)                                          'value_targets': np.ndarray((3240,), dtype=float32, min=-0.155, max=-0.028, mean=-0.042),
# (RolloutWorker pid=26688)                                          'values_bootstrapped': np.ndarray((3240,), dtype=float32, min=-0.066, max=-0.034, mean=-0.043),
# (RolloutWorker pid=26688)                                          'vf_preds': np.ndarray((3240,), dtype=float32, min=-0.067, max=-0.034, mean=-0.043)}},
# (RolloutWorker pid=26688)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=26688) 2024-11-26 21:21:54,973	INFO rollout_worker.py:674 -- Generating sample batch of size 1600
# (PPO pid=21948) 2024-11-26 21:22:18,156	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=21948)
# (PPO pid=21948) { 'count': 128,
# (PPO pid=21948)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-1.135, max=6.274, mean=-0.228),
# (PPO pid=21948)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=6.789),
# (PPO pid=21948)                                          'advantages': np.ndarray((128,), dtype=float32, min=-5.641, max=0.602, mean=0.024),
# (PPO pid=21948)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=0.922),
# (PPO pid=21948)                                          'eps_id': np.ndarray((128,), dtype=int64, min=3336850926833639.0, max=9.945016397022021e+17, mean=4.7448518213284314e+17),
# (PPO pid=21948)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=21948)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=21948)                                          'rewards': np.ndarray((128,), dtype=float64, min=-0.1, max=0.0, mean=-0.001),
# (PPO pid=21948)                                          't': np.ndarray((128,), dtype=int32, min=480.0, max=499.0, mean=489.602),
# (PPO pid=21948)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=21948)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=4233.0, max=4809.0, mean=4510.438),
# (PPO pid=21948)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.162, max=-0.029, mean=-0.041),
# (PPO pid=21948)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.067, max=-0.035, mean=-0.042),
# (PPO pid=21948)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.067, max=-0.035, mean=-0.042)}},
# (PPO pid=21948)   'type': 'MultiAgentBatch'}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:22:18,165	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=21948)
# (PPO pid=21948) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=21948)                      'diff_num_grad_updates_vs_sampler_policy': 2398.0,
# (PPO pid=21948)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=21948)                                         'cur_kl_coeff': 0.25312500000000004,
# (PPO pid=21948)                                         'cur_lr': 0.0001,
# (PPO pid=21948)                                         'entropy': 0.6083643436431885,
# (PPO pid=21948)                                         'entropy_coeff': 0.0,
# (PPO pid=21948)                                         'grad_gnorm': 0.07019074261188507,
# (PPO pid=21948)                                         'kl': 0.010365716181695461,
# (PPO pid=21948)                                         'policy_loss': -0.020498517900705338,
# (PPO pid=21948)                                         'total_loss': -0.01757294125854969,
# (PPO pid=21948)                                         'vf_explained_var': 0.21489250659942627,
# (PPO pid=21948)                                         'vf_loss': 0.00030173902632668614},
# (PPO pid=21948)                      'model': {},
# (PPO pid=21948)                      'num_agent_steps_trained': 128,
# (PPO pid=21948)                      'num_grad_updates_lifetime': 98669}}
# (PPO pid=21948)
# (PPO pid=21948) 2024-11-26 21:22:18,928	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# 2024-11-26 21:22:32,148	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_21-06-25' in 0.0306s.
# (PPO pid=21948) Checkpoint successfully created at: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_21-06-25/PPO_RoadIntersectionEnv_32856_00000_0_2024-11-26_21-06-25/checkpoint_000004)
# 2024-11-26 21:22:32,576	INFO tune.py:1041 -- Total run time: 966.79 seconds (966.16 seconds for the tuning loop).
# 2024-11-26 21:22:32,642	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# 2024-11-26 21:22:32,643	WARNING deprecation.py:50 -- DeprecationWarning: `algo = Algorithm(env='RoadIntersectionEnv', ...)` has been deprecated. Use `algo = AlgorithmConfig().environment('RoadIntersectionEnv').build()` instead. This will raise an error in the future!
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:568: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# Available metrics: Index(['num_healthy_workers', 'num_in_flight_async_sample_reqs',
#        'num_remote_worker_restarts', 'num_agent_steps_sampled',
#        'num_agent_steps_trained', 'num_env_steps_sampled',
#        'num_env_steps_trained', 'num_env_steps_sampled_this_iter',
#        'num_env_steps_trained_this_iter',
#        'num_env_steps_sampled_throughput_per_sec',
#        ...
#        'info/learner/shared_policy/learner_stats/grad_gnorm',
#        'info/learner/shared_policy/learner_stats/cur_kl_coeff',
#        'info/learner/shared_policy/learner_stats/cur_lr',
#        'info/learner/shared_policy/learner_stats/total_loss',
#        'info/learner/shared_policy/learner_stats/policy_loss',
#        'info/learner/shared_policy/learner_stats/vf_loss',
#        'info/learner/shared_policy/learner_stats/vf_explained_var',
#        'info/learner/shared_policy/learner_stats/kl',
#        'info/learner/shared_policy/learner_stats/entropy',
#        'info/learner/shared_policy/learner_stats/entropy_coeff'],
#       dtype='object', length=339)
# Best checkpoint: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_21-06-25/PPO_RoadIntersectionEnv_32856_00000_0_2024-11-26_21-06-25/checkpoint_000004)
# (RolloutWorker pid=15888) 2024-11-26 21:22:44,233	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy
# (RolloutWorker pid=15888) 2024-11-26 21:22:44,234	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x0000020F8D685A30>: Discrete(14) -> (14,)
# (RolloutWorker pid=15888) 2024-11-26 21:22:44,247	INFO policy.py:1243 -- Policy (worker=3) running on CPU.
# (RolloutWorker pid=15888) 2024-11-26 21:22:44,248	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices.
# 2024-11-26 21:22:48,361	INFO env_runner_group.py:314 -- Inferred observation/action spaces from remote worker (local worker has no env): {'shared_policy': (Discrete(14), Discrete(14)), '__env__': (Discrete(14), Discrete(14))}
# 2024-11-26 21:22:48,365	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy
# 2024-11-26 21:22:48,366	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x000001C891565A30>: Discrete(14) -> (14,)
# 2024-11-26 21:22:48,387	INFO policy.py:1243 -- Policy (worker=local) running on CPU.
# 2024-11-26 21:22:48,388	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices.
# (RolloutWorker pid=15888) 2024-11-26 21:22:48,335	INFO util.py:118 -- Using connectors:
# (RolloutWorker pid=15888) 2024-11-26 21:22:48,335	INFO util.py:119 --     AgentConnectorPipeline
# (RolloutWorker pid=15888)         ObsPreprocessorConnector
# (RolloutWorker pid=15888)         StateBufferConnector
# (RolloutWorker pid=15888)         ViewRequirementAgentConnector
# (RolloutWorker pid=15888) 2024-11-26 21:22:48,335	INFO util.py:120 --     ActionConnectorPipeline
# (RolloutWorker pid=15888)         ConvertToNumpyConnector
# (RolloutWorker pid=15888)         NormalizeActionsConnector
# (RolloutWorker pid=15888)         ImmutableActionsConnector
# 2024-11-26 21:22:51,341	INFO util.py:118 -- Using connectors:
# 2024-11-26 21:22:51,342	INFO util.py:119 --     AgentConnectorPipeline
#         ObsPreprocessorConnector
#         StateBufferConnector
#         ViewRequirementAgentConnector
# 2024-11-26 21:22:51,343	INFO util.py:120 --     ActionConnectorPipeline
#         ConvertToNumpyConnector
#         NormalizeActionsConnector
#         ImmutableActionsConnector
# 2024-11-26 21:22:51,344	INFO rollout_worker.py:1748 -- Built policy map: <PolicyMap lru-caching-capacity=100 policy-IDs=['shared_policy']>
# 2024-11-26 21:22:51,345	INFO rollout_worker.py:1749 -- Built preprocessor map: {'shared_policy': None}
# 2024-11-26 21:22:51,346	INFO rollout_worker.py:545 -- Built filter map: defaultdict(<class 'ray.rllib.utils.filter.NoFilter'>, {})
# 2024-11-26 21:22:51,348	INFO trainable.py:161 -- Trainable.setup took 18.689 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-26 21:22:51,351	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# 2024-11-26 21:22:51,409	DEBUG policy.py:1000 -- restoring agent connectors:
# 2024-11-26 21:22:51,410	DEBUG policy.py:1001 --     AgentConnectorPipeline
#         ObsPreprocessorConnector
#         StateBufferConnector
#         ViewRequirementAgentConnector
# 2024-11-26 21:22:51,410	DEBUG policy.py:1006 -- restoring action connectors:
# 2024-11-26 21:22:51,411	DEBUG policy.py:1007 --     ActionConnectorPipeline
#         ConvertToNumpyConnector
#         NormalizeActionsConnector
#         ImmutableActionsConnector
# (RolloutWorker pid=5700) 2024-11-26 21:22:51,439	DEBUG policy.py:1000 -- restoring agent connectors:
# (RolloutWorker pid=5700) 2024-11-26 21:22:51,439	DEBUG policy.py:1001 --     AgentConnectorPipeline
# (RolloutWorker pid=5700) 2024-11-26 21:22:51,439	DEBUG policy.py:1006 -- restoring action connectors:
# (RolloutWorker pid=5700) 2024-11-26 21:22:51,439	DEBUG policy.py:1007 --     ActionConnectorPipeline
# (RolloutWorker pid=25096) 2024-11-26 21:22:44,241	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy [repeated 4x across cluster]
# (RolloutWorker pid=25096) 2024-11-26 21:22:44,241	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x000002228D6FFEF0>: Discrete(14) -> (14,) [repeated 4x across cluster]
# (RolloutWorker pid=25096) 2024-11-26 21:22:44,256	INFO policy.py:1243 -- Policy (worker=5) running on CPU. [repeated 4x across cluster]
# (RolloutWorker pid=25096) 2024-11-26 21:22:44,256	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices. [repeated 4x across cluster]
# 2024-11-26 21:22:51,468	INFO trainable.py:583 -- Restored on 127.0.0.1 from checkpoint: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_21-06-25/PPO_RoadIntersectionEnv_32856_00000_0_2024-11-26_21-06-25/checkpoint_000004)

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.utils.framework import try_import_torch
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import sys
import torch
import os
from collections import deque
import time
import pygame
import xml.etree.ElementTree as ET
import re

# Set the CUDA_VISIBLE_DEVICES environment variable to the GPU index of the L4 (e.g., 0)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Replace "0" with the actual index of the L4 GPU based on `nvidia-smi`

pygame.init()
WIDTH, HEIGHT = 1200, 900
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Aircraft Movement on Taxiways")

# Parse the KML file
file_path = "5x5.kml"  # Update this path to your KML file
tree = ET.parse(file_path)
root = tree.getroot()
namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

# Lists to store the taxiways and gates
taxiways = []
gates = []

# Extract LineStrings (taxiways and runways) and Points (gates)
for placemark in root.findall('.//kml:Placemark', namespace):
    line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
    if line_string is not None:
        line_coords = line_string.text.strip().split()
        path = []
        for coord in line_coords:
            lon, lat, _ = map(float, coord.split(','))
            path.append((lon, lat))
        taxiway = {'path': path}
        name = placemark.find('kml:name', namespace)
        if name is not None:
            placemark_name = name.text.strip()
            taxiway['name'] = placemark_name
            match = re.search(r'\b(L1|L2|L3)\b', placemark_name)
            if match:
                taxiway['code'] = match.group(1)
            else:
                taxiway['code'] = ''
            if 'CENTRELINE' in placemark_name.upper():
                taxiway['is_runway'] = True
        taxiways.append(taxiway)
    point = placemark.find('.//kml:Point/kml:coordinates', namespace)
    if point is not None:
        coord = point.text.strip().split(',')
        lon, lat, _ = map(float, coord)
        gates.append({'position': (lon, lat)})

# Find the bounds of all coordinates
all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
all_gate_coords = [gate['position'] for gate in gates]
all_coords = all_taxiway_coords + all_gate_coords

lon_min = min(coord[0] for coord in all_coords)
lon_max = max(coord[0] for coord in all_coords)
lat_min = min(coord[1] for coord in all_coords)
lat_max = max(coord[1] for coord in all_coords)

margin = 0.05
lon_range = lon_max - lon_min
lat_range = lat_max - lat_min
lon_min -= lon_range * margin
lon_max += lon_range * margin
lat_min -= lat_range * margin
lat_max += lat_range * margin

def convert_coords(lon, lat):
    x = (lon - lon_min) / (lon_max - lon_min) * WIDTH
    y = HEIGHT - (lat - lat_min) / (lat_max - lat_min) * HEIGHT
    return pygame.math.Vector2(x, y)

for taxiway in taxiways:
    pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
    taxiway['pixel_path'] = pixel_path

for gate in gates:
    gate['pixel_position'] = convert_coords(*gate['position'])

def distance(p1, p2):
    return (p1 - p2).length()

G = nx.Graph()
node_id_counter = 0
node_positions = {}
for idx, taxiway in enumerate(taxiways):
    path = taxiway['pixel_path']
    taxiway_name = taxiway.get('name', '')
    taxiway_code = taxiway.get('code', '')
    taxiway_nodes = []
    for i, point in enumerate(path):
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=(point.x, point.y))
        G.nodes[node_id]['taxiway_name'] = taxiway_name
        G.nodes[node_id]['taxiway_code'] = taxiway_code
        if taxiway.get('is_runway'):
            G.nodes[node_id]['is_runway_node'] = True
        node_positions[node_id] = point
        taxiway_nodes.append(node_id)
        if i > 0:
            prev_node_id = taxiway_nodes[i - 1]
            G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
    taxiway['node_ids'] = taxiway_nodes

def connect_taxiway_endpoints():
    CONNECTION_THRESHOLD = 30
    for taxiway1 in taxiways:
        for taxiway2 in taxiways:
            if taxiway1 == taxiway2:
                continue
            endpoints1 = [taxiway1['node_ids'][0], taxiway1['node_ids'][-1]]
            endpoints2 = [taxiway2['node_ids'][0], taxiway2['node_ids'][-1]]
            for node1 in endpoints1:
                for node2 in endpoints2:
                    pos1 = pygame.math.Vector2(G.nodes[node1]['pos'])
                    pos2 = pygame.math.Vector2(G.nodes[node2]['pos'])
                    if distance(pos1, pos2) < CONNECTION_THRESHOLD:
                        if not G.has_edge(node1, node2):
                            G.add_edge(node1, node2, weight=distance(pos1, pos2))

connect_taxiway_endpoints()

def connect_runways_to_taxiways():
    CONNECTION_THRESHOLD = 30
    for runway in [t for t in taxiways if t.get('is_runway')]:
        for taxiway in [t for t in taxiways if not t.get('is_runway')]:
            for runway_node in runway['node_ids']:
                for taxiway_node in taxiway['node_ids']:
                    pos_runway = pygame.math.Vector2(G.nodes[runway_node]['pos'])
                    pos_taxiway = pygame.math.Vector2(G.nodes[taxiway_node]['pos'])
                    if distance(pos_runway, pos_taxiway) < CONNECTION_THRESHOLD:
                        if not G.has_edge(runway_node, taxiway_node):
                            G.add_edge(runway_node, taxiway_node, weight=distance(pos_runway, pos_taxiway))

connect_runways_to_taxiways()

flipped_positions = {node: (pos[0], -pos[1]) for node, pos in node_positions.items()}

# Ensure all edges have a weight of 1
for edge in G.edges():
    G[edge[0]][edge[1]]['weight'] = 1

# Custom Multi-Agent Environment for Shortest Path Finding (RLlib-compatible)
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, graph, num_agents=3):
        super().__init__()
        self.graph = graph
        self.total_agents = num_agents
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}

        # Use Discrete spaces to represent each agent's current node in the graph
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        nodes = np.array(list(self.graph.nodes)).flatten()
        for agent in self.agents:
            self.pos[agent] = np.random.choice(nodes)
            self.distance_travelled[agent] = 0
        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}  # Return observations as a dictionary
        return obs, {}

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        # Move each agent
        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            # Ensure next_node is a valid neighbor of the current node
            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += nx.get_edge_attributes(self.graph, 'weight').get((current_node, next_node), 1)
                rewards[agent] = -0.1  # Small negative reward to encourage shorter paths  # Encourage shorter paths

        # Detect collisions
        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 5  # Reduced penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 10
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        # Update done flags for all agents
        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True  # Mark as truncated to properly handle episode end

        # Check if all agents are done
        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}  # Return observations as a dictionary
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}  # Update infos to match the current observation keys

        return obs, rewards, dones, truncateds, infos

def render_pygame(env):
    screen.fill((255, 255, 255))  # Fill background with white

    # Draw taxiways
    for taxiway in taxiways:
        pixel_path = taxiway['pixel_path']
        if len(pixel_path) > 1:
            pygame.draw.lines(screen, (0, 0, 0), False, [(point.x, point.y) for point in pixel_path], 2)

    # Draw nodes
    for node in env.graph.nodes:
        pos = env.graph.nodes[node]['pos']
        pygame.draw.circle(screen, (0, 0, 255), (int(pos[0]), int(pos[1])), 5)

    # Draw agents
    colors = [(255, 0, 0), (0, 255, 0), (128, 0, 128)]
    for idx, agent in enumerate(env.agents):
        if env.pos[agent] is not None:
            pos = env.graph.nodes[env.pos[agent]]['pos']
            pygame.draw.circle(screen, colors[idx % len(colors)], (int(pos[0]), int(pos[1])), 10)

    pygame.display.flip()  # Update the display

# Adjust training config and PPO code accordingly

# Create environment
env = RoadIntersectionEnv(G, num_agents=3)

# RLlib Training Configuration with fixed typo
ray.init(ignore_reinit_error=True, num_gpus=1, log_to_driver=True)

from ray.tune.registry import register_env

def env_creator(env_config):
    return RoadIntersectionEnv(env_config['graph'], env_config['num_agents'])

register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

def policy_mapping_fn(agent_id, *args, **kwargs):
    return "shared_policy"

config = {
    "rllib_version": "2.38",
    "env": "RoadIntersectionEnv",
    "env_config": {
        "graph": G,
        "num_agents": 3
    },
    "framework": "torch",  # Switch to PyTorch framework
    "num_workers": 7,  # Adjust number of workers to utilize available CPU cores
    "num_envs_per_worker": 80,  # Set environments per worker to balance CPU usage
    "num_gpus": 0,  # Specify that GPU should be used
    "train_batch_size": 8000,  # Increased batch size for more data per update
    "sgd_minibatch_size": 128,  # Increase minibatch size for training
    "lr": 1e-4,  # Reduced learning rate for stability
    "gamma": 0.99,  # Discount factor for reward
    "log_level": "DEBUG",
    "multiagent": {
        "policies": {
            "shared_policy": (None, env.observation_space, env.action_space, {})
        },
        "policy_mapping_fn": policy_mapping_fn,
        "policies_to_train": ["shared_policy"],
    },
    "exploration_config": {  # Add exploration configuration
        "type": "EpsilonGreedy",
        "initial_epsilon": 1.0,
        "final_epsilon": 0.05,
        "epsilon_timesteps": 20000  # Increased exploration time for better learning
    },
    "monitor": True,  # Enable monitoring for visualization
    "metric": "episode_reward_mean",
    "mode": "max"
}

# Track training progress
rewards_history = deque(maxlen=100)
iterations = []
mean_rewards = []

# Train the model using PPO with more frequent checkpoints
analysis = tune.run(
    "PPO", 
    config=config,
    reuse_actors=True, 
    stop={"training_iteration": 25}, 
    verbose=1, 
     storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints",  
    checkpoint_at_end=True,
    checkpoint_freq=5  # Save checkpoints more frequently
)

# Save the model
try:
    print("Available metrics:", analysis.results_df.columns)
    if analysis.trials and analysis.get_best_trial(metric="training_iteration", mode="max") is not None:
        best_trial = analysis.get_best_trial(metric="training_iteration", mode="max")
        best_checkpoint = analysis.get_best_checkpoint(trial=best_trial, metric="training_iteration", mode="max")
    else:
        # Fallback if 'episode_reward_mean' is not available
        best_trial = analysis.get_best_trial(metric="training_iteration", mode="max")
        best_checkpoint = analysis.get_best_checkpoint(trial=best_trial, metric="training_iteration", mode="max")

    if best_checkpoint is not None:
        print(f"Best checkpoint: {best_checkpoint}")

        # Use the trained model
        obs = env.reset()[0]
        trainer = PPO(env="RoadIntersectionEnv", config=config)
        trainer.restore(best_checkpoint)

        done = {agent: False for agent in env.agents}
        done['__all__'] = False

        should_render = True  # Change to True to visualize

        while not done['__all__']:
            actions = {agent: trainer.compute_single_action(obs[agent], policy_id="shared_policy", explore=True) for agent in env.agents if not done[agent]}
            obs, rewards, done, truncateds, infos = env.step(actions)
            
            if should_render:
                render_pygame(env)

            # Track rewards for visualization
            episode_reward = sum(rewards.values())
            rewards_history.append(episode_reward)
            iterations.append(len(iterations) + 1)
            mean_reward = np.mean(rewards_history)
            mean_rewards.append(mean_reward)

        # # Plot training progress
        # plt.plot(iterations, mean_rewards)
        # plt.xlabel('Training Iteration')
        # plt.ylabel('Mean Episode Reward (last 100 episodes)')
        # plt.title('Training Progress')
        # plt.grid()
        # plt.show()
    else:
        print("No valid checkpoint found. Unable to restore the model.")
except KeyError as e:
    print(f"KeyError encountered: {e}. Unable to retrieve the required metric.")
    if best_checkpoint is not None:
        print(f"Best checkpoint: {best_checkpoint}")

        # Use the trained model
        obs = env.reset()[0]
        trainer = PPO(config=config)
        trainer.restore(best_checkpoint)

        done = {agent: False for agent in env.agents}
        done['__all__'] = False

        should_render = True  # Change to True to visualize

        while not done['__all__']:
            actions = {agent: trainer.compute_single_action(obs[agent], policy_id="shared_policy") for agent in env.agents if not done[agent]}
            obs, rewards, done, truncateds, info = env.step(actions)
            
            if should_render:
                render_pygame(env)

            # Track rewards for visualization
            episode_reward = sum(rewards.values())
            rewards_history.append(episode_reward)
            iterations.append(len(iterations) + 1)
            mean_reward = np.mean(rewards_history)
            mean_rewards.append(mean_reward)

        # # Plot training progress
        # plt.plot(iterations, mean_rewards)
        # plt.xlabel('Training Iteration')
        # plt.ylabel('Mean Episode Reward (last 100 episodes)')
        # plt.title('Training Progress')
        # plt.grid()
        # plt.show()
    else:
        print("No valid checkpoint found. Unable to restore the model.")
else:
    print("No valid trials found. Unable to retrieve the best checkpoint.")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-11-26 23:21:57</td></tr>
# <tr><td>Running for: </td><td>00:18:31.18        </td></tr>
# <tr><td>Memory:      </td><td>15.2/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 8.0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status    </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_8ae45_00000</td><td>TERMINATED</td><td>127.0.0.1:30884</td><td style="text-align: right;">    25</td><td style="text-align: right;">         1056.93</td><td style="text-align: right;">200000</td><td style="text-align: right;">                    7</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-11-26 23:03:26,139	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (PPO pid=30884) 2024-11-26 23:03:41,640	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (RolloutWorker pid=28932) 2024-11-26 23:04:03,286	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy
# (RolloutWorker pid=28932) 2024-11-26 23:04:03,287	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x000001F80D7BC590>: Discrete(14) -> (14,)
# (RolloutWorker pid=28932) 2024-11-26 23:04:03,314	INFO policy.py:1243 -- Policy (worker=2) running on CPU.
# (RolloutWorker pid=28932) 2024-11-26 23:04:03,314	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices.
# (RolloutWorker pid=28932) 2024-11-26 23:04:07,737	INFO util.py:118 -- Using connectors:
# (RolloutWorker pid=28932) 2024-11-26 23:04:07,738	INFO util.py:119 --     AgentConnectorPipeline
# (RolloutWorker pid=28932)         ObsPreprocessorConnector
# (RolloutWorker pid=28932)         StateBufferConnector
# (RolloutWorker pid=28932)         ViewRequirementAgentConnector
# (RolloutWorker pid=28932) 2024-11-26 23:04:07,738	INFO util.py:120 --     ActionConnectorPipeline
# (RolloutWorker pid=28932)         ConvertToNumpyConnector
# (RolloutWorker pid=28932)         NormalizeActionsConnector
# (RolloutWorker pid=28932)         ImmutableActionsConnector
# (RolloutWorker pid=8452) 2024-11-26 23:04:05,372	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy [repeated 3x across cluster]
# (RolloutWorker pid=8452) 2024-11-26 23:04:05,372	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x000001C28D304BF0>: Discrete(14) -> (14,) [repeated 3x across cluster]
# (RolloutWorker pid=8452) 2024-11-26 23:04:05,396	INFO policy.py:1243 -- Policy (worker=4) running on CPU. [repeated 3x across cluster]
# (RolloutWorker pid=8452) 2024-11-26 23:04:05,396	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices. [repeated 3x across cluster]
# (RolloutWorker pid=4076) 2024-11-26 23:04:12,868	INFO util.py:118 -- Using connectors: [repeated 4x across cluster]
# (RolloutWorker pid=4076) 2024-11-26 23:04:12,868	INFO util.py:119 --     AgentConnectorPipeline [repeated 4x across cluster]
# (RolloutWorker pid=4076)         ObsPreprocessorConnector [repeated 4x across cluster]
# (RolloutWorker pid=4076)         StateBufferConnector [repeated 4x across cluster]
# (RolloutWorker pid=4076)         ViewRequirementAgentConnector [repeated 4x across cluster]
# (RolloutWorker pid=4076) 2024-11-26 23:04:12,868	INFO util.py:120 --     ActionConnectorPipeline [repeated 4x across cluster]
# (RolloutWorker pid=4076)         ConvertToNumpyConnector [repeated 4x across cluster]
# (RolloutWorker pid=4076)         NormalizeActionsConnector [repeated 4x across cluster]
# (RolloutWorker pid=4076)         ImmutableActionsConnector [repeated 4x across cluster]
# (RolloutWorker pid=28176) 2024-11-26 23:04:12,365	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy [repeated 3x across cluster]
# (RolloutWorker pid=28176) 2024-11-26 23:04:12,366	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x000002070D796F90>: Discrete(14) -> (14,) [repeated 3x across cluster]
# (RolloutWorker pid=28176) 2024-11-26 23:04:12,386	INFO policy.py:1243 -- Policy (worker=6) running on CPU. [repeated 3x across cluster]
# (RolloutWorker pid=28176) 2024-11-26 23:04:12,386	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices. [repeated 3x across cluster]
# (PPO pid=30884) 2024-11-26 23:04:15,526	INFO env_runner_group.py:314 -- Inferred observation/action spaces from remote worker (local worker has no env): {'shared_policy': (Discrete(14), Discrete(14)), '__env__': (Discrete(14), Discrete(14))}
# (PPO pid=30884) 2024-11-26 23:04:15,550	INFO policy.py:1243 -- Policy (worker=local) running on CPU.
# (PPO pid=30884) 2024-11-26 23:04:18,616	INFO rollout_worker.py:1748 -- Built policy map: <PolicyMap lru-caching-capacity=100 policy-IDs=['shared_policy']>
# (PPO pid=30884) 2024-11-26 23:04:18,616	INFO rollout_worker.py:1749 -- Built preprocessor map: {'shared_policy': None}
# (PPO pid=30884) 2024-11-26 23:04:18,616	INFO rollout_worker.py:545 -- Built filter map: defaultdict(<class 'ray.rllib.utils.filter.NoFilter'>, {})
# (PPO pid=30884) Trainable.setup took 36.193 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=30884) Install gputil for GPU system monitoring.
# (PPO pid=30884) 2024-11-26 23:04:18,615	INFO util.py:118 -- Using connectors: [repeated 3x across cluster]
# (PPO pid=30884) 2024-11-26 23:04:18,615	INFO util.py:119 --     AgentConnectorPipeline [repeated 3x across cluster]
# (PPO pid=30884)         ObsPreprocessorConnector [repeated 3x across cluster]
# (PPO pid=30884)         StateBufferConnector [repeated 3x across cluster]
# (PPO pid=30884)         ViewRequirementAgentConnector [repeated 3x across cluster]
# (PPO pid=30884) 2024-11-26 23:04:18,616	INFO util.py:120 --     ActionConnectorPipeline [repeated 3x across cluster]
# (PPO pid=30884)         ConvertToNumpyConnector [repeated 3x across cluster]
# (PPO pid=30884)         NormalizeActionsConnector [repeated 3x across cluster]
# (PPO pid=30884)         ImmutableActionsConnector [repeated 3x across cluster]
# (RolloutWorker pid=30896) 2024-11-26 23:04:18,652	INFO rollout_worker.py:674 -- Generating sample batch of size 1200
# (RolloutWorker pid=30896) 2024-11-26 23:04:20,954	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896) { 'count': 1200,
# (RolloutWorker pid=30896)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((2880, 14), dtype=float32, min=-0.006, max=0.007, mean=-0.0),
# (RolloutWorker pid=30896)                                          'action_logp': np.ndarray((2880,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'actions': np.ndarray((2880,), dtype=int64, min=0.0, max=13.0, mean=6.578),
# (RolloutWorker pid=30896)                                          'advantages': np.ndarray((2880,), dtype=float32, min=-20.003, max=0.001, mean=-0.06),
# (RolloutWorker pid=30896)                                          'agent_index': np.ndarray((2880,), dtype=int32, min=0.0, max=2.0, mean=0.971),
# (RolloutWorker pid=30896)                                          'eps_id': np.ndarray((2880,), dtype=int64, min=1.0014521123449044e+16, max=9.783664255354723e+17, mean=4.63595608592406e+17),
# (RolloutWorker pid=30896)                                          'infos': np.ndarray((2880,), dtype=object, head={}),
# (RolloutWorker pid=30896)                                          'new_obs': np.ndarray((2880, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'obs': np.ndarray((2880, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'rewards': np.ndarray((2880,), dtype=float64, min=-20.0, max=0.0, mean=-0.018),
# (RolloutWorker pid=30896)                                          't': np.ndarray((2880,), dtype=int32, min=0.0, max=14.0, mean=6.828),
# (RolloutWorker pid=30896)                                          'terminateds': np.ndarray((2880,), dtype=bool, min=0.0, max=1.0, mean=0.001),
# (RolloutWorker pid=30896)                                          'truncateds': np.ndarray((2880,), dtype=bool, min=0.0, max=1.0, mean=0.001),
# (RolloutWorker pid=30896)                                          'unroll_id': np.ndarray((2880,), dtype=int32, min=3.0, max=485.0, mean=247.1),
# (RolloutWorker pid=30896)                                          'value_targets': np.ndarray((2880,), dtype=float32, min=-20.0, max=0.004, mean=-0.059),
# (RolloutWorker pid=30896)                                          'values_bootstrapped': np.ndarray((2880,), dtype=float32, min=-0.004, max=0.004, mean=0.001),
# (RolloutWorker pid=30896)                                          'vf_preds': np.ndarray((2880,), dtype=float32, min=-0.004, max=0.004, mean=0.001)}},
# (RolloutWorker pid=30896)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=30896)
# (PPO pid=30884) 2024-11-26 23:04:15,530	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy
# (PPO pid=30884) 2024-11-26 23:04:15,530	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x0000029B916A9310>: Discrete(14) -> (14,)
# (PPO pid=30884) 2024-11-26 23:04:15,550	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices.
# (PPO pid=30884) 2024-11-26 23:04:20,985	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (PPO pid=30884) 2024-11-26 23:04:20,987	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:04:21,000	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=30884)
# (PPO pid=30884) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=30884)                      'diff_num_grad_updates_vs_sampler_policy': 0,
# (PPO pid=30884)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=30884)                                         'cur_kl_coeff': 0.2,
# (PPO pid=30884)                                         'cur_lr': 0.0001,
# (PPO pid=30884)                                         'entropy': 2.639054536819458,
# (PPO pid=30884)                                         'entropy_coeff': 0.0,
# (PPO pid=30884)                                         'grad_gnorm': 0.17191116511821747,
# (PPO pid=30884)                                         'kl': 5.116591637488455e-06,
# (PPO pid=30884)                                         'policy_loss': 0.0785980373620987,
# (PPO pid=30884)                                         'total_loss': 0.08888532966375351,
# (PPO pid=30884)                                         'vf_explained_var': -0.0015801191329956055,
# (PPO pid=30884)                                         'vf_loss': 0.010286281816661358},
# (PPO pid=30884)                      'model': {},
# (PPO pid=30884)                      'num_agent_steps_trained': 128,
# (PPO pid=30884)                      'num_grad_updates_lifetime': 1}}
# (PPO pid=30884)
# (RolloutWorker pid=30896) 2024-11-26 23:05:48,736	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896) { 'count': 1200, [repeated 2x across cluster]
# (RolloutWorker pid=30896)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((2730, 14), dtype=float32, min=-0.73, max=3.087, mean=-0.113), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'action_logp': np.ndarray((2730,), dtype=float32, min=0.0, max=0.0, mean=0.0), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'actions': np.ndarray((2730,), dtype=int64, min=0.0, max=13.0, mean=7.934), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'advantages': np.ndarray((2730,), dtype=float32, min=-0.195, max=0.013, mean=0.002), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'agent_index': np.ndarray((2730,), dtype=int32, min=0.0, max=2.0, mean=0.967), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'eps_id': np.ndarray((2730,), dtype=int64, min=1.0014521123449044e+16, max=9.783664255354723e+17, mean=4.5790655497816506e+17), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'infos': np.ndarray((2730,), dtype=object, head={}), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'new_obs': np.ndarray((2730, 14), dtype=float32, min=0.0, max=1.0, mean=0.071), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'obs': np.ndarray((2730, 14), dtype=float32, min=0.0, max=1.0, mean=0.071), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'rewards': np.ndarray((2730,), dtype=float64, min=-0.1, max=0.0, mean=-0.0), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          't': np.ndarray((2730,), dtype=int32, min=29.0, max=44.0, mean=36.984), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'terminateds': np.ndarray((2730,), dtype=bool, min=0.0, max=0.0, mean=0.0), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'truncateds': np.ndarray((2730,), dtype=bool, min=0.0, max=0.0, mean=0.0), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'unroll_id': np.ndarray((2730,), dtype=int32, min=668.0, max=849.0, mean=758.5), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'value_targets': np.ndarray((2730,), dtype=float32, min=-0.245, max=-0.035, mean=-0.053), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'values_bootstrapped': np.ndarray((2730,), dtype=float32, min=-0.097, max=-0.04, mean=-0.055), [repeated 2x across cluster]
# (RolloutWorker pid=30896)                                          'vf_preds': np.ndarray((2730,), dtype=float32, min=-0.097, max=-0.04, mean=-0.055)}}, [repeated 2x across cluster]
# (RolloutWorker pid=30896)   'type': 'MultiAgentBatch'} [repeated 2x across cluster]
# (PPO pid=30884) 2024-11-26 23:06:03,888	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:06:03,898	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=30884)
# (PPO pid=30884) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=30884)                      'diff_num_grad_updates_vs_sampler_policy': 1607.0,
# (PPO pid=30884)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=30884)                                         'cur_kl_coeff': 0.15000000000000002,
# (PPO pid=30884)                                         'cur_lr': 0.0001,
# (PPO pid=30884)                                         'entropy': 1.340993881225586,
# (PPO pid=30884)                                         'entropy_coeff': 0.0,
# (PPO pid=30884)                                         'grad_gnorm': 0.09910693019628525,
# (PPO pid=30884)                                         'kl': 0.08211483061313629,
# (PPO pid=30884)                                         'policy_loss': 0.10223075747489929,
# (PPO pid=30884)                                         'total_loss': 0.11506196111440659,
# (PPO pid=30884)                                         'vf_explained_var': 0.24407440423965454,
# (PPO pid=30884)                                         'vf_loss': 0.0005139923305250704},
# (PPO pid=30884)                      'model': {},
# (PPO pid=30884)                      'num_agent_steps_trained': 128,
# (PPO pid=30884)                      'num_grad_updates_lifetime': 10158}}
# (PPO pid=30884)
# (PPO pid=30884) { 'count': 128,
# (PPO pid=30884)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-0.73, max=3.087, mean=-0.121),
# (PPO pid=30884)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=8.242),
# (PPO pid=30884)                                          'advantages': np.ndarray((128,), dtype=float32, min=-8.492, max=0.624, mean=-0.144),
# (PPO pid=30884)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.016),
# (PPO pid=30884)                                          'eps_id': np.ndarray((128,), dtype=int64, min=6867870192362660.0, max=9.963899446681144e+17, mean=4.699189906402371e+17),
# (PPO pid=30884)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=30884)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'rewards': np.ndarray((128,), dtype=float64, min=-0.1, max=0.0, mean=-0.001),
# (PPO pid=30884)                                          't': np.ndarray((128,), dtype=int32, min=28.0, max=44.0, mean=35.023),
# (PPO pid=30884)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=653.0, max=853.0, mean=755.289),
# (PPO pid=30884)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.19, max=-0.035, mean=-0.056),
# (PPO pid=30884)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.097, max=-0.04, mean=-0.056),
# (PPO pid=30884)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.097, max=-0.04, mean=-0.056)}},
# (PPO pid=30884)   'type': 'MultiAgentBatch'}
# (PPO pid=30884) 2024-11-26 23:06:04,295	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=30896) 2024-11-26 23:06:27,797	INFO rollout_worker.py:674 -- Generating sample batch of size 1200
# 2024-11-26 23:07:08,398	WARNING util.py:201 -- The `on_step_begin` operation took 0.760 s, which may be a performance bottleneck.
# 2024-11-26 23:07:19,378	WARNING util.py:201 -- The `on_step_begin` operation took 0.937 s, which may be a performance bottleneck.
# (PPO pid=30884) 2024-11-26 23:07:27,767	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=30884)
# (PPO pid=30884) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=30884)                      'diff_num_grad_updates_vs_sampler_policy': 1316.0,
# (PPO pid=30884)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=30884)                                         'cur_kl_coeff': 0.22500000000000003,
# (PPO pid=30884)                                         'cur_lr': 0.0001,
# (PPO pid=30884)                                         'entropy': 1.132731556892395,
# (PPO pid=30884)                                         'entropy_coeff': 0.0,
# (PPO pid=30884)                                         'grad_gnorm': 0.0753234326839447,
# (PPO pid=30884)                                         'kl': 0.003985738381743431,
# (PPO pid=30884)                                         'policy_loss': -0.007780078798532486,
# (PPO pid=30884)                                         'total_loss': -0.006687043234705925,
# (PPO pid=30884)                                         'vf_explained_var': 0.44689124822616577,
# (PPO pid=30884)                                         'vf_loss': 0.00019625312415882945},
# (PPO pid=30884)                      'model': {},
# (PPO pid=30884)                      'num_agent_steps_trained': 128,
# (PPO pid=30884)                      'num_grad_updates_lifetime': 18087}}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:07:27,768	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884) { 'count': 128,
# (PPO pid=30884)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-0.953, max=4.06, mean=-0.144),
# (PPO pid=30884)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.312),
# (PPO pid=30884)                                          'advantages': np.ndarray((128,), dtype=float32, min=-12.173, max=0.751, mean=-0.171),
# (PPO pid=30884)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.086),
# (PPO pid=30884)                                          'eps_id': np.ndarray((128,), dtype=int64, min=3491272858787319.0, max=9.875437841417112e+17, mean=4.931155642141497e+17),
# (PPO pid=30884)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=30884)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'rewards': np.ndarray((128,), dtype=float64, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          't': np.ndarray((128,), dtype=int32, min=56.0, max=73.0, mean=63.25),
# (PPO pid=30884)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=976.0, max=1217.0, mean=1102.125),
# (PPO pid=30884)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.238, max=-0.035, mean=-0.053),
# (PPO pid=30884)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.088, max=-0.04, mean=-0.052),
# (PPO pid=30884)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.088, max=-0.037, mean=-0.052)}},
# (PPO pid=30884)   'type': 'MultiAgentBatch'}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:07:28,220	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (PPO pid=30884) Checkpoint successfully created at: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_23-03-25/PPO_RoadIntersectionEnv_8ae45_00000_0_2024-11-26_23-03-26/checkpoint_000000)
# (RolloutWorker pid=30896) 2024-11-26 23:07:58,132	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896) { 'count': 1200,
# (RolloutWorker pid=30896)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((2702, 14), dtype=float32, min=-1.013, max=4.493, mean=-0.16),
# (RolloutWorker pid=30896)                                          'action_logp': np.ndarray((2702,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'actions': np.ndarray((2702,), dtype=int64, min=0.0, max=13.0, mean=7.915),
# (RolloutWorker pid=30896)                                          'advantages': np.ndarray((2702,), dtype=float32, min=-0.139, max=0.013, mean=0.0),
# (RolloutWorker pid=30896)                                          'agent_index': np.ndarray((2702,), dtype=int32, min=0.0, max=2.0, mean=0.972),
# (RolloutWorker pid=30896)                                          'eps_id': np.ndarray((2702,), dtype=int64, min=1.0014521123449044e+16, max=9.783664255354723e+17, mean=4.5534416372582976e+17),
# (RolloutWorker pid=30896)                                          'infos': np.ndarray((2702,), dtype=object, head={}),
# (RolloutWorker pid=30896)                                          'new_obs': np.ndarray((2702, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'obs': np.ndarray((2702, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'rewards': np.ndarray((2702,), dtype=float64, min=-0.1, max=0.0, mean=-0.001),
# (RolloutWorker pid=30896)                                          't': np.ndarray((2702,), dtype=int32, min=74.0, max=89.0, mean=81.978),
# (RolloutWorker pid=30896)                                          'terminateds': np.ndarray((2702,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'truncateds': np.ndarray((2702,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'unroll_id': np.ndarray((2702,), dtype=int32, min=1214.0, max=1395.0, mean=1304.189),
# (RolloutWorker pid=30896)                                          'value_targets': np.ndarray((2702,), dtype=float32, min=-0.187, max=-0.035, mean=-0.051),
# (RolloutWorker pid=30896)                                          'values_bootstrapped': np.ndarray((2702,), dtype=float32, min=-0.088, max=-0.041, mean=-0.051),
# (RolloutWorker pid=30896)                                          'vf_preds': np.ndarray((2702,), dtype=float32, min=-0.088, max=-0.04, mean=-0.051)}},
# (RolloutWorker pid=30896)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=30896)
# 2024-11-26 23:08:20,572	WARNING util.py:201 -- The `on_step_begin` operation took 0.736 s, which may be a performance bottleneck.
# (RolloutWorker pid=30896) 2024-11-26 23:08:37,940	INFO rollout_worker.py:674 -- Generating sample batch of size 1200
# (PPO pid=30884) 2024-11-26 23:08:54,651	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884) { 'count': 128,
# (PPO pid=30884)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-1.137, max=5.206, mean=-0.143),
# (PPO pid=30884)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.281),
# (PPO pid=30884)                                          'advantages': np.ndarray((128,), dtype=float32, min=-6.511, max=0.671, mean=-0.003),
# (PPO pid=30884)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.062),
# (PPO pid=30884)                                          'eps_id': np.ndarray((128,), dtype=int64, min=6867870192362660.0, max=9.910614595648321e+17, mean=4.304117358438209e+17),
# (PPO pid=30884)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=30884)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'rewards': np.ndarray((128,), dtype=float64, min=-0.1, max=0.0, mean=-0.001),
# (PPO pid=30884)                                          't': np.ndarray((128,), dtype=int32, min=84.0, max=104.0, mean=92.938),
# (PPO pid=30884)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=1309.0, max=1593.0, mean=1441.094),
# (PPO pid=30884)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.149, max=-0.034, mean=-0.05),
# (PPO pid=30884)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.088, max=-0.039, mean=-0.05),
# (PPO pid=30884)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.088, max=-0.039, mean=-0.05)}},
# (PPO pid=30884)   'type': 'MultiAgentBatch'}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:08:54,659	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=30884)
# (PPO pid=30884) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=30884)                      'diff_num_grad_updates_vs_sampler_policy': 1465.0,
# (PPO pid=30884)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=30884)                                         'cur_kl_coeff': 0.11250000000000002,
# (PPO pid=30884)                                         'cur_lr': 0.0001,
# (PPO pid=30884)                                         'entropy': 0.9744647145271301,
# (PPO pid=30884)                                         'entropy_coeff': 0.0,
# (PPO pid=30884)                                         'grad_gnorm': 0.07377324998378754,
# (PPO pid=30884)                                         'kl': 0.007921787910163403,
# (PPO pid=30884)                                         'policy_loss': 0.014550145715475082,
# (PPO pid=30884)                                         'total_loss': 0.01568637602031231,
# (PPO pid=30884)                                         'vf_explained_var': 0.346666157245636,
# (PPO pid=30884)                                         'vf_loss': 0.00024503187160007656},
# (PPO pid=30884)                      'model': {},
# (PPO pid=30884)                      'num_agent_steps_trained': 128,
# (PPO pid=30884)                      'num_grad_updates_lifetime': 26426}}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:08:54,978	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=30896) 2024-11-26 23:10:01,675	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896) { 'count': 1200,
# (RolloutWorker pid=30896)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((2700, 14), dtype=float32, min=-1.214, max=6.223, mean=-0.208),
# (RolloutWorker pid=30896)                                          'action_logp': np.ndarray((2700,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'actions': np.ndarray((2700,), dtype=int64, min=0.0, max=13.0, mean=7.762),
# (RolloutWorker pid=30896)                                          'advantages': np.ndarray((2700,), dtype=float32, min=-0.223, max=0.016, mean=0.001),
# (RolloutWorker pid=30896)                                          'agent_index': np.ndarray((2700,), dtype=int32, min=0.0, max=2.0, mean=0.972),
# (RolloutWorker pid=30896)                                          'eps_id': np.ndarray((2700,), dtype=int64, min=1.0014521123449044e+16, max=9.783664255354723e+17, mean=4.5515910213538336e+17),
# (RolloutWorker pid=30896)                                          'infos': np.ndarray((2700,), dtype=object, head={}),
# (RolloutWorker pid=30896)                                          'new_obs': np.ndarray((2700, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'obs': np.ndarray((2700, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'rewards': np.ndarray((2700,), dtype=float64, min=-0.1, max=0.0, mean=-0.0),
# (RolloutWorker pid=30896)                                          't': np.ndarray((2700,), dtype=int32, min=119.0, max=134.0, mean=126.983),
# (RolloutWorker pid=30896)                                          'terminateds': np.ndarray((2700,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'truncateds': np.ndarray((2700,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'unroll_id': np.ndarray((2700,), dtype=int32, min=1756.0, max=1935.0, mean=1845.5),
# (RolloutWorker pid=30896)                                          'value_targets': np.ndarray((2700,), dtype=float32, min=-0.277, max=-0.03, mean=-0.047),
# (RolloutWorker pid=30896)                                          'values_bootstrapped': np.ndarray((2700,), dtype=float32, min=-0.084, max=-0.035, mean=-0.048),
# (RolloutWorker pid=30896)                                          'vf_preds': np.ndarray((2700,), dtype=float32, min=-0.085, max=-0.035, mean=-0.048)}},
# (RolloutWorker pid=30896)   'type': 'MultiAgentBatch'}
# (PPO pid=30884) 2024-11-26 23:10:19,565	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884) { 'count': 128,
# (PPO pid=30884)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-1.214, max=6.223, mean=-0.246),
# (PPO pid=30884)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.938),
# (PPO pid=30884)                                          'advantages': np.ndarray((128,), dtype=float32, min=-6.282, max=0.85, mean=0.067),
# (PPO pid=30884)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=0.891),
# (PPO pid=30884)                                          'eps_id': np.ndarray((128,), dtype=int64, min=1.4643100037963776e+16, max=9.963899446681144e+17, mean=4.896995716647396e+17),
# (PPO pid=30884)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=30884)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'rewards': np.ndarray((128,), dtype=float64, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          't': np.ndarray((128,), dtype=int32, min=112.0, max=134.0, mean=121.438),
# (PPO pid=30884)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=1636.0, max=1926.0, mean=1793.664),
# (PPO pid=30884)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.156, max=-0.03, mean=-0.047),
# (PPO pid=30884)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.084, max=-0.035, mean=-0.049),
# (PPO pid=30884)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.085, max=-0.035, mean=-0.05)}},
# (PPO pid=30884)   'type': 'MultiAgentBatch'}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:10:19,574	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=30884)
# (PPO pid=30884) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=30884)                      'diff_num_grad_updates_vs_sampler_policy': 1891.0,
# (PPO pid=30884)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=30884)                                         'cur_kl_coeff': 0.16875,
# (PPO pid=30884)                                         'cur_lr': 0.0001,
# (PPO pid=30884)                                         'entropy': 0.8217059373855591,
# (PPO pid=30884)                                         'entropy_coeff': 0.0,
# (PPO pid=30884)                                         'grad_gnorm': 0.07285072654485703,
# (PPO pid=30884)                                         'kl': 0.016494020819664,
# (PPO pid=30884)                                         'policy_loss': -0.06635389477014542,
# (PPO pid=30884)                                         'total_loss': -0.06339939683675766,
# (PPO pid=30884)                                         'vf_explained_var': 0.4263368844985962,
# (PPO pid=30884)                                         'vf_loss': 0.00017113477224484086},
# (PPO pid=30884)                      'model': {},
# (PPO pid=30884)                      'num_agent_steps_trained': 128,
# (PPO pid=30884)                      'num_grad_updates_lifetime': 34982}}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:10:20,781	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=30896) 2024-11-26 23:10:43,838	INFO rollout_worker.py:674 -- Generating sample batch of size 1200
# (PPO pid=30884) Checkpoint successfully created at: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_23-03-25/PPO_RoadIntersectionEnv_8ae45_00000_0_2024-11-26_23-03-26/checkpoint_000001)
# (PPO pid=30884) 2024-11-26 23:11:41,068	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884) { 'count': 128,
# (PPO pid=30884)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-1.358, max=7.032, mean=-0.187),
# (PPO pid=30884)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.891),
# (PPO pid=30884)                                          'advantages': np.ndarray((128,), dtype=float32, min=-5.279, max=0.582, mean=0.07),
# (PPO pid=30884)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=0.922),
# (PPO pid=30884)                                          'eps_id': np.ndarray((128,), dtype=int64, min=7873646899109241.0, max=9.963899446681144e+17, mean=4.640671187741805e+17),
# (PPO pid=30884)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=30884)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'rewards': np.ndarray((128,), dtype=float64, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          't': np.ndarray((128,), dtype=int32, min=140.0, max=164.0, mean=149.492),
# (PPO pid=30884)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=1964.0, max=2324.0, mean=2136.773),
# (PPO pid=30884)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.155, max=-0.032, mean=-0.046),
# (PPO pid=30884)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.083, max=-0.037, mean=-0.048),
# (PPO pid=30884)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.083, max=-0.035, mean=-0.048)}},
# (PPO pid=30884)   'type': 'MultiAgentBatch'}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:11:41,078	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=30884)
# (PPO pid=30884) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=30884)                      'diff_num_grad_updates_vs_sampler_policy': 1257.0,
# (PPO pid=30884)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=30884)                                         'cur_kl_coeff': 0.16875,
# (PPO pid=30884)                                         'cur_lr': 0.0001,
# (PPO pid=30884)                                         'entropy': 0.7556722164154053,
# (PPO pid=30884)                                         'entropy_coeff': 0.0,
# (PPO pid=30884)                                         'grad_gnorm': 0.07663973420858383,
# (PPO pid=30884)                                         'kl': 0.00664014695212245,
# (PPO pid=30884)                                         'policy_loss': -0.061505962163209915,
# (PPO pid=30884)                                         'total_loss': -0.06017892062664032,
# (PPO pid=30884)                                         'vf_explained_var': 0.35380351543426514,
# (PPO pid=30884)                                         'vf_loss': 0.0002065100852632895},
# (PPO pid=30884)                      'model': {},
# (PPO pid=30884)                      'num_agent_steps_trained': 128,
# (PPO pid=30884)                      'num_grad_updates_lifetime': 42448}}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:11:41,921	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=30896) 2024-11-26 23:12:10,819	INFO rollout_worker.py:716 -- Completed sample batch:
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896)
# (RolloutWorker pid=30896) { 'count': 1200,
# (RolloutWorker pid=30896)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((2700, 14), dtype=float32, min=-1.511, max=7.337, mean=-0.228),
# (RolloutWorker pid=30896)                                          'action_logp': np.ndarray((2700,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'actions': np.ndarray((2700,), dtype=int64, min=0.0, max=13.0, mean=7.92),
# (RolloutWorker pid=30896)                                          'advantages': np.ndarray((2700,), dtype=float32, min=-0.109, max=0.012, mean=0.0),
# (RolloutWorker pid=30896)                                          'agent_index': np.ndarray((2700,), dtype=int32, min=0.0, max=2.0, mean=0.972),
# (RolloutWorker pid=30896)                                          'eps_id': np.ndarray((2700,), dtype=int64, min=1.0014521123449044e+16, max=9.783664255354723e+17, mean=4.5515910213538336e+17),
# (RolloutWorker pid=30896)                                          'infos': np.ndarray((2700,), dtype=object, head={}),
# (RolloutWorker pid=30896)                                          'new_obs': np.ndarray((2700, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'obs': np.ndarray((2700, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'rewards': np.ndarray((2700,), dtype=float64, min=-0.1, max=0.0, mean=-0.0),
# (RolloutWorker pid=30896)                                          't': np.ndarray((2700,), dtype=int32, min=164.0, max=179.0, mean=171.983),
# (RolloutWorker pid=30896)                                          'terminateds': np.ndarray((2700,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'truncateds': np.ndarray((2700,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'unroll_id': np.ndarray((2700,), dtype=int32, min=2296.0, max=2475.0, mean=2385.5),
# (RolloutWorker pid=30896)                                          'value_targets': np.ndarray((2700,), dtype=float32, min=-0.176, max=-0.03, mean=-0.047),
# (RolloutWorker pid=30896)                                          'values_bootstrapped': np.ndarray((2700,), dtype=float32, min=-0.082, max=-0.035, mean=-0.047),
# (RolloutWorker pid=30896)                                          'vf_preds': np.ndarray((2700,), dtype=float32, min=-0.083, max=-0.035, mean=-0.047)}},
# (RolloutWorker pid=30896)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=30896) 2024-11-26 23:12:52,820	INFO rollout_worker.py:674 -- Generating sample batch of size 1200
# (PPO pid=30884) 2024-11-26 23:13:07,886	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884) { 'count': 128,
# (PPO pid=30884)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-1.58, max=7.484, mean=-0.268),
# (PPO pid=30884)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=7.742),
# (PPO pid=30884)                                          'advantages': np.ndarray((128,), dtype=float32, min=-6.141, max=0.666, mean=0.122),
# (PPO pid=30884)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=0.906),
# (PPO pid=30884)                                          'eps_id': np.ndarray((128,), dtype=int64, min=3491272858787319.0, max=9.963899446681144e+17, mean=4.626021915709207e+17),
# (PPO pid=30884)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# ...
# (RolloutWorker pid=30896)                                          'eps_id': np.ndarray((2670,), dtype=int64, min=1.0014521123449044e+16, max=9.783664255354723e+17, mean=4.569320191667709e+17),
# (RolloutWorker pid=30896)                                          'infos': np.ndarray((2670,), dtype=object, head={}),
# (RolloutWorker pid=30896)                                          'new_obs': np.ndarray((2670, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'obs': np.ndarray((2670, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (RolloutWorker pid=30896)                                          'rewards': np.ndarray((2670,), dtype=float64, min=-0.1, max=0.0, mean=-0.0),
# (RolloutWorker pid=30896)                                          't': np.ndarray((2670,), dtype=int32, min=344.0, max=359.0, mean=351.983),
# (RolloutWorker pid=30896)                                          'terminateds': np.ndarray((2670,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'truncateds': np.ndarray((2670,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (RolloutWorker pid=30896)                                          'unroll_id': np.ndarray((2670,), dtype=int32, min=4456.0, max=4633.0, mean=4544.5),
# (RolloutWorker pid=30896)                                          'value_targets': np.ndarray((2670,), dtype=float32, min=-0.144, max=-0.028, mean=-0.042),
# (RolloutWorker pid=30896)                                          'values_bootstrapped': np.ndarray((2670,), dtype=float32, min=-0.066, max=-0.033, mean=-0.043),
# (RolloutWorker pid=30896)                                          'vf_preds': np.ndarray((2670,), dtype=float32, min=-0.067, max=-0.033, mean=-0.043)}},
# (RolloutWorker pid=30896)   'type': 'MultiAgentBatch'}
# (RolloutWorker pid=30896) 2024-11-26 23:21:16,198	INFO rollout_worker.py:674 -- Generating sample batch of size 1200
# (PPO pid=30884) 2024-11-26 23:21:34,412	INFO rollout_worker.py:793 -- Training on concatenated sample batches:
# (PPO pid=30884)
# (PPO pid=30884) { 'count': 128,
# (PPO pid=30884)   'policy_batches': { 'shared_policy': { 'action_dist_inputs': np.ndarray((128, 14), dtype=float32, min=-2.348, max=7.21, mean=-0.346),
# (PPO pid=30884)                                          'action_logp': np.ndarray((128,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'actions': np.ndarray((128,), dtype=int64, min=0.0, max=13.0, mean=8.016),
# (PPO pid=30884)                                          'advantages': np.ndarray((128,), dtype=float32, min=-4.716, max=0.668, mean=0.122),
# (PPO pid=30884)                                          'agent_index': np.ndarray((128,), dtype=int32, min=0.0, max=2.0, mean=1.016),
# (PPO pid=30884)                                          'eps_id': np.ndarray((128,), dtype=int64, min=7873646899109241.0, max=9.996436452976248e+17, mean=5.339742966605534e+17),
# (PPO pid=30884)                                          'infos': np.ndarray((128,), dtype=object, head={}),
# (PPO pid=30884)                                          'new_obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'obs': np.ndarray((128, 14), dtype=float32, min=0.0, max=1.0, mean=0.071),
# (PPO pid=30884)                                          'rewards': np.ndarray((128,), dtype=float64, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          't': np.ndarray((128,), dtype=int32, min=336.0, max=374.0, mean=348.539),
# (PPO pid=30884)                                          'terminateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'truncateds': np.ndarray((128,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (PPO pid=30884)                                          'unroll_id': np.ndarray((128,), dtype=int32, min=4243.0, max=4872.0, mean=4535.352),
# (PPO pid=30884)                                          'value_targets': np.ndarray((128,), dtype=float32, min=-0.139, max=-0.028, mean=-0.04),
# (PPO pid=30884)                                          'values_bootstrapped': np.ndarray((128,), dtype=float32, min=-0.064, max=-0.032, mean=-0.042),
# (PPO pid=30884)                                          'vf_preds': np.ndarray((128,), dtype=float32, min=-0.066, max=-0.032, mean=-0.042)}},
# (PPO pid=30884)   'type': 'MultiAgentBatch'}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:21:34,420	DEBUG rollout_worker.py:832 -- Training out:
# (PPO pid=30884)
# (PPO pid=30884) { 'shared_policy': { 'custom_metrics': {},
# (PPO pid=30884)                      'diff_num_grad_updates_vs_sampler_policy': 1663.0,
# (PPO pid=30884)                      'learner_stats': { 'allreduce_latency': 0.0,
# (PPO pid=30884)                                         'cur_kl_coeff': 0.18984375000000003,
# (PPO pid=30884)                                         'cur_lr': 0.0001,
# (PPO pid=30884)                                         'entropy': 0.549807071685791,
# (PPO pid=30884)                                         'entropy_coeff': 0.0,
# (PPO pid=30884)                                         'grad_gnorm': 0.043947700411081314,
# (PPO pid=30884)                                         'kl': 0.005970540922135115,
# (PPO pid=30884)                                         'policy_loss': -0.10084858536720276,
# (PPO pid=30884)                                         'total_loss': -0.09965987503528595,
# (PPO pid=30884)                                         'vf_explained_var': 0.6280758380889893,
# (PPO pid=30884)                                         'vf_loss': 5.5243428505491465e-05},
# (PPO pid=30884)                      'model': {},
# (PPO pid=30884)                      'num_agent_steps_trained': 128,
# (PPO pid=30884)                      'num_grad_updates_lifetime': 99164}}
# (PPO pid=30884)
# (PPO pid=30884) 2024-11-26 23:21:35,015	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# 2024-11-26 23:21:57,312	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_23-03-25' in 0.0281s.
# (PPO pid=30884) Checkpoint successfully created at: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_23-03-25/PPO_RoadIntersectionEnv_8ae45_00000_0_2024-11-26_23-03-26/checkpoint_000004)
# 2024-11-26 23:21:57,530	INFO tune.py:1041 -- Total run time: 1112.34 seconds (1111.15 seconds for the tuning loop).
# 2024-11-26 23:21:57,612	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# 2024-11-26 23:21:57,622	WARNING deprecation.py:50 -- DeprecationWarning: `algo = Algorithm(env='RoadIntersectionEnv', ...)` has been deprecated. Use `algo = AlgorithmConfig().environment('RoadIntersectionEnv').build()` instead. This will raise an error in the future!
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:568: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# Available metrics: Index(['num_healthy_workers', 'num_in_flight_async_sample_reqs',
#        'num_remote_worker_restarts', 'num_agent_steps_sampled',
#        'num_agent_steps_trained', 'num_env_steps_sampled',
#        'num_env_steps_trained', 'num_env_steps_sampled_this_iter',
#        'num_env_steps_trained_this_iter',
#        'num_env_steps_sampled_throughput_per_sec',
#        ...
#        'info/learner/shared_policy/learner_stats/grad_gnorm',
#        'info/learner/shared_policy/learner_stats/cur_kl_coeff',
#        'info/learner/shared_policy/learner_stats/cur_lr',
#        'info/learner/shared_policy/learner_stats/total_loss',
#        'info/learner/shared_policy/learner_stats/policy_loss',
#        'info/learner/shared_policy/learner_stats/vf_loss',
#        'info/learner/shared_policy/learner_stats/vf_explained_var',
#        'info/learner/shared_policy/learner_stats/kl',
#        'info/learner/shared_policy/learner_stats/entropy',
#        'info/learner/shared_policy/learner_stats/entropy_coeff'],
#       dtype='object', length=339)
# Best checkpoint: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_23-03-25/PPO_RoadIntersectionEnv_8ae45_00000_0_2024-11-26_23-03-26/checkpoint_000004)
# (RolloutWorker pid=33028) 2024-11-26 23:22:09,636	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy
# (RolloutWorker pid=33028) 2024-11-26 23:22:09,637	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x000002508D607C80>: Discrete(14) -> (14,)
# (RolloutWorker pid=33028) 2024-11-26 23:22:09,653	INFO policy.py:1243 -- Policy (worker=2) running on CPU.
# (RolloutWorker pid=33028) 2024-11-26 23:22:09,654	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices.
# (RolloutWorker pid=33028) 2024-11-26 23:22:13,888	INFO util.py:118 -- Using connectors:
# (RolloutWorker pid=33028) 2024-11-26 23:22:13,888	INFO util.py:119 --     AgentConnectorPipeline
# (RolloutWorker pid=33028)         ObsPreprocessorConnector
# (RolloutWorker pid=33028)         StateBufferConnector
# (RolloutWorker pid=33028)         ViewRequirementAgentConnector
# (RolloutWorker pid=33028) 2024-11-26 23:22:13,888	INFO util.py:120 --     ActionConnectorPipeline
# (RolloutWorker pid=33028)         ConvertToNumpyConnector
# (RolloutWorker pid=33028)         NormalizeActionsConnector
# (RolloutWorker pid=33028)         ImmutableActionsConnector
# (RolloutWorker pid=17140) 2024-11-26 23:22:14,220	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy [repeated 6x across cluster]
# (RolloutWorker pid=17140) 2024-11-26 23:22:14,220	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x000001DCEF79FCB0>: Discrete(14) -> (14,) [repeated 6x across cluster]
# (RolloutWorker pid=17140) 2024-11-26 23:22:14,243	INFO policy.py:1243 -- Policy (worker=7) running on CPU. [repeated 6x across cluster]
# (RolloutWorker pid=17140) 2024-11-26 23:22:14,244	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices. [repeated 6x across cluster]
# 2024-11-26 23:22:17,532	INFO env_runner_group.py:314 -- Inferred observation/action spaces from remote worker (local worker has no env): {'shared_policy': (Discrete(14), Discrete(14)), '__env__': (Discrete(14), Discrete(14))}
# 2024-11-26 23:22:17,534	DEBUG rollout_worker.py:1767 -- Creating policy for shared_policy
# 2024-11-26 23:22:17,536	DEBUG catalog.py:705 -- Created preprocessor <ray.rllib.models.preprocessors.OneHotPreprocessor object at 0x00000276AED4BA10>: Discrete(14) -> (14,)
# 2024-11-26 23:22:17,557	INFO policy.py:1243 -- Policy (worker=local) running on CPU.
# 2024-11-26 23:22:17,558	INFO torch_policy_v2.py:108 -- Found 0 visible cuda devices.
# 2024-11-26 23:22:20,843	INFO util.py:118 -- Using connectors:
# 2024-11-26 23:22:20,844	INFO util.py:119 --     AgentConnectorPipeline
#         ObsPreprocessorConnector
#         StateBufferConnector
#         ViewRequirementAgentConnector
# 2024-11-26 23:22:20,845	INFO util.py:120 --     ActionConnectorPipeline
#         ConvertToNumpyConnector
#         NormalizeActionsConnector
#         ImmutableActionsConnector
# 2024-11-26 23:22:20,846	INFO rollout_worker.py:1748 -- Built policy map: <PolicyMap lru-caching-capacity=100 policy-IDs=['shared_policy']>
# 2024-11-26 23:22:20,847	INFO rollout_worker.py:1749 -- Built preprocessor map: {'shared_policy': None}
# 2024-11-26 23:22:20,847	INFO rollout_worker.py:545 -- Built filter map: defaultdict(<class 'ray.rllib.utils.filter.NoFilter'>, {})
# 2024-11-26 23:22:20,850	INFO trainable.py:161 -- Trainable.setup took 23.201 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-26 23:22:20,856	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# 2024-11-26 23:22:20,907	DEBUG policy.py:1000 -- restoring agent connectors:
# 2024-11-26 23:22:20,908	DEBUG policy.py:1001 --     AgentConnectorPipeline
#         ObsPreprocessorConnector
#         StateBufferConnector
#         ViewRequirementAgentConnector
# 2024-11-26 23:22:20,910	DEBUG policy.py:1006 -- restoring action connectors:
# 2024-11-26 23:22:20,911	DEBUG policy.py:1007 --     ActionConnectorPipeline
#         ConvertToNumpyConnector
#         NormalizeActionsConnector
#         ImmutableActionsConnector
# 2024-11-26 23:22:20,966	INFO trainable.py:583 -- Restored on 127.0.0.1 from checkpoint: Checkpoint(filesystem=local, path=D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-26_23-03-25/PPO_RoadIntersectionEnv_8ae45_00000_0_2024-11-26_23-03-26/checkpoint_000004)
# (RolloutWorker pid=33028) 2024-11-26 23:22:20,941	DEBUG policy.py:1000 -- restoring agent connectors:
# (RolloutWorker pid=33028) 2024-11-26 23:22:20,942	DEBUG policy.py:1001 --     AgentConnectorPipeline
# (RolloutWorker pid=33028) 2024-11-26 23:22:20,942	DEBUG policy.py:1006 -- restoring action connectors:
# (RolloutWorker pid=33028) 2024-11-26 23:22:20,942	DEBUG policy.py:1007 --     ActionConnectorPipeline
# (RolloutWorker pid=17140) 2024-11-26 23:22:17,516	INFO util.py:118 -- Using connectors: [repeated 6x across cluster]
# (RolloutWorker pid=17140) 2024-11-26 23:22:17,516	INFO util.py:119 --     AgentConnectorPipeline [repeated 6x across cluster]
# (RolloutWorker pid=33028)         ObsPreprocessorConnector [repeated 7x across cluster]
# (RolloutWorker pid=33028)         StateBufferConnector [repeated 7x across cluster]
# (RolloutWorker pid=33028)         ViewRequirementAgentConnector [repeated 7x across cluster]
# (RolloutWorker pid=17140) 2024-11-26 23:22:17,516	INFO util.py:120 --     ActionConnectorPipeline [repeated 6x across cluster]
# (RolloutWorker pid=33028)         ConvertToNumpyConnector [repeated 7x across cluster]
# (RolloutWorker pid=33028)         NormalizeActionsConnector [repeated 7x across cluster]
# (RolloutWorker pid=33028)         ImmutableActionsConnector [repeated 7x across cluster]

# %% [markdown]
# # Training well, ray tune used, renders at end

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.utils.framework import try_import_torch
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import sys
import torch
import os
from collections import deque
import time
import pygame
import xml.etree.ElementTree as ET
import re

# Set the CUDA_VISIBLE_DEVICES environment variable to the GPU index of the L4 (e.g., 0)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Replace "0" with the actual index of the L4 GPU based on `nvidia-smi`

pygame.init()
WIDTH, HEIGHT = 1200, 900
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Aircraft Movement on Taxiways")

# Parse the KML file
file_path = "reduced_nodes.kml"  # Update this path to your KML file
tree = ET.parse(file_path)
root = tree.getroot()
namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

# Lists to store the taxiways and gates
taxiways = []
gates = []

# Extract LineStrings (taxiways and runways) and Points (gates)
for placemark in root.findall('.//kml:Placemark', namespace):
    line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
    if line_string is not None:
        line_coords = line_string.text.strip().split()
        path = []
        for coord in line_coords:
            lon, lat, _ = map(float, coord.split(','))
            path.append((lon, lat))
        taxiway = {'path': path}
        name = placemark.find('kml:name', namespace)
        if name is not None:
            placemark_name = name.text.strip()
            taxiway['name'] = placemark_name
            match = re.search(r'\b(L1|L2|L3)\b', placemark_name)
            if match:
                taxiway['code'] = match.group(1)
            else:
                taxiway['code'] = ''
            if 'CENTRELINE' in placemark_name.upper():
                taxiway['is_runway'] = True
        taxiways.append(taxiway)
    point = placemark.find('.//kml:Point/kml:coordinates', namespace)
    if point is not None:
        coord = point.text.strip().split(',')
        lon, lat, _ = map(float, coord)
        gates.append({'position': (lon, lat)})

# Find the bounds of all coordinates
all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
all_gate_coords = [gate['position'] for gate in gates]
all_coords = all_taxiway_coords + all_gate_coords

lon_min = min(coord[0] for coord in all_coords)
lon_max = max(coord[0] for coord in all_coords)
lat_min = min(coord[1] for coord in all_coords)
lat_max = max(coord[1] for coord in all_coords)

margin = 0.05
lon_range = lon_max - lon_min
lat_range = lat_max - lat_min
lon_min -= lon_range * margin
lon_max += lon_range * margin
lat_min -= lat_range * margin
lat_max += lat_range * margin

def convert_coords(lon, lat):
    x = (lon - lon_min) / (lon_max - lon_min) * WIDTH
    y = HEIGHT - (lat - lat_min) / (lat_max - lat_min) * HEIGHT
    return pygame.math.Vector2(x, y)

for taxiway in taxiways:
    pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
    taxiway['pixel_path'] = pixel_path

for gate in gates:
    gate['pixel_position'] = convert_coords(*gate['position'])

def distance(p1, p2):
    return (p1 - p2).length()

G = nx.Graph()
node_id_counter = 0
node_positions = {}
for idx, taxiway in enumerate(taxiways):
    path = taxiway['pixel_path']
    taxiway_name = taxiway.get('name', '')
    taxiway_code = taxiway.get('code', '')
    taxiway_nodes = []
    for i, point in enumerate(path):
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=(point.x, point.y))
        G.nodes[node_id]['taxiway_name'] = taxiway_name
        G.nodes[node_id]['taxiway_code'] = taxiway_code
        if taxiway.get('is_runway'):
            G.nodes[node_id]['is_runway_node'] = True
        node_positions[node_id] = point
        taxiway_nodes.append(node_id)
        if i > 0:
            prev_node_id = taxiway_nodes[i - 1]
            G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
    taxiway['node_ids'] = taxiway_nodes

def connect_taxiway_endpoints():
    CONNECTION_THRESHOLD = 30
    for taxiway1 in taxiways:
        for taxiway2 in taxiways:
            if taxiway1 == taxiway2:
                continue
            endpoints1 = [taxiway1['node_ids'][0], taxiway1['node_ids'][-1]]
            endpoints2 = [taxiway2['node_ids'][0], taxiway2['node_ids'][-1]]
            for node1 in endpoints1:
                for node2 in endpoints2:
                    pos1 = pygame.math.Vector2(G.nodes[node1]['pos'])
                    pos2 = pygame.math.Vector2(G.nodes[node2]['pos'])
                    if distance(pos1, pos2) < CONNECTION_THRESHOLD:
                        if not G.has_edge(node1, node2):
                            G.add_edge(node1, node2, weight=distance(pos1, pos2))

connect_taxiway_endpoints()

def connect_runways_to_taxiways():
    CONNECTION_THRESHOLD = 30
    for runway in [t for t in taxiways if t.get('is_runway')]:
        for taxiway in [t for t in taxiways if not t.get('is_runway')]:
            for runway_node in runway['node_ids']:
                for taxiway_node in taxiway['node_ids']:
                    pos_runway = pygame.math.Vector2(G.nodes[runway_node]['pos'])
                    pos_taxiway = pygame.math.Vector2(G.nodes[taxiway_node]['pos'])
                    if distance(pos_runway, pos_taxiway) < CONNECTION_THRESHOLD:
                        if not G.has_edge(runway_node, taxiway_node):
                            G.add_edge(runway_node, taxiway_node, weight=distance(pos_runway, pos_taxiway))

connect_runways_to_taxiways()

flipped_positions = {node: (pos[0], -pos[1]) for node, pos in node_positions.items()}

# Ensure all edges have a weight of 1
for edge in G.edges():
    G[edge[0]][edge[1]]['weight'] = 1

# Predefined gates and runway endpoints for agents to start and end
gate_coordinates = [
    (77.71046165300096, 13.20355775032989),
    (77.71066072998956, 13.20166801620613),
    (77.70315360361252, 13.20165318995302),
    (77.71305689010458, 13.201637816132),
    (77.70195813939766, 13.20169406641297),
    (77.71149825860202, 13.20165032306983),
    (77.72279066770344, 13.19968338101175),
    (77.7132055646255, 13.20167917723071),
    (77.7089924860226, 13.20357466411958),
    (77.71648635375834, 13.20336974504588)
]

runway_endpoints = [
    (77.68686735208298, 13.20718308006773),
    (77.7222951686759, 13.20687066472886),
    (77.69060216489893, 13.18975920793089),
    (77.72642499411846, 13.18944676842937)
]

# Add nodes for gates and runway endpoints to the graph
for gate_coord in gate_coordinates:
    gate_pixel_position = convert_coords(*gate_coord)
    node_id = node_id_counter
    node_id_counter += 1
    G.add_node(node_id, pos=(gate_pixel_position.x, gate_pixel_position.y), is_gate=True)
    node_positions[node_id] = gate_pixel_position

for runway_coord in runway_endpoints:
    runway_pixel_position = convert_coords(*runway_coord)
    node_id = node_id_counter
    node_id_counter += 1
    G.add_node(node_id, pos=(runway_pixel_position.x, runway_pixel_position.y), is_runway_endpoint=True)
    node_positions[node_id] = runway_pixel_position

# Custom Multi-Agent Environment for Shortest Path Finding (RLlib-compatible)
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, graph, num_agents=3):
        super().__init__()
        self.graph = graph
        self.total_agents = num_agents
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}

        # Use Discrete spaces to represent each agent's current node in the graph
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        # Randomly assign starting positions from gates and runway endpoints
        available_nodes = [node for node, data in self.graph.nodes(data=True) if data.get('is_gate') or data.get('is_runway_endpoint')]
        for agent in self.agents:
            self.pos[agent] = np.random.choice(available_nodes)
            self.distance_travelled[agent] = 0
        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}  # Return observations as a dictionary
        return obs, {}

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        # Move each agent
        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            # Ensure next_node is a valid neighbor of the current node
            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += nx.get_edge_attributes(self.graph, 'weight').get((current_node, next_node), 1)
                rewards[agent] = -0.1  # Small negative reward to encourage shorter paths  # Encourage shorter paths

        # Detect collisions
        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 5  # Reduced penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 10
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        # Update done flags for all agents
        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True  # Mark as truncated to properly handle episode end

        # Check if all agents are done
        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}  # Return observations as a dictionary
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}  # Update infos to match the current observation keys

        return obs, rewards, dones, truncateds, infos

def render_pygame(env):
    screen.fill((255, 255, 255))  # Fill background with white

    # Draw taxiways
    for taxiway in taxiways:
        pixel_path = taxiway['pixel_path']
        if len(pixel_path) > 1:
            pygame.draw.lines(screen, (0, 0, 0), False, [(point.x, point.y) for point in pixel_path], 2)

    # Draw nodes
    for node in env.graph.nodes:
        pos = env.graph.nodes[node]['pos']
        pygame.draw.circle(screen, (0, 0, 255), (int(pos[0]), int(pos[1])), 5)

    # Draw agents
    colors = [(255, 0, 0), (0, 255, 0), (128, 0, 128)]
    for idx, agent in enumerate(env.agents):
        if env.pos[agent] is not None:
            pos = env.graph.nodes[env.pos[agent]]['pos']
            pygame.draw.circle(screen, colors[idx % len(colors)], (int(pos[0]), int(pos[1])), 10)

    pygame.display.flip()  # Update the display

# Adjust training config and PPO code accordingly

# Create environment
env = RoadIntersectionEnv(G, num_agents=3)

# RLlib Training Configuration with fixed typo
ray.init(ignore_reinit_error=True, num_gpus=1, log_to_driver=True)

from ray.tune.registry import register_env

def env_creator(env_config):
    return RoadIntersectionEnv(env_config['graph'], env_config['num_agents'])

register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

def policy_mapping_fn(agent_id, *args, **kwargs):
    return "shared_policy"

config = {
    "rllib_version": "2.38",
    "env": "RoadIntersectionEnv",
    "env_config": {
        "graph": G,
        "num_agents": 3
    },
    "framework": "torch",  # Switch to PyTorch framework
    "num_workers": 8,  # Adjust number of workers to utilize available CPU cores
    "num_envs_per_worker": 8,  # Set environments per worker to balance CPU usage
    "num_gpus": 1,  # Specify that GPU should be used
    "train_batch_size": 8000,  # Increased batch size for more data per update
    "sgd_minibatch_size": 128,  # Increase minibatch size for training
    "lr": 1e-2,  # Reduced learning rate for stability
    "gamma": 0.5,  # Discount factor for reward
    "log_level": "WARN",
    "multiagent": {
        "policies": {
            "shared_policy": (None, env.observation_space, env.action_space, {})
        },
        "policy_mapping_fn": policy_mapping_fn,
        "policies_to_train": ["shared_policy"],
    },
   
    "monitor": True,  # Enable monitoring for visualization
    "metric": "episode_reward_mean",
    "mode": "max"
}

# Track training progress
rewards_history = deque(maxlen=100)
iterations = []
mean_rewards = []

# Train the model using PPO with more frequent checkpoints
analysis = tune.run(
    "PPO", 
    config=config,
    reuse_actors=True, 
    stop={"training_iteration": 5}, 
    verbose=1, 
    storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/", 
    checkpoint_at_end=True,
    checkpoint_freq=1  # Save checkpoints more frequently
)

# Save the model
try:
    print("Available metrics:", analysis.results_df.columns)
    if analysis.trials and analysis.get_best_trial(metric="training_iteration", mode="max") is not None:
        best_trial = analysis.get_best_trial(metric="training_iteration", mode="max")
        best_checkpoint = analysis.get_best_checkpoint(trial=best_trial, metric="training_iteration", mode="max")
    else:
        # Fallback if 'episode_reward_mean' is not available
        best_trial = analysis.get_best_trial(metric="training_iteration", mode="max")
        best_checkpoint = analysis.get_best_checkpoint(trial=best_trial, metric="training_iteration", mode="max")

    if best_checkpoint is not None:
        print(f"Best checkpoint: {best_checkpoint}")

        # Use the trained model
        obs = env.reset()[0]
        trainer = PPO(env="RoadIntersectionEnv", config=config)
        trainer.restore(best_checkpoint)

        done = {agent: False for agent in env.agents}
        done['__all__'] = False

        should_render = True  # Change to True to visualize

        while not done['__all__']:
            actions = {agent: trainer.compute_single_action(obs[agent], policy_id="shared_policy", explore=True) for agent in env.agents if not done[agent]}
            obs, rewards, done, truncateds, infos = env.step(actions)
            
            if should_render:
                render_pygame(env)

            # Track rewards for visualization
            episode_reward = sum(rewards.values())
            rewards_history.append(episode_reward)
            iterations.append(len(iterations) + 1)
            mean_reward = np.mean(rewards_history)
            mean_rewards.append(mean_reward)

        # # Plot training progress
        # plt.plot(iterations, mean_rewards)
        # plt.xlabel('Training Iteration')
        # plt.ylabel('Mean Episode Reward (last 100 episodes)')
        # plt.title('Training Progress')
        # plt.grid()
        # plt.show()
    else:
        print("No valid checkpoint found. Unable to restore the model.")
except KeyError as e:
    print(f"KeyError encountered: {e}. Unable to retrieve the required metric.")
    if best_checkpoint is not None:
        print(f"Best checkpoint: {best_checkpoint}")

        # Use the trained model
        obs = env.reset()[0]
        trainer = PPO(config=config)
        trainer.restore(best_checkpoint)

        done = {agent: False for agent in env.agents}
        done['__all__'] = False

        should_render = True  # Change to True to visualize

        while not done['__all__']:
            actions = {agent: trainer.compute_single_action(obs[agent], policy_id="shared_policy") for agent in env.agents if not done[agent]}
            obs, rewards, done, truncateds, info = env.step(actions)
            
            if should_render:
                render_pygame(env)

            # Track rewards for visualization
            episode_reward = sum(rewards.values())
            rewards_history.append(episode_reward)
            iterations.append(len(iterations) + 1)
            mean_reward = np.mean(rewards_history)
            mean_rewards.append(mean_reward)

        # # Plot training progress
        # plt.plot(iterations, mean_rewards)
        # plt.xlabel('Training Iteration')
        # plt.ylabel('Mean Episode Reward (last 100 episodes)')
        # plt.title('Training Progress')
        # plt.grid()
        # plt.show()
    else:
        print("No valid checkpoint found. Unable to restore the model.")
else:
    print("No valid trials found. Unable to retrieve the best checkpoint.")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-11-29 00:00:21</td></tr>
# <tr><td>Running for: </td><td>00:00:34.96        </td></tr>
# <tr><td>Memory:      </td><td>18.0/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 9.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_be994_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-11-28 23:59:46,608	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (PPO pid=33084) 2024-11-29 00:00:02,064	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# 2024-11-29 00:00:21,528	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-11-29 00:00:21,556	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-28_23-59-46' in 0.0257s.
# 2024-11-29 00:00:31,579	INFO tune.py:1041 -- Total run time: 45.25 seconds (34.93 seconds for the tuning loop).
# 2024-11-29 00:00:31,581	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
# 2024-11-29 00:00:31,600	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 1 trial(s):
# - PPO_RoadIntersectionEnv_be994_00000: FileNotFoundError('Could not fetch metrics for PPO_RoadIntersectionEnv_be994_00000: both result.json and progress.csv were not found at D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-28_23-59-46/PPO_RoadIntersectionEnv_be994_00000_0_2024-11-28_23-59-46')
# 2024-11-29 00:00:31,616	ERROR experiment_analysis.py:467 -- No checkpoints have been found for trial PPO_RoadIntersectionEnv_be994_00000.
# Available metrics: Index([], dtype='object')
# No valid checkpoint found. Unable to restore the model.
# No valid trials found. Unable to retrieve the best checkpoint.

# %% [markdown]
# # Code w/o ray tune, live training plotting apparently

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO, PPOConfig
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import sys
import os
import pygame
import xml.etree.ElementTree as ET
import re
from collections import deque
import matplotlib.pyplot as plt
import time

# ================================
# Define the Distance Function at the Module Level
# ================================
def distance(p1, p2):
    return (p1 - p2).length()

# ================================
# Set Screen Dimensions (No Pygame Initialization Here)
# ================================
WIDTH, HEIGHT = 1200, 900

# ================================
# Parse the KML File
# ================================
def parse_kml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

    taxiways = []
    gates = []

    for placemark in root.findall('.//kml:Placemark', namespace):
        # Extract LineStrings (taxiways and runways)
        line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
        if line_string is not None:
            line_coords = line_string.text.strip().split()
            path = []
            for coord in line_coords:
                lon, lat, _ = map(float, coord.split(','))
                path.append((lon, lat))
            taxiway = {'path': path}
            name = placemark.find('kml:name', namespace)
            if name is not None:
                placemark_name = name.text.strip()
                taxiway['name'] = placemark_name
                match = re.search(r'\b(L1|L2|L3)\b', placemark_name)
                if match:
                    taxiway['code'] = match.group(1)
                else:
                    taxiway['code'] = ''
                if 'CENTRELINE' in placemark_name.upper():
                    taxiway['is_runway'] = True
            taxiways.append(taxiway)

        # Extract Points (gates)
        point = placemark.find('.//kml:Point/kml:coordinates', namespace)
        if point is not None:
            coord = point.text.strip().split(',')
            lon, lat, _ = map(float, coord)
            gates.append({'position': (lon, lat)})

    return taxiways, gates

# ================================
# Build the NetworkX Graph
# ================================
def build_graph(taxiways, gates, width, height):
    all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
    all_gate_coords = [gate['position'] for gate in gates]
    all_coords = all_taxiway_coords + all_gate_coords

    lon_min = min(coord[0] for coord in all_coords)
    lon_max = max(coord[0] for coord in all_coords)
    lat_min = min(coord[1] for coord in all_coords)
    lat_max = max(coord[1] for coord in all_coords)

    margin = 0.05
    lon_range = lon_max - lon_min
    lat_range = lat_max - lat_min
    lon_min -= lon_range * margin
    lon_max += lon_range * margin
    lat_min -= lat_range * margin
    lat_max += lat_range * margin

    def convert_coords(lon, lat):
        x = (lon - lon_min) / (lon_max - lon_min) * width
        y = height - (lat - lat_min) / (lat_max - lat_min) * height
        return pygame.math.Vector2(x, y)

    for taxiway in taxiways:
        pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
        taxiway['pixel_path'] = pixel_path

    for gate in gates:
        gate['pixel_position'] = convert_coords(*gate['position'])

    G = nx.Graph()
    node_id_counter = 0
    node_positions = {}
    for idx, taxiway in enumerate(taxiways):
        path = taxiway['pixel_path']
        taxiway_name = taxiway.get('name', '')
        taxiway_code = taxiway.get('code', '')
        taxiway_nodes = []
        for i, point in enumerate(path):
            node_id = node_id_counter
            node_id_counter += 1
            G.add_node(node_id, pos=(point.x, point.y))
            G.nodes[node_id]['taxiway_name'] = taxiway_name
            G.nodes[node_id]['taxiway_code'] = taxiway_code
            if taxiway.get('is_runway'):
                G.nodes[node_id]['is_runway_node'] = True
            node_positions[node_id] = point
            taxiway_nodes.append(node_id)
            if i > 0:
                prev_node_id = taxiway_nodes[i - 1]
                G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
        taxiway['node_ids'] = taxiway_nodes

    def connect_taxiway_endpoints(G, taxiways):
        CONNECTION_THRESHOLD = 30
        for taxiway1 in taxiways:
            for taxiway2 in taxiways:
                if taxiway1 == taxiway2:
                    continue
                endpoints1 = [taxiway1['node_ids'][0], taxiway1['node_ids'][-1]]
                endpoints2 = [taxiway2['node_ids'][0], taxiway2['node_ids'][-1]]
                for node1 in endpoints1:
                    for node2 in endpoints2:
                        pos1 = pygame.math.Vector2(G.nodes[node1]['pos'])
                        pos2 = pygame.math.Vector2(G.nodes[node2]['pos'])
                        if distance(pos1, pos2) < CONNECTION_THRESHOLD:
                            if not G.has_edge(node1, node2):
                                G.add_edge(node1, node2, weight=distance(pos1, pos2))

    def connect_runways_to_taxiways(G, taxiways):
        CONNECTION_THRESHOLD = 30
        for runway in [t for t in taxiways if t.get('is_runway')]:
            for taxiway in [t for t in taxiways if not t.get('is_runway')]:
                for runway_node in runway['node_ids']:
                    for taxiway_node in taxiway['node_ids']:
                        pos_runway = pygame.math.Vector2(G.nodes[runway_node]['pos'])
                        pos_taxiway = pygame.math.Vector2(G.nodes[taxiway_node]['pos'])
                        if distance(pos_runway, pos_taxiway) < CONNECTION_THRESHOLD:
                            if not G.has_edge(runway_node, taxiway_node):
                                G.add_edge(runway_node, taxiway_node, weight=distance(pos_runway, pos_taxiway))

    connect_taxiway_endpoints(G, taxiways)
    connect_runways_to_taxiways(G, taxiways)

    flipped_positions = {node: (pos[0], -pos[1]) for node, pos in node_positions.items()}

    # Ensure all edges have a weight of 1
    for edge in G.edges():
        G[edge[0]][edge[1]]['weight'] = 1

    return G, node_positions, convert_coords

# ================================
# Add Predefined Gates and Runway Endpoints
# ================================
def add_predefined_nodes(G, node_positions, gate_coordinates, runway_endpoints, convert_coords, node_id_counter):
    for gate_coord in gate_coordinates:
        gate_pixel_position = convert_coords(*gate_coord)
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=(gate_pixel_position.x, gate_pixel_position.y), is_gate=True)
        node_positions[node_id] = gate_pixel_position

    for runway_coord in runway_endpoints:
        runway_pixel_position = convert_coords(*runway_coord)
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=(runway_pixel_position.x, runway_pixel_position.y), is_runway_endpoint=True)
        node_positions[node_id] = runway_pixel_position

    return G, node_positions, node_id_counter

# ================================
# Custom Multi-Agent Environment
# ================================
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, config):
        super().__init__()
        self.graph = config["graph"]
        self.total_agents = config["num_agents"]
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}

        # Use Discrete spaces to represent each agent's current node in the graph
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        # Randomly assign starting positions from gates and runway endpoints
        available_nodes = [node for node, data in self.graph.nodes(data=True) if data.get('is_gate') or data.get('is_runway_endpoint')]
        for agent in self.agents:
            self.pos[agent] = np.random.choice(available_nodes)
            self.distance_travelled[agent] = 0
        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}  # Return observations as a dictionary
        return obs, {}

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        # Move each agent
        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            # Ensure next_node is a valid neighbor of the current node
            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += self.graph[current_node][next_node]['weight']
                rewards[agent] = -0.1  # Small negative reward to encourage shorter paths
            else:
                # Invalid action, penalize the agent
                rewards[agent] -= 1

        # Detect collisions
        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 5  # Penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 5
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        # Update done flags for all agents
        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True  # Mark as truncated to properly handle episode end

        # Check if all agents are done
        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}  # Return observations as a dictionary
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}  # Update infos to match the current observation keys

        return obs, rewards, dones, truncateds, infos

    def render(self, mode='human'):
        # Get the current screen
        screen = pygame.display.get_surface()
        if screen is None:
            return

        screen.fill((255, 255, 255))  # Fill background with white

        # Draw taxiways
        for taxiway in taxiways:
            pixel_path = taxiway['pixel_path']
            if len(pixel_path) > 1:
                pygame.draw.lines(screen, (0, 0, 0), False, [(point.x, point.y) for point in pixel_path], 2)

        # Draw nodes
        for node in self.graph.nodes:
            pos = self.graph.nodes[node]['pos']
            pygame.draw.circle(screen, (0, 0, 255), (int(pos[0]), int(pos[1])), 5)

        # Draw agents
        colors = [(255, 0, 0), (0, 255, 0), (128, 0, 128)]
        for idx, agent in enumerate(self.agents):
            if self.pos[agent] is not None:
                pos = self.graph.nodes[self.pos[agent]]['pos']
                pygame.draw.circle(screen, colors[idx % len(colors)], (int(pos[0]), int(pos[1])), 10)

        pygame.display.flip()  # Update the display

# ================================
# Main Function
# ================================
def main():
    # Include global variables required by the environment
    global taxiways

    # ================================
    # Parse KML and Build Graph
    # ================================
    file_path = "reduced_nodes.kml"  # Update this path to your KML file
    taxiways, gates = parse_kml(file_path)
    G, node_positions, convert_coords = build_graph(taxiways, gates, WIDTH, HEIGHT)

    # Predefined gates and runway endpoints for agents to start and end
    gate_coordinates = [
        (77.71046165300096, 13.20355775032989),
        (77.71066072998956, 13.20166801620613),
        (77.70315360361252, 13.20165318995302),
        (77.71305689010458, 13.201637816132),
        (77.70195813939766, 13.20169406641297),
        (77.71149825860202, 13.20165032306983),
        (77.72279066770344, 13.19968338101175),
        (77.7132055646255, 13.20167917723071),
        (77.7089924860226, 13.20357466411958),
        (77.71648635375834, 13.20336974504588)
    ]

    runway_endpoints = [
        (77.68686735208298, 13.20718308006773),
        (77.7222951686759, 13.20687066472886),
        (77.69060216489893, 13.18975920793089),
        (77.72642499411846, 13.18944676842937)
    ]

    # Add predefined gates and runway endpoints to the graph
    node_id_counter = len(G.nodes())
    G, node_positions, node_id_counter = add_predefined_nodes(
        G, node_positions, gate_coordinates, runway_endpoints,
        convert_coords=convert_coords,
        node_id_counter=node_id_counter
    )

    # ================================
    # Initialize Ray
    # ================================
    ray.init(ignore_reinit_error=True, log_to_driver=True)

    # ================================
    # Register the Environment
    # ================================
    from ray.tune.registry import register_env

    def env_creator(env_config):
        return RoadIntersectionEnv(env_config)

    register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

    # ================================
    # Define Policy Mapping Function
    # ================================
    def policy_mapping_fn(agent_id, *args, **kwargs):
        return "shared_policy"

    # ================================
    # RLlib Training Configuration
    # ================================
    temp_env = RoadIntersectionEnv({"graph": G, "num_agents": 3})

    config = {
        "env": "RoadIntersectionEnv",
        "env_config": {
            "graph": G,
            "num_agents": 3
        },
        "framework": "torch",
        "num_workers": 0,  # Run in the main thread for rendering
        "num_envs_per_worker": 1,
        "num_gpus": 0,  # Set to 1 if you have a GPU and want to use it
        "train_batch_size": 4000,
        "sgd_minibatch_size": 128,
        "lr": 1e-3,
        "gamma": 0.99,
        "log_level": "WARN",
        "multiagent": {
            "policies": {
                "shared_policy": (None, temp_env.observation_space, temp_env.action_space, {})
            },
            "policy_mapping_fn": policy_mapping_fn,
            "policies_to_train": ["shared_policy"],
        },
    }

    # ================================
    # Initialize Pygame (Moved Here)
    # ================================
    pygame.init()
    screen = pygame.display.set_mode((WIDTH, HEIGHT))
    pygame.display.set_caption("Aircraft Movement on Taxiways")

    # ================================
    # Create the PPO Trainer
    # ================================
    ppo_config = PPOConfig().environment(
        env="RoadIntersectionEnv",
        env_config=config["env_config"],
    ).framework(
        framework="torch"
    ).training(
        lr=config["lr"],
        train_batch_size=config["train_batch_size"],
        gamma=config["gamma"],
    ).resources(
        num_gpus=config["num_gpus"],
        num_cpus_per_worker=1,
    ).rollouts(
        num_rollout_workers=config["num_workers"],
        num_envs_per_worker=config["num_envs_per_worker"],
    ).multi_agent(
        policies=config["multiagent"]["policies"],
        policy_mapping_fn=policy_mapping_fn,
        policies_to_train=["shared_policy"],
    )

    # Set sgd_minibatch_size directly
    ppo_config.sgd_minibatch_size = config["sgd_minibatch_size"]

    # Build the trainer
    trainer = ppo_config.build()

    # ================================
    # Training Loop with Live Rendering and Checkpoints
    # ================================
    checkpoint_dir = "./checkpoints"
    if not os.path.exists(checkpoint_dir):
        os.makedirs(checkpoint_dir)

    max_iterations = 50  # Set the number of training iterations
    rewards_history = deque(maxlen=100)
    iterations_list = []
    mean_rewards = []

    try:
        for i in range(max_iterations):
            print(f"Starting training iteration {i+1}/{max_iterations}")
            
            # Perform one training iteration
            result = trainer.train()
            mean_reward = result.get('episode_reward_mean', 0)
            print(f"Iteration {i+1} results: {mean_reward} mean reward")

            # Append results for plotting
            iterations_list.append(i+1)
            mean_rewards.append(mean_reward)
            rewards_history.append(mean_reward)

            # Save checkpoint after each iteration
            checkpoint_path = trainer.save(checkpoint_dir)
            print(f"Checkpoint saved at {checkpoint_path}")

            # Reset the environment
            env = RoadIntersectionEnv(config["env_config"])
            obs, _ = env.reset()

            done = {agent: False for agent in env.agents}
            done['__all__'] = False

            should_render = True  # Set to True to visualize

            # Run one episode to visualize the agent's behavior
            while not done['__all__']:
                # Handle pygame events
                for event in pygame.event.get():
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        ray.shutdown()
                        sys.exit()

                actions = {}
                for agent_id in obs:
                    action = trainer.compute_single_action(obs[agent_id], policy_id="shared_policy", explore=False)
                    actions[agent_id] = action

                obs, rewards, done, truncateds, infos = env.step(actions)

                if should_render:
                    env.render()

                # Optional: Add a delay for visualization purposes
                pygame.time.delay(100)  # Delay in milliseconds

        # ================================
        # Plot Training Progress
        # ================================
        plt.figure(figsize=(10, 6))
        plt.plot(iterations_list, mean_rewards, label='Mean Episode Reward')
        plt.xlabel('Training Iteration')
        plt.ylabel('Mean Episode Reward')
        plt.title('Training Progress')
        plt.legend()
        plt.grid()
        plt.show()

    except KeyboardInterrupt:
        print("Training interrupted by user.")

    finally:
        # ================================
        # Clean up Resources
        # ================================
        ray.shutdown()
        pygame.quit()

# ================================
# Run the Main Function
# ================================
if __name__ == "__main__":
    main()
# Out:
# 2024-11-29 19:57:36,955	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-11-29 19:57:37,969	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-11-29 19:57:55,041	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2024-11-29 19:58:00,612	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.resources(num_cpus_per_worker)` has been deprecated. Use `AlgorithmConfig.env_runners(num_cpus_per_env_runner)` instead. This will raise an error in the future!
# 2024-11-29 19:58:00,613	WARNING deprecation.py:50 -- DeprecationWarning: `rollouts` has been deprecated. Use `AlgorithmConfig.env_runners(..)` instead. This will raise an error in the future!
# 2024-11-29 19:58:00,614	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# 2024-11-29 19:58:00,616	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_envs_per_worker)` has been deprecated. Use `AlgorithmConfig.env_runners(num_envs_per_env_runner)` instead. This will raise an error in the future!
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:568: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-11-29 19:58:04,874	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Starting training iteration 1/50
# 2024-11-29 19:58:22,364	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# Iteration 1 results: 0 mean reward
# Checkpoint saved at TrainingResult(checkpoint=Checkpoint(filesystem=local, path=./checkpoints), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'shared_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.15109199859426484, 'cur_kl_coeff': 0.2, 'cur_lr': 0.0010000000000000002, 'total_loss': 9.908783388137817, 'policy_loss': -0.09068131533373767, 'vf_loss': 9.987498008443954, 'vf_explained_var': -0.00025003529186789873, 'kl': 0.05983342881704626, 'entropy': 7.801557375353279, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 127.65957446808511, 'num_grad_updates_lifetime': 1410.5, 'diff_num_grad_updates_vs_sampler_policy': 1409.5}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 0, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 38.094709840517964, 'num_env_steps_trained_throughput_per_sec': 38.094709840517964, 'timesteps_total': 4000, 'num_env_steps_sampled_lifetime': 4000, 'num_agent_steps_sampled_lifetime': 12000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 12000, 'timers': {'training_iteration_time_ms': 105001.456, 'restore_workers_time_ms': 0.0, 'training_step_time_ms': 105001.456, 'sample_time_ms': 17333.709, 'learn_time_ms': 87656.215, 'learn_throughput': 45.633, 'synch_weights_time_ms': 0.0}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'done': False, 'training_iteration': 1, 'trial_id': 'default', 'date': '2024-11-29_19-59-49', 'timestamp': 1732890589, 'time_this_iter_s': 105.00245404243469, 'time_total_s': 105.00245404243469, 'pid': 28364, 'hostname': 'LAPTOP-6E8U0HP2', 'node_ip': '127.0.0.1', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'enable_rl_module_and_learner': False, 'enable_env_runner_and_connector_v2': False, 'env': 'RoadIntersectionEnv', 'env_config': {'graph': <networkx.classes.graph.Graph object at 0x000001841EBC6570>, 'num_agents': 3}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task ...
# Training interrupted by user.

# %% [markdown]
# # Matplotlib rendering

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from ray.tune import Callback
import sys
import os
import xml.etree.ElementTree as ET
import re
import matplotlib
import matplotlib.pyplot as plt
import time

# Set matplotlib backend to ensure compatibility with interactive plots
matplotlib.use('TkAgg')

# Custom Callback for Real-Time Plotting
class RealTimePlottingCallback(Callback):
    def __init__(self):
        self.iterations = []
        self.mean_rewards = []
        self.fig, (self.ax1, self.ax2) = plt.subplots(1, 2, figsize=(12, 6))
        plt.ion()  # Interactive mode for real-time plotting
        plt.show()
        self.current_positions = None
        self.graph = None

    def on_trial_result(self, iteration, trials, trial, result, **info):
        mean_reward = result.get("episode_reward_mean", 0)
        self.iterations.append(iteration)
        self.mean_rewards.append(mean_reward)

        # Update the reward plot
        # Update reward plot without clearing the entire axis
        self.ax1.lines = []  # Clear only the lines in the plot
        self.ax1.plot(self.iterations, self.mean_rewards, label="Mean Episode Reward")
        self.ax1.set_xlabel("Training Iteration")
        self.ax1.set_ylabel("Mean Episode Reward")
        self.ax1.set_title("Training Progress")
        self.ax1.legend()
        self.ax1.grid()

        # Update the agent movement plot if graph and positions are available
        if self.graph and self.current_positions:
            # Update agent movement plot without clearing the entire axis
            pos = nx.get_node_attributes(self.graph, 'pos')
            self.ax2.collections = []  # Clear existing nodes and edges       
            nx.draw(self.graph, pos, ax=self.ax2, node_color='lightblue', edge_color='gray', with_labels=False, node_size=20)
            agent_positions = np.array(list(self.current_positions.values()))
            self.ax2.scatter(agent_positions[:, 0], agent_positions[:, 1], color='red', s=100, label="Agents")
            self.ax2.set_title("Agent Movement in Environment")
            self.ax2.legend()

        plt.pause(0.01)  # Pause to allow the plot to update

    def update_positions(self, graph, current_positions):
        self.graph = graph
        self.current_positions = current_positions

# ================================
# Define the Distance Function at the Module Level
# ================================
def distance(p1, p2):
    return np.linalg.norm(p1 - p2)

# ================================
# Set Screen Dimensions
# ================================
WIDTH, HEIGHT = 1200, 900

# ================================
# Parse the KML File
# ================================
def parse_kml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

    taxiways = []
    gates = []

    for placemark in root.findall('.//kml:Placemark', namespace):
        # Extract LineStrings (taxiways and runways)
        line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
        if line_string is not None:
            line_coords = line_string.text.strip().split()
            path = []
            for coord in line_coords:
                lon, lat, _ = map(float, coord.split(','))
                path.append((lon, lat))
            taxiway = {'path': path}
            name = placemark.find('kml:name', namespace)
            if name is not None:
                placemark_name = name.text.strip()
                taxiway['name'] = placemark_name
                match = re.search(r'\b(L1|L2|L3)\b', placemark_name)
                if match:
                    taxiway['code'] = match.group(1)
                else:
                    taxiway['code'] = ''
                if 'CENTRELINE' in placemark_name.upper():
                    taxiway['is_runway'] = True
            taxiways.append(taxiway)

        # Extract Points (gates)
        point = placemark.find('.//kml:Point/kml:coordinates', namespace)
        if point is not None:
            coord = point.text.strip().split(',')
            lon, lat, _ = map(float, coord)
            gates.append({'position': (lon, lat)})

    return taxiways, gates

# ================================
# Build the NetworkX Graph
# ================================
def build_graph(taxiways, gates, width, height):
    all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
    all_gate_coords = [gate['position'] for gate in gates]
    all_coords = all_taxiway_coords + all_gate_coords

    lon_min = min(coord[0] for coord in all_coords)
    lon_max = max(coord[0] for coord in all_coords)
    lat_min = min(coord[1] for coord in all_coords)
    lat_max = max(coord[1] for coord in all_coords)

    margin = 0.05
    lon_range = lon_max - lon_min
    lat_range = lat_max - lat_min
    lon_min -= lon_range * margin
    lon_max += lon_range * margin
    lat_min -= lat_range * margin
    lat_max += lat_range * margin

    def convert_coords(lon, lat):
        x = (lon - lon_min) / (lon_max - lon_min) * width
        y = height - (lat - lat_min) / (lat_max - lat_min) * height
        return np.array([x, y])

    for taxiway in taxiways:
        pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
        taxiway['pixel_path'] = pixel_path

    for gate in gates:
        gate['pixel_position'] = convert_coords(*gate['position'])

    G = nx.Graph()
    node_id_counter = 0
    node_positions = {}
    for idx, taxiway in enumerate(taxiways):
        path = taxiway['pixel_path']
        taxiway_name = taxiway.get('name', '')
        taxiway_code = taxiway.get('code', '')
        taxiway_nodes = []
        for i, point in enumerate(path):
            node_id = node_id_counter
            node_id_counter += 1
            G.add_node(node_id, pos=point)
            G.nodes[node_id]['taxiway_name'] = taxiway_name
            G.nodes[node_id]['taxiway_code'] = taxiway_code
            if taxiway.get('is_runway'):
                G.nodes[node_id]['is_runway_node'] = True
            node_positions[node_id] = point
            taxiway_nodes.append(node_id)
            if i > 0:
                prev_node_id = taxiway_nodes[i - 1]
                G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
        taxiway['node_ids'] = taxiway_nodes

    def connect_taxiway_endpoints(G, taxiways):
        CONNECTION_THRESHOLD = 30
        for taxiway1 in taxiways:
            for taxiway2 in taxiways:
                if taxiway1 == taxiway2:
                    continue
                endpoints1 = [taxiway1['node_ids'][0], taxiway1['node_ids'][-1]]
                endpoints2 = [taxiway2['node_ids'][0], taxiway2['node_ids'][-1]]
                for node1 in endpoints1:
                    for node2 in endpoints2:
                        pos1 = G.nodes[node1]['pos']
                        pos2 = G.nodes[node2]['pos']
                        if np.linalg.norm(pos1 - pos2) < CONNECTION_THRESHOLD:
                            if not G.has_edge(node1, node2):
                                G.add_edge(node1, node2, weight=np.linalg.norm(pos1 - pos2))

    def connect_runways_to_taxiways(G, taxiways):
        CONNECTION_THRESHOLD = 30
        for runway in [t for t in taxiways if t.get('is_runway')]:
            for taxiway in [t for t in taxiways if not t.get('is_runway')]:
                for runway_node in runway['node_ids']:
                    for taxiway_node in taxiway['node_ids']:
                        pos_runway = G.nodes[runway_node]['pos']
                        pos_taxiway = G.nodes[taxiway_node]['pos']
                        if np.linalg.norm(pos_runway - pos_taxiway) < CONNECTION_THRESHOLD:
                            if not G.has_edge(runway_node, taxiway_node):
                                G.add_edge(runway_node, taxiway_node, weight=np.linalg.norm(pos_runway - pos_taxiway))

    connect_taxiway_endpoints(G, taxiways)
    connect_runways_to_taxiways(G, taxiways)

    # Ensure all edges have a weight of 1
    for edge in G.edges():
        G[edge[0]][edge[1]]['weight'] = 1

    return G, node_positions, convert_coords

# ================================
# Add Predefined Gates and Runway Endpoints
# ================================
def add_predefined_nodes(G, node_positions, gate_coordinates, runway_endpoints, convert_coords, node_id_counter):
    for gate_coord in gate_coordinates:
        gate_pixel_position = convert_coords(*gate_coord)
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=gate_pixel_position, is_gate=True)
        node_positions[node_id] = gate_pixel_position

    for runway_coord in runway_endpoints:
        runway_pixel_position = convert_coords(*runway_coord)
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=runway_pixel_position, is_runway_endpoint=True)
        node_positions[node_id] = runway_pixel_position

    return G, node_positions, node_id_counter

# ================================
# Custom Multi-Agent Environment
# ================================
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, config, callback=None):
        super().__init__()
        self.graph = config["graph"]
        self.total_agents = config["num_agents"]
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}
        self.callback = callback

        # Use Discrete spaces to represent each agent's current node in the graph
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        # Randomly assign starting positions from gates and runway endpoints
        available_nodes = [node for node, data in self.graph.nodes(data=True) if data.get('is_gate') or data.get('is_runway_endpoint')]
        for agent in self.agents:
            self.pos[agent] = np.random.choice(available_nodes)
            self.distance_travelled[agent] = 0
        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}  # Return observations as a dictionary

        # Update callback with current positions
        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        return obs, {}

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        # Move each agent
        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            # Ensure next_node is a valid neighbor of the current node
            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += self.graph[current_node][next_node]['weight']
                rewards[agent] = -0.1  # Small negative reward to encourage shorter paths
            else:
                # Invalid action, penalize the agent
                rewards[agent] -= 1

        # Detect collisions
        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 5  # Penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 5
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        # Update done flags for all agents
        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True  # Mark as truncated to properly handle episode end

        # Check if all agents are done
        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}  # Return observations as a dictionary
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}  # Update infos to match the current observation keys

        # Update callback with current positions
        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        # Render the environment to visualize agent movement
        self.render()

        return obs, rewards, dones, truncateds, infos

    def render(self):
        if self.callback and self.callback.graph and self.callback.current_positions:
            self.callback.fig.suptitle("Agent Movement Visualization", fontsize=16)
            self.callback.ax2.clear()
            pos = nx.get_node_attributes(self.graph, 'pos')
            nx.draw(self.graph, pos, node_color='lightblue', edge_color='gray', with_labels=False, node_size=20)
            agent_positions = np.array(list(self.pos.values()))
            agent_coordinates = [self.graph.nodes[node]['pos'] for node in agent_positions if node is not None]
            if agent_coordinates:
                agent_coordinates = np.array(agent_coordinates)
                plt.scatter(agent_coordinates[:, 0], agent_coordinates[:, 1], color='red', s=100, label="Agents")
            plt.title("Agent Movement in Environment")
            plt.legend()
            plt.pause(0.01)

# ================================
# Main Function
# ================================
def main():
    # Include global variables required by the environment
    global taxiways

    # ================================
    # Parse KML and Build Graph
    # ================================
    file_path = "reduced_nodes.kml"  # Update this path to your KML file
    taxiways, gates = parse_kml(file_path)
    G, node_positions, convert_coords = build_graph(taxiways, gates, WIDTH, HEIGHT)

    # Predefined gates and runway endpoints for agents to start and end
    gate_coordinates = [
        (77.71046165300096, 13.20355775032989),
        (77.71066072998956, 13.20166801620613),
        (77.70315360361252, 13.20165318995302),
        (77.71305689010458, 13.201637816132),
        (77.70195813939766, 13.20169406641297),
        (77.71149825860202, 13.20165032306983),
        (77.72279066770344, 13.19968338101175),
        (77.7132055646255, 13.20167917723071),
        (77.7089924860226, 13.20357466411958),
        (77.71648635375834, 13.20336974504588)
    ]

    runway_endpoints = [
        (77.68686735208298, 13.20718308006773),
        (77.7222951686759, 13.20687066472886),
        (77.69060216489893, 13.18975920793089),
        (77.72642499411846, 13.18944676842937)
    ]

    # Add predefined gates and runway endpoints to the graph
    node_id_counter = len(G.nodes())
    G, node_positions, node_id_counter = add_predefined_nodes(
        G, node_positions, gate_coordinates, runway_endpoints,
        convert_coords=convert_coords,
        node_id_counter=node_id_counter
    )

    # ================================
    # Initialize Ray
    # ================================
    ray.init(ignore_reinit_error=True, log_to_driver=True)

    # ================================
    # Register the Environment
    # ================================
    from ray.tune.registry import register_env

    callback = RealTimePlottingCallback()

    def env_creator(env_config):
        return RoadIntersectionEnv(env_config, callback=callback)

    register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

    # ================================
    # Define Policy Mapping Function
    # ================================
    def policy_mapping_fn(agent_id, *args, **kwargs):
        return "shared_policy"

    # ================================
    # RLlib Training Configuration
    # ================================
    temp_env = RoadIntersectionEnv({"graph": G, "num_agents": 3}, callback=callback)

    config = {
        "env": "RoadIntersectionEnv",
        "env_config": {
            "graph": G,
            "num_agents": 3
        },
        "framework": "torch",
        "num_workers": 1,  # Run in the main thread for rendering
        "num_envs_per_worker": 1,
        "num_gpus": 1,  # Set to 1 if you have a GPU and want to use it
        "train_batch_size": 4000,
        "sgd_minibatch_size": 128,
        "lr": 1e-3,
        "gamma": 0.99,
        "log_level": "WARN",
        "multiagent": {
            "policies": {
                "shared_policy": (None, temp_env.observation_space, temp_env.action_space, {})
            },
            "policy_mapping_fn": policy_mapping_fn,
            "policies_to_train": ["shared_policy"],
        },
    }

    # Training using tune.run with Custom Callback for Real-Time Visualization
    tune.run(
        "PPO",
        config=config,
        stop={"training_iteration": 25},
        storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints",
        checkpoint_freq=5,
        checkpoint_at_end=True,
        verbose=1,
        callbacks=[callback]
    )

    # Clean up
    ray.shutdown()

# ================================
# Run the Main Function
# ================================
if __name__ == "__main__":
    main()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-11-29 23:37:40</td></tr>
# <tr><td>Running for: </td><td>00:00:35.91        </td></tr>
# <tr><td>Memory:      </td><td>14.2/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name                         </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_bd0fb_00000</td><td style="text-align: right;">           1</td><td>C:/Users/aniru/AppData/Local/Temp/ray/session_2024-11-29_23-12-10_287643_5668/artifacts/2024-11-29_23-37-04/PPO_2024-11-29_23-37-03/driver_artifacts/PPO_RoadIntersectionEnv_bd0fb_00000_0_2024-11-29_23-37-04/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status  </th><th>loc            </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_bd0fb_00000</td><td>ERROR   </td><td>127.0.0.1:40028</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-11-29 23:37:04,305	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (PPO pid=40028) 2024-11-29 23:37:18,085	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (PPO pid=40028) Trainable.setup took 20.531 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=40028) Install gputil for GPU system monitoring.
# 2024-11-29 23:37:40,111	ERROR tune_controller.py:1331 -- Trial task failed for trial PPO_RoadIntersectionEnv_bd0fb_00000
# Traceback (most recent call last):
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 2745, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 901, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::PPO.train() (pid=40028, ip=127.0.0.1, actor_id=2f3c432a82cb77b027117e5a01000000, repr=PPO)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1803, in ray._raylet.execute_task.function_executor
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py", line 328, in train
#     result = self.step()
#              ^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 934, in step
#     train_results, train_iter_ctx = self._run_one_training_iteration()
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 3528, in _run_one_training_iteration
#     training_step_results = self.training_step()
#                             ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 410, in training_step
#     return self._training_step_old_api_stack()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 521, in _training_step_old_api_stack
#     train_batch = synchronous_parallel_sample(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sampled_data = worker_set.foreach_worker(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py", line 909, in foreach_worker
#     FaultTolerantActorManager.handle_remote_call_result_errors(
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 638, in handle_remote_call_result_errors
#     raise result_or_error.get()
# ray.exceptions.RayTaskError(ValueError): ray::RolloutWorker.apply() (pid=30040, ip=127.0.0.1, actor_id=4ca3016666be917cf1491d8601000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020B104A1D60>)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1803, in ray._raylet.execute_task.function_executor
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 194, in apply
#     raise e
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 183, in apply
#     return func(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 102, in <lambda>
#     (lambda w: w.sample(**random_action_kwargs))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 680, in sample
#     batches = [self.input_reader.next()]
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 91, in next
#     batches = [self.get_data()]
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 273, in get_data
#     item = next(self._env_runner)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 329, in run
#     outputs = self.step()
#               ^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 385, in step
#     self._base_env.send_actions(actions_to_send)
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\multi_agent_env.py", line 539, in send_actions
#     raise e
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\multi_agent_env.py", line 528, in send_actions
#     obs, rewards, terminateds, truncateds, infos = env.step(agent_dict)
#                                                    ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\AppData\Local\Temp\ipykernel_5668\97784452.py", line 329, in step
#   File "C:\Users\aniru\AppData\Local\Temp\ipykernel_5668\97784452.py", line 336, in render
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axes\_base.py", line 1391, in clear
#     self.__clear()
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axes\_base.py", line 1379, in __clear
#     axis._set_lim(0, 1, auto=True)
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axis.py", line 1269, in _set_lim
#     self.set_view_interval(v0, v1, ignore=True)
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axis.py", line 2317, in setter
#     setattr(getattr(self.axes, lim_name), attr_name, (vmin, vmax))
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\transforms.py", line 988, in intervalx
#     self._points[:, 0] = interval
#     ~~~~~~~~~~~~^^^^^^
# ValueError: assignment destination is read-only
# (PPO pid=40028) 2024-11-29 23:37:40,097	ERROR actor_manager.py:804 -- Ray error (ray::RolloutWorker.apply() (pid=30040, ip=127.0.0.1, actor_id=4ca3016666be917cf1491d8601000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020B104A1D60>)
# (PPO pid=40028)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (PPO pid=40028)   File "python\ray\_raylet.pyx", line 1803, in ray._raylet.execute_task.function_executor
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
# (PPO pid=40028)     return method(__ray_actor, *args, **kwargs)
# (PPO pid=40028)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
# (PPO pid=40028)     return method(self, *_args, **_kwargs)
# (PPO pid=40028)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 194, in apply
# (PPO pid=40028)     raise e
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 183, in apply
# (PPO pid=40028)     return func(self, *args, **kwargs)
# (PPO pid=40028)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 102, in <lambda>
# (PPO pid=40028)     (lambda w: w.sample(**random_action_kwargs))
# (PPO pid=40028)                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
# (PPO pid=40028)     return method(self, *_args, **_kwargs)
# (PPO pid=40028)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 680, in sample
# (PPO pid=40028)     batches = [self.input_reader.next()]
# (PPO pid=40028)                ^^^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 91, in next
# (PPO pid=40028)     batches = [self.get_data()]
# (PPO pid=40028)                ^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 273, in get_data
# (PPO pid=40028)     item = next(self._env_runner)
# (PPO pid=40028)            ^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 329, in run
# (PPO pid=40028)     outputs = self.step()
# (PPO pid=40028)               ^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 385, in step
# (PPO pid=40028)     self._base_env.send_actions(actions_to_send)
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\multi_agent_env.py", line 539, in send_actions
# (PPO pid=40028)     raise e
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\multi_agent_env.py", line 528, in send_actions
# (PPO pid=40028)     obs, rewards, terminateds, truncateds, infos = env.step(agent_dict)
# (PPO pid=40028)                                                    ^^^^^^^^^^^^^^^^^^^^
# (PPO pid=40028)   File "C:\Users\aniru\AppData\Local\Temp\ipykernel_5668\97784452.py", line 329, in step
# (PPO pid=40028)   File "C:\Users\aniru\AppData\Local\Temp\ipykernel_5668\97784452.py", line 336, in render
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axes\_base.py", line 1391, in clear
# (PPO pid=40028)     self.__clear()
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axes\_base.py", line 1379, in __clear
# (PPO pid=40028)     axis._set_lim(0, 1, auto=True)
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axis.py", line 1269, in _set_lim
# (PPO pid=40028)     self.set_view_interval(v0, v1, ignore=True)
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\axis.py", line 2317, in setter
# (PPO pid=40028)     setattr(getattr(self.axes, lim_name), attr_name, (vmin, vmax))
# (PPO pid=40028)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\matplotlib\transforms.py", line 988, in intervalx
# (PPO pid=40028)     self._points[:, 0] = interval
# (PPO pid=40028)     ~~~~~~~~~~~~^^^^^^
# (PPO pid=40028) ValueError: assignment destination is read-only), taking actor 1 out of service.
# 2024-11-29 23:37:40,204	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-11-29_23-37-03' in 0.0524s.
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[7], line 462
#     458 # ================================
#     459 # Run the Main Function
#     460 # ================================
#     461 if __name__ == "__main__":
# --> 462     main()
#
# Cell In[7], line 444, in main()
#     419 config = {
#     420     "env": "RoadIntersectionEnv",
#     421     "env_config": {
#    (...)
#     440     },
#     441 }
#     443 # Training using tune.run with Custom Callback for Real-Time Visualization
# --> 444 tune.run(
#     445     "PPO",
#     446     config=config,
#     447     stop={"training_iteration": 25},
#     448     storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints",
#     449     checkpoint_freq=5,
#     450     checkpoint_at_end=True,
#     451     verbose=1,
#     452     callbacks=[callback]
#     453 )
#     455 # Clean up
#     456 ray.shutdown()
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\tune\tune.py:1035, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1033 if incomplete_trials:
#    1034     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1035         raise TuneError("Trials did not complete", incomplete_trials)
#    1036     else:
#    1037         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [PPO_RoadIntersectionEnv_bd0fb_00000])

# %%
# D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints
# 
#

# %% [markdown]
# # Matplotlib but no ray tune

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from ray.tune import Callback
import sys
import os
import xml.etree.ElementTree as ET
import re
import matplotlib
import matplotlib.pyplot as plt
import time

# Set matplotlib backend to ensure compatibility with interactive plots
matplotlib.use('TkAgg')

# Custom Callback for Real-Time Plotting
class RealTimePlottingCallback(Callback):
    def __init__(self):
        self.iterations = []
        self.mean_rewards = []
        self.fig, self.ax1 = plt.subplots(figsize=(8, 6))
        plt.ion()  # Interactive mode for real-time plotting
        plt.show()
        self.current_positions = None
        self.graph = None

    def on_trial_result(self, iteration, trials, trial, result, **info):
        mean_reward = result.get("episode_reward_mean", 0)
        self.iterations.append(iteration)
        self.mean_rewards.append(mean_reward)

        # Update the reward plot
        self.ax1.clear()
        self.ax1.plot(self.iterations, self.mean_rewards, label="Mean Episode Reward")
        self.ax1.set_xlabel("Training Iteration")
        self.ax1.set_ylabel("Mean Episode Reward")
        self.ax1.set_title("Training Progress")
        self.ax1.legend()
        self.ax1.grid()

        plt.pause(0.01)  # Pause to allow the plot to update

    def update_positions(self, graph, current_positions):
        self.graph = graph
        self.current_positions = current_positions

        # Update the agent movement plot
        plt.figure("Agent Movement Visualization")
        plt.clf()
        pos = nx.get_node_attributes(self.graph, 'pos')
        nx.draw(self.graph, pos, node_color='lightblue', edge_color='gray', with_labels=False, node_size=20)
        agent_positions = np.array(list(self.current_positions.values()))
        plt.scatter(agent_positions[:, 0], agent_positions[:, 1], color='red', s=100, label="Agents")
        plt.title("Agent Movement in Environment")
        plt.legend()
        plt.pause(0.01)

# ================================
# Define the Distance Function at the Module Level
# ================================
def distance(p1, p2):
    return np.linalg.norm(p1 - p2)

# ================================
# Set Screen Dimensions
# ================================
WIDTH, HEIGHT = 1200, 900

# ================================
# Parse the KML File
# ================================
def parse_kml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

    taxiways = []
    gates = []

    for placemark in root.findall('.//kml:Placemark', namespace):
        # Extract LineStrings (taxiways and runways)
        line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
        if line_string is not None:
            line_coords = line_string.text.strip().split()
            path = []
            for coord in line_coords:
                lon, lat, _ = map(float, coord.split(','))
                path.append((lon, lat))
            taxiway = {'path': path}
            name = placemark.find('kml:name', namespace)
            if name is not None:
                placemark_name = name.text.strip()
                taxiway['name'] = placemark_name
                match = re.search(r'\b(L1|L2|L3)\b', placemark_name)
                if match:
                    taxiway['code'] = match.group(1)
                else:
                    taxiway['code'] = ''
                if 'CENTRELINE' in placemark_name.upper():
                    taxiway['is_runway'] = True
            taxiways.append(taxiway)

        # Extract Points (gates)
        point = placemark.find('.//kml:Point/kml:coordinates', namespace)
        if point is not None:
            coord = point.text.strip().split(',')
            lon, lat, _ = map(float, coord)
            gates.append({'position': (lon, lat)})

    return taxiways, gates

# ================================
# Build the NetworkX Graph
# ================================
def build_graph(taxiways, gates, width, height):
    all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
    all_gate_coords = [gate['position'] for gate in gates]
    all_coords = all_taxiway_coords + all_gate_coords

    lon_min = min(coord[0] for coord in all_coords)
    lon_max = max(coord[0] for coord in all_coords)
    lat_min = min(coord[1] for coord in all_coords)
    lat_max = max(coord[1] for coord in all_coords)

    margin = 0.05
    lon_range = lon_max - lon_min
    lat_range = lat_max - lat_min
    lon_min -= lon_range * margin
    lon_max += lon_range * margin
    lat_min -= lat_range * margin
    lat_max += lat_range * margin

    def convert_coords(lon, lat):
        x = (lon - lon_min) / (lon_max - lon_min) * width
        y = height - (lat - lat_min) / (lat_max - lat_min) * height
        return np.array([x, y])

    for taxiway in taxiways:
        pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
        taxiway['pixel_path'] = pixel_path

    for gate in gates:
        gate['pixel_position'] = convert_coords(*gate['position'])

    G = nx.Graph()
    node_id_counter = 0
    node_positions = {}
    for idx, taxiway in enumerate(taxiways):
        path = taxiway['pixel_path']
        taxiway_name = taxiway.get('name', '')
        taxiway_code = taxiway.get('code', '')
        taxiway_nodes = []
        for i, point in enumerate(path):
            node_id = node_id_counter
            node_id_counter += 1
            G.add_node(node_id, pos=point)
            G.nodes[node_id]['taxiway_name'] = taxiway_name
            G.nodes[node_id]['taxiway_code'] = taxiway_code
            if taxiway.get('is_runway'):
                G.nodes[node_id]['is_runway_node'] = True
            node_positions[node_id] = point
            taxiway_nodes.append(node_id)
            if i > 0:
                prev_node_id = taxiway_nodes[i - 1]
                G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
        taxiway['node_ids'] = taxiway_nodes

    def connect_taxiway_endpoints(G, taxiways):
        CONNECTION_THRESHOLD = 30
        for taxiway1 in taxiways:
            for taxiway2 in taxiways:
                if taxiway1 == taxiway2:
                    continue
                endpoints1 = [taxiway1['node_ids'][0], taxiway1['node_ids'][-1]]
                endpoints2 = [taxiway2['node_ids'][0], taxiway2['node_ids'][-1]]
                for node1 in endpoints1:
                    for node2 in endpoints2:
                        pos1 = G.nodes[node1]['pos']
                        pos2 = G.nodes[node2]['pos']
                        if np.linalg.norm(pos1 - pos2) < CONNECTION_THRESHOLD:
                            if not G.has_edge(node1, node2):
                                G.add_edge(node1, node2, weight=np.linalg.norm(pos1 - pos2))

    def connect_runways_to_taxiways(G, taxiways):
        CONNECTION_THRESHOLD = 30
        for runway in [t for t in taxiways if t.get('is_runway')]:
            for taxiway in [t for t in taxiways if not t.get('is_runway')]:
                for runway_node in runway['node_ids']:
                    for taxiway_node in taxiway['node_ids']:
                        pos_runway = G.nodes[runway_node]['pos']
                        pos_taxiway = G.nodes[taxiway_node]['pos']
                        if np.linalg.norm(pos_runway - pos_taxiway) < CONNECTION_THRESHOLD:
                            if not G.has_edge(runway_node, taxiway_node):
                                G.add_edge(runway_node, taxiway_node, weight=np.linalg.norm(pos_runway - pos_taxiway))

    connect_taxiway_endpoints(G, taxiways)
    connect_runways_to_taxiways(G, taxiways)

    # Ensure all edges have a weight of 1
    for edge in G.edges():
        G[edge[0]][edge[1]]['weight'] = 1

    return G, node_positions, convert_coords

# ================================
# Add Predefined Gates and Runway Endpoints
# ================================
def add_predefined_nodes(G, node_positions, gate_coordinates, runway_endpoints, convert_coords, node_id_counter):
    for gate_coord in gate_coordinates:
        gate_pixel_position = convert_coords(*gate_coord)
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=gate_pixel_position, is_gate=True)
        node_positions[node_id] = gate_pixel_position

    for runway_coord in runway_endpoints:
        runway_pixel_position = convert_coords(*runway_coord)
        node_id = node_id_counter
        node_id_counter += 1
        G.add_node(node_id, pos=runway_pixel_position, is_runway_endpoint=True)
        node_positions[node_id] = runway_pixel_position

    return G, node_positions, node_id_counter

# ================================
# Custom Multi-Agent Environment
# ================================
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, config, callback=None):
        super().__init__()
        self.graph = config["graph"]
        self.total_agents = config["num_agents"]
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}
        self.callback = callback

        # Use Discrete spaces to represent each agent's current node in the graph
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        # Randomly assign starting positions from gates and runway endpoints
        available_nodes = [node for node, data in self.graph.nodes(data=True) if data.get('is_gate') or data.get('is_runway_endpoint')]
        for agent in self.agents:
            self.pos[agent] = np.random.choice(available_nodes)
            self.distance_travelled[agent] = 0
        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}  # Return observations as a dictionary

        # Update callback with current positions
        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        return obs, {}

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        # Move each agent
        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            # Ensure next_node is a valid neighbor of the current node
            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += self.graph[current_node][next_node]['weight']
                rewards[agent] = -0.1  # Small negative reward to encourage shorter paths
            else:
                # Invalid action, penalize the agent
                rewards[agent] -= 1

        # Detect collisions
        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 5  # Penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 5
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        # Update done flags for all agents
        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True  # Mark as truncated to properly handle episode end

        # Check if all agents are done
        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}  # Return observations as a dictionary
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}  # Update infos to match the current observation keys

        # Update callback with current positions
        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        return obs, rewards, dones, truncateds, infos

# ================================
# Main Function
# ================================
def main():
    # Include global variables required by the environment
    global taxiways

    # ================================
    # Parse KML and Build Graph
    # ================================
    file_path = "reduced_nodes.kml"  # Update this path to your KML file
    taxiways, gates = parse_kml(file_path)
    G, node_positions, convert_coords = build_graph(taxiways, gates, WIDTH, HEIGHT)

    # Predefined gates and runway endpoints for agents to start and end
    gate_coordinates = [
        (77.71046165300096, 13.20355775032989),
        (77.71066072998956, 13.20166801620613),
        (77.70315360361252, 13.20165318995302),
        (77.71305689010458, 13.201637816132),
        (77.70195813939766, 13.20169406641297),
        (77.71149825860202, 13.20165032306983),
        (77.72279066770344, 13.19968338101175),
        (77.7132055646255, 13.20167917723071),
        (77.7089924860226, 13.20357466411958),
        (77.71648635375834, 13.20336974504588)
    ]

    runway_endpoints = [
        (77.68686735208298, 13.20718308006773),
        (77.7222951686759, 13.20687066472886),
        (77.69060216489893, 13.18975920793089),
        (77.72642499411846, 13.18944676842937)
    ]

    # Add predefined gates and runway endpoints to the graph
    node_id_counter = len(G.nodes())
    G, node_positions, node_id_counter = add_predefined_nodes(
        G, node_positions, gate_coordinates, runway_endpoints,
        convert_coords=convert_coords,
        node_id_counter=node_id_counter
    )

    # ================================
    # Initialize Ray
    # ================================
    ray.init(ignore_reinit_error=True, log_to_driver=True)

    # ================================
    # Register the Environment
    # ================================
    from ray.tune.registry import register_env

    callback = RealTimePlottingCallback()

    def env_creator(env_config):
        return RoadIntersectionEnv(env_config, callback=callback)

    register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

    # ================================
    # Define Policy Mapping Function
    # ================================
    def policy_mapping_fn(agent_id, *args, **kwargs):
        return "shared_policy"

    # ================================
    # RLlib Training Configuration
    # ================================
    temp_env = RoadIntersectionEnv({"graph": G, "num_agents": 3}, callback=callback)

    config = {
        "env": "RoadIntersectionEnv",
        "env_config": {
            "graph": G,
            "num_agents": 3
        },
        "framework": "torch",
        "num_workers": 1,  # Run in the main thread for rendering
        "num_envs_per_worker": 1,
        "num_gpus": 1,  # Set to 1 if you have a GPU and want to use it
        "train_batch_size": 4000,
        "sgd_minibatch_size": 128,
        "lr": 1e-3,
        "gamma": 0.99,
        "log_level": "WARN",
        "multiagent": {
            "policies": {
                "shared_policy": (None, temp_env.observation_space, temp_env.action_space, {})
            },
            "policy_mapping_fn": policy_mapping_fn,
            "policies_to_train": ["shared_policy"],
        },
    }

    # Training using tune.run with Custom Callback for Real-Time Visualization
    tune.run(
        "PPO",
        config=config,
        stop={"training_iteration": 50},
        storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints",
        checkpoint_freq=5,
        checkpoint_at_end=True,
        verbose=1,
        callbacks=[callback]
    )

    # Clean up
    ray.shutdown()

# ================================
# Run the Main Function
# ================================
if __name__ == "__main__":
    main()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-12-01 11:38:18</td></tr>
# <tr><td>Running for: </td><td>00:33:01.25        </td></tr>
# <tr><td>Memory:      </td><td>10.4/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_0bab1_00000</td><td>RUNNING </td><td>127.0.0.1:29284</td><td style="text-align: right;">    15</td><td style="text-align: right;">         1822.62</td><td style="text-align: right;">   0</td><td style="text-align: right;">                    1</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-12-01 11:05:16,802	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (PPO pid=29284) 2024-12-01 11:05:29,839	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.num_envs_per_worker` has been deprecated. Use `AlgorithmConfig.num_envs_per_env_runner` instead. This will raise an error in the future!
# (PPO pid=29284) Trainable.setup took 22.062 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=29284) Install gputil for GPU system monitoring.
# (RolloutWorker pid=25588) Figure(800x600)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (PPO pid=29284) 2024-12-01 11:06:54,312	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# ...
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# 2024-12-01 11:38:17,998	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-12-01 11:38:18,048	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-12-01_11-05-16' in 0.0478s.
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# (RolloutWorker pid=25588) Figure(640x480)
# 2024-12-01 11:38:28,187	INFO tune.py:1041 -- Total run time: 1991.66 seconds (1981.20 seconds for the tuning loop).
# 2024-12-01 11:38:28,189	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)

# %%
# D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints

# %% [markdown]
# # Visualising only checkpoints without training

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPOConfig, PPO
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import sys
import os
import xml.etree.ElementTree as ET
import re
import pygame

# ================================
# Define the Distance Function at the Module Level
# ================================
def distance(p1, p2):
    return np.linalg.norm(p1 - p2)

# ================================
# Set Screen Dimensions
# ================================
WIDTH, HEIGHT = 1200, 900

# ================================
# Parse the KML File
# ================================
def parse_kml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

    taxiways = []
    gates = []

    for placemark in root.findall('.//kml:Placemark', namespace):
        # Extract LineStrings (taxiways and runways)
        line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
        if line_string is not None:
            line_coords = line_string.text.strip().split()
            path = []
            for coord in line_coords:
                lon, lat, _ = map(float, coord.split(','))
                path.append((lon, lat))
            taxiway = {'path': path}
            name = placemark.find('kml:name', namespace)
            if name is not None:
                placemark_name = name.text.strip()
                taxiway['name'] = placemark_name
            taxiways.append(taxiway)

        # Extract Points (gates)
        point = placemark.find('.//kml:Point/kml:coordinates', namespace)
        if point is not None:
            coord = point.text.strip().split(',')
            lon, lat, _ = map(float, coord)
            gates.append({'position': (lon, lat)})

    return taxiways, gates

# ================================
# Build the NetworkX Graph
# ================================
def build_graph(taxiways, gates, width, height):
    all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
    all_gate_coords = [gate['position'] for gate in gates]
    all_coords = all_taxiway_coords + all_gate_coords

    lon_min = min(coord[0] for coord in all_coords)
    lon_max = max(coord[0] for coord in all_coords)
    lat_min = min(coord[1] for coord in all_coords)
    lat_max = max(coord[1] for coord in all_coords)

    margin = 0.05
    lon_range = lon_max - lon_min
    lat_range = lat_max - lat_min
    lon_min -= lon_range * margin
    lon_max += lon_range * margin
    lat_min -= lat_range * margin
    lat_max += lat_range * margin

    def convert_coords(lon, lat):
        x = (lon - lon_min) / (lon_max - lon_min) * width
        y = height - (lat - lat_min) / (lat_max - lat_min) * height
        return np.array([x, y])

    for taxiway in taxiways:
        pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
        taxiway['pixel_path'] = pixel_path

    for gate in gates:
        gate['pixel_position'] = convert_coords(*gate['position'])

    G = nx.Graph()
    node_id_counter = 0
    node_positions = {}
    for idx, taxiway in enumerate(taxiways):
        path = taxiway['pixel_path']
        taxiway_name = taxiway.get('name', '')
        taxiway_nodes = []
        for i, point in enumerate(path):
            node_id = node_id_counter
            node_id_counter += 1
            G.add_node(node_id, pos=point)
            G.nodes[node_id]['taxiway_name'] = taxiway_name
            node_positions[node_id] = point
            taxiway_nodes.append(node_id)
            if i > 0:
                prev_node_id = taxiway_nodes[i - 1]
                G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
        taxiway['node_ids'] = taxiway_nodes

    # Ensure all edges have a weight of 1
    for edge in G.edges():
        G[edge[0]][edge[1]]['weight'] = 1

    return G, node_positions, convert_coords

# ================================
# Custom Multi-Agent Environment
# ================================
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, config, callback=None):
        super().__init__()
        self.graph = config["graph"]
        self.total_agents = config["num_agents"]
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}
        self.destinations = {agent: None for agent in self.agents}
        self.callback = callback

        self.width, self.height = WIDTH, HEIGHT
        self.screen = None

        # Define observation and action spaces
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

        # Predefined gates and runway endpoints for agents to start and end
        self.gate_coordinates = [
            (77.71046165300096, 13.20355775032989),
            (77.71066072998956, 13.20166801620613),
            (77.70315360361252, 13.20165318995302),
            (77.71305689010458, 13.201637816132),
            (77.70195813939766, 13.20169406641297),
            (77.71149825860202, 13.20165032306983),
            (77.72279066770344, 13.19968338101175),
            (77.7132055646255, 13.20167917723071),
            (77.7089924860226, 13.20357466411958),
            (77.71648635375834, 13.20336974504588)
        ]

        self.runway_endpoints = [
            (77.68686735208298, 13.20718308006773),
            (77.7222951686759, 13.20687066472886),
            (77.69060216489893, 13.18975920793089),
            (77.72642499411846, 13.18944676842937)
        ]

        # Pygame initialization
        pygame.init()
        self.screen = pygame.display.set_mode((self.width, self.height))
        pygame.display.set_caption("Airport Taxiway Management")
        self.clock = pygame.time.Clock()

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        # Flatten the list of coordinates for use in np.random.choice
        all_coordinates = self.gate_coordinates + self.runway_endpoints

        for agent in self.agents:
            start_coord = all_coordinates[np.random.choice(len(all_coordinates))]
            dest_coord = all_coordinates[np.random.choice(len(all_coordinates))]
            while dest_coord == start_coord:
                dest_coord = all_coordinates[np.random.choice(len(all_coordinates))]

            # Convert start and destination coordinates to node positions
            start_pos = self._convert_coords(*start_coord)
            dest_pos = self._convert_coords(*dest_coord)

            # Find the closest node to the start and destination positions
            start_node = self._find_closest_node(start_pos)
            dest_node = self._find_closest_node(dest_pos)

            self.pos[agent] = start_node
            self.destinations[agent] = dest_node
            self.distance_travelled[agent] = 0

        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}

        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        # Render the environment state after reset
        self.render()

        return obs, {}

    def _convert_coords(self, lon, lat):
        lon_min, lon_max, lat_min, lat_max = self._get_bounds()
        x = (lon - lon_min) / (lon_max - lon_min) * self.width
        y = self.height - (lat - lat_min) / (lat_max - lat_min) * self.height
        return np.array([x, y])

    def _get_bounds(self):
        all_coords = self.gate_coordinates + self.runway_endpoints
        lon_min = min(coord[0] for coord in all_coords)
        lon_max = max(coord[0] for coord in all_coords)
        lat_min = min(coord[1] for coord in all_coords)
        lat_max = max(coord[1] for coord in all_coords)
        return lon_min, lon_max, lat_min, lat_max

    def _find_closest_node(self, pos):
        closest_node = None
        min_distance = float('inf')
        for node, data in self.graph.nodes(data=True):
            node_pos = data['pos']
            dist = np.linalg.norm(pos - node_pos)
            if dist < min_distance:
                closest_node = node
                min_distance = dist
        return closest_node

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += self.graph[current_node][next_node]['weight']

                # Reward for moving towards the destination
                if next_node == self.destinations[agent]:
                    rewards[agent] += 100  # High reward for reaching the destination
                    dones[agent] = True
                    self.done_agents.add(agent)
                else:
                    rewards[agent] += 1  # Reduced positive reward for moving towards the destination
                    rewards[agent] -= 0.5  # Small negative reward for taking a longer path
            else:
                rewards[agent] -= 1  # Penalty for invalid action

        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 50  # High penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 50
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True

        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}

        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        # Render the environment state after each step
        self.render()

        return obs, rewards, dones, truncateds, infos

    def render(self):
        # Handle Pygame events to prevent the window from hanging
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        # Draw the graph
        self.screen.fill((0, 0, 0))  # Black background)  # White background

        # Draw edges
        for edge in self.graph.edges():
            start_pos = self.graph.nodes[edge[0]]['pos']
            end_pos = self.graph.nodes[edge[1]]['pos']
            pygame.draw.line(self.screen, (0, 0, 255), start_pos, end_pos, 2)  # Blue for edges  # Light grey for edges

        # Draw nodes
        for node, data in self.graph.nodes(data=True):
            pos = data['pos']
            color = (0, 0, 255) if data.get('is_gate') else (0, 255, 0)
            pygame.draw.circle(self.screen, color, (int(pos[0]), int(pos[1])), 5)

        # Draw agents
        for agent, node_id in self.pos.items():
            if node_id is not None:
                pos = self.graph.nodes[node_id]['pos']
                pygame.draw.circle(self.screen, (255, 0, 0), (int(pos[0]), int(pos[1])), 10)

        pygame.display.flip()
        self.clock.tick(60)  # Cap at 60 frames per second

# ================================
# Main Function
# ================================
if __name__ == "__main__":
    # Parse KML and Build Graph
    file_path = "reduced_nodes.kml"  # Update this path to your KML file
    taxiways, gates = parse_kml(file_path)
    G, node_positions, convert_coords = build_graph(taxiways, gates, WIDTH, HEIGHT)

    # Initialize Ray
    ray.init(ignore_reinit_error=True, log_to_driver=True)

    # Register the Environment
    from ray.tune.registry import register_env

    def env_creator(env_config):
        return RoadIntersectionEnv(env_config)

    register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

    # RLlib Training Configuration
    config = {
        "env": "RoadIntersectionEnv",
        "env_config": {
            "graph": G,
            "num_agents": 3
        },
        "framework": "torch",
        "num_workers": 1,
        "num_gpus": 1,
        "train_batch_size": 4000,
        "sgd_minibatch_size": 128,
        "lr": 1e-3,
        "gamma": 0.99,
        "log_level": "WARN",
    }

    # Train the model
    tune.run(
        "PPO",
        config=config,
        stop={"training_iteration": 50},
        checkpoint_freq=5,
        checkpoint_at_end=True,
        verbose=1,
        storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints"  # Save checkpoints to this directory
    )
    checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
    ppo_trainer = PPO(config=config)
    ppo_trainer.restore(checkpoint_path)

    # Create environment for evaluation
    env = RoadIntersectionEnv(config["env_config"])
    obs = env.reset()
    done = {"__all__": False}
    while not done["__all__"]:
        action_dict = {}
        for agent_id, agent_obs in obs.items():
            action = ppo_trainer.compute_single_action(agent_obs, policy_id="default_policy")
            action_dict[agent_id] = action
        obs, rewards, dones, truncateds, infos = env.step(action_dict)
        done = dones

    # Clean up
    ray.shutdown()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-12-02 22:39:57</td></tr>
# <tr><td>Running for: </td><td>00:06:17.85        </td></tr>
# <tr><td>Memory:      </td><td>17.9/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_60cba_00000</td><td>RUNNING </td><td>127.0.0.1:22100</td><td style="text-align: right;">     4</td><td style="text-align: right;">         278.385</td><td style="text-align: right;">   0</td><td style="text-align: right;">                    1</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (RolloutWorker pid=19040) 2024-12-02 22:34:09,390	WARNING deprecation.py:50 -- DeprecationWarning: `get_agent_ids` has been deprecated. Use `MultiAgentEnv.possible_agents` instead. This will raise an error in the future!
# (PPO pid=22100) Trainable.setup took 20.961 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=22100) Install gputil for GPU system monitoring.
# (PPO pid=22100) 2024-12-02 22:35:16,923	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (PPO pid=22100) 2024-12-02 22:36:26,619	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (PPO pid=22100) 2024-12-02 22:37:36,303	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (PPO pid=22100) 2024-12-02 22:38:47,613	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (PPO pid=22100) 2024-12-02 22:39:56,001	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2024-12-02 22:39:57,899	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-12-02 22:39:57,928	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-12-02_22-33-40' in 0.0281s.
# 2024-12-02 22:40:03,433	INFO tune.py:1041 -- Total run time: 383.76 seconds (377.82 seconds for the tuning loop).
# 2024-12-02 22:40:03,434	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:568: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=25164) 2024-12-02 22:40:13,894	WARNING deprecation.py:50 -- DeprecationWarning: `get_agent_ids` has been deprecated. Use `MultiAgentEnv.possible_agents` instead. This will raise an error in the future!
# 2024-12-02 22:40:17,014	INFO trainable.py:161 -- Trainable.setup took 13.507 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-12-02 22:40:17,017	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 377
#     375 checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
#     376 ppo_trainer = PPO(config=config)
# --> 377 ppo_trainer.restore(checkpoint_path)
#     379 # Create environment for evaluation
#     380 env = RoadIntersectionEnv(config["env_config"])
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py:575, in Trainable.restore(self, checkpoint_path)
#     573             self.load_checkpoint(checkpoint_dict)
#     574         else:
# --> 575             self.load_checkpoint(checkpoint_dir)
#     576 else:
#     577     # TODO(justinvyu): The Function Trainable case doesn't conform
#     578     # to the load_checkpoint API at the moment.
#     579     self.load_checkpoint(checkpoint_result)
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:2706, in Algorithm.load_checkpoint(self, checkpoint_dir)
#    2703 # Checkpoint is provided as a local directory.
#    2704 # Restore from the checkpoint file or dir.
#    2705 checkpoint_info = get_checkpoint_info(checkpoint_dir)
# -> 2706 checkpoint_data = Algorithm._checkpoint_info_to_algorithm_state(checkpoint_info)
#    2707 self.__setstate__(checkpoint_data)
#    2708 # Call the `on_checkpoint_loaded` callback.
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:3372, in Algorithm._checkpoint_info_to_algorithm_state(checkpoint_info, policy_ids, policy_mapping_fn, policies_to_train)
#    3370         state = msgpack.unpackb(data, raw=False)
#    3371     else:
# -> 3372         state = pickle.load(f)
#    3374 # Old API stack: Policies are in separate sub-dirs.
#    3375 if (
#    3376     checkpoint_info["checkpoint_version"] > version.Version("0.1")
#    3377     and state.get("worker") is not None
#    3378     and state.get("worker")
#    3379 ):
#
# TypeError: code() argument 13 must be str, not int

# %%
# D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints
#D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029


'''
    tune.run(
        "PPO",
        config=config,
        stop={"training_iteration": 50},
        checkpoint_freq=5,
        checkpoint_at_end=True,
        verbose=1,
        storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints"  # Save checkpoints to this directory
    )

    # Load from a checkpoint and evaluate
    checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
    ppo_trainer = PPO(config=config)
    ppo_trainer.restore(checkpoint_path)

    # Create environment for evaluation
    env = RoadIntersectionEnv(config["env_config"])
    obs = env.reset()
    done = {"__all__": False}
    while not done["__all__"]:
        action_dict = {}
        for agent_id, agent_obs in obs.items():
            action = ppo_trainer.compute_single_action(agent_obs, policy_id="default_policy")
            action_dict[agent_id] = action
        obs, rewards, dones, truncateds, infos = env.step(action_dict)
        done = dones

    # Clean up
    ray.shutdown()
'''

# %% [markdown]
# # Some final working codes

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPOConfig, PPO
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import sys
import os
import xml.etree.ElementTree as ET
import re
import pygame

# ================================
# Define the Distance Function at the Module Level
# ================================
def distance(p1, p2):
    return np.linalg.norm(p1 - p2)

# ================================
# Set Screen Dimensions
# ================================
WIDTH, HEIGHT = 1200, 628

# ================================
# Parse the KML File
# ================================
def parse_kml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

    taxiways = []
    gates = []

    for placemark in root.findall('.//kml:Placemark', namespace):
        # Extract LineStrings (taxiways and runways)
        line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
        if line_string is not None:
            line_coords = line_string.text.strip().split()
            path = []
            for coord in line_coords:
                lon, lat, _ = map(float, coord.split(','))
                path.append((lon, lat))
            taxiway = {'path': path}
            name = placemark.find('kml:name', namespace)
            if name is not None:
                placemark_name = name.text.strip()
                taxiway['name'] = placemark_name
            taxiways.append(taxiway)

        # Extract Points (gates)
        point = placemark.find('.//kml:Point/kml:coordinates', namespace)
        if point is not None:
            coord = point.text.strip().split(',')
            lon, lat, _ = map(float, coord)
            gates.append({'position': (lon, lat)})

    return taxiways, gates

# ================================
# Build the NetworkX Graph
# ================================
def build_graph(taxiways, gates, width, height):
    all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
    all_gate_coords = [gate['position'] for gate in gates]
    all_coords = all_taxiway_coords + all_gate_coords

    lon_min = min(coord[0] for coord in all_coords)
    lon_max = max(coord[0] for coord in all_coords)
    lat_min = min(coord[1] for coord in all_coords)
    lat_max = max(coord[1] for coord in all_coords)

    margin = 0.05
    lon_range = lon_max - lon_min
    lat_range = lat_max - lat_min
    lon_min -= lon_range * margin
    lon_max += lon_range * margin
    lat_min -= lat_range * margin
    lat_max += lat_range * margin

    def convert_coords(lon, lat):
        x = (lon - lon_min) / (lon_max - lon_min) * width
        y = height - (lat - lat_min) / (lat_max - lat_min) * height
        return np.array([x, y])

    for taxiway in taxiways:
        pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
        taxiway['pixel_path'] = pixel_path

    for gate in gates:
        gate['pixel_position'] = convert_coords(*gate['position'])

    G = nx.Graph()
    node_id_counter = 0
    node_positions = {}
    for idx, taxiway in enumerate(taxiways):
        path = taxiway['pixel_path']
        taxiway_name = taxiway.get('name', '')
        taxiway_nodes = []
        for i, point in enumerate(path):
            node_id = node_id_counter
            node_id_counter += 1
            G.add_node(node_id, pos=point)
            G.nodes[node_id]['taxiway_name'] = taxiway_name
            node_positions[node_id] = point
            taxiway_nodes.append(node_id)
            if i > 0:
                prev_node_id = taxiway_nodes[i - 1]
                G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
        taxiway['node_ids'] = taxiway_nodes

    # Ensure all edges have a weight of 1
    for edge in G.edges():
        G[edge[0]][edge[1]]['weight'] = 1

    return G, node_positions, convert_coords

# ================================
# Custom Multi-Agent Environment
# ================================
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, config, callback=None):
        super().__init__()
        self.graph = config["graph"]
        self.total_agents = config["num_agents"]
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}
        self.destinations = {agent: None for agent in self.agents}
        self.callback = callback

        self.width, self.height = WIDTH, HEIGHT
        self.screen = None

        # Define observation and action spaces
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

        # Predefined gates and runway endpoints for agents to start and end
        self.gate_coordinates = [
            (77.71046165300096, 13.20355775032989),
            (77.71066072998956, 13.20166801620613),
            (77.70315360361252, 13.20165318995302),
            (77.71305689010458, 13.201637816132),
            (77.70195813939766, 13.20169406641297),
            (77.71149825860202, 13.20165032306983),
            (77.72279066770344, 13.19968338101175),
            (77.7132055646255, 13.20167917723071),
            (77.7089924860226, 13.20357466411958),
            (77.71648635375834, 13.20336974504588)
        ]

        self.runway_endpoints = [
            (77.68686735208298, 13.20718308006773),
            (77.7222951686759, 13.20687066472886),
            (77.69060216489893, 13.18975920793089),
            (77.72642499411846, 13.18944676842937)
        ]

        # Pygame initialization
        pygame.init()
        self.screen = pygame.display.set_mode((self.width, self.height))
        pygame.display.set_caption("Airport Taxiway Management")
        self.clock = pygame.time.Clock()

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        # Flatten the list of coordinates for use in np.random.choice
        all_coordinates = self.gate_coordinates + self.runway_endpoints

        for agent in self.agents:
            start_coord = all_coordinates[np.random.choice(len(all_coordinates))]
            dest_coord = all_coordinates[np.random.choice(len(all_coordinates))]
            while dest_coord == start_coord:
                dest_coord = all_coordinates[np.random.choice(len(all_coordinates))]

            # Convert start and destination coordinates to node positions
            start_pos = self._convert_coords(*start_coord)
            dest_pos = self._convert_coords(*dest_coord)

            # Find the closest node to the start and destination positions
            start_node = self._find_closest_node(start_pos)
            dest_node = self._find_closest_node(dest_pos)

            self.pos[agent] = start_node
            self.destinations[agent] = dest_node
            self.distance_travelled[agent] = 0

        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}

        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        # Render the environment state after reset
        self.render()

        return obs, {}

    def _convert_coords(self, lon, lat):
        lon_min, lon_max, lat_min, lat_max = self._get_bounds()
        x = (lon - lon_min) / (lon_max - lon_min) * self.width
        y = self.height - (lat - lat_min) / (lat_max - lat_min) * self.height
        return np.array([x, y])

    def _get_bounds(self):
        all_coords = self.gate_coordinates + self.runway_endpoints
        lon_min = min(coord[0] for coord in all_coords)
        lon_max = max(coord[0] for coord in all_coords)
        lat_min = min(coord[1] for coord in all_coords)
        lat_max = max(coord[1] for coord in all_coords)
        return lon_min, lon_max, lat_min, lat_max

    def _find_closest_node(self, pos):
        closest_node = None
        min_distance = float('inf')
        for node, data in self.graph.nodes(data=True):
            node_pos = data['pos']
            dist = np.linalg.norm(pos - node_pos)
            if dist < min_distance:
                closest_node = node
                min_distance = dist
        return closest_node

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += self.graph[current_node][next_node]['weight']

                # Reward for moving towards the destination
                if next_node == self.destinations[agent]:
                    rewards[agent] += 100  # High reward for reaching the destination
                    dones[agent] = True
                    self.done_agents.add(agent)
                else:
                    rewards[agent] += 1  # Reduced positive reward for moving towards the destination
                    rewards[agent] -= 0.5  # Small negative reward for taking a longer path
            else:
                rewards[agent] -= 1  # Penalty for invalid action

        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                # Collision occurred
                rewards[agent] -= 50  # High penalty for collision
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 50
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True

        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}

        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        # Render the environment state after each step
        self.render()

        return obs, rewards, dones, truncateds, infos

    def render(self):
        # Handle Pygame events to prevent the window from hanging
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        # Draw the graph
        self.screen.fill((0, 0, 0))  # Black background

        # Draw edges
        for edge in self.graph.edges():
            start_pos = self.graph.nodes[edge[0]]['pos']
            end_pos = self.graph.nodes[edge[1]]['pos']
            pygame.draw.line(self.screen, (0, 0, 255), start_pos, end_pos, 2)  # Blue for edges

        # Draw agents
        for agent, node_id in self.pos.items():
            if node_id is not None:
                pos = self.graph.nodes[node_id]['pos']
                if agent.startswith('car') and self.pos[agent] in [self._find_closest_node(self._convert_coords(*coord)) for coord in self.gate_coordinates]:
                    pygame.draw.circle(self.screen, (0, 255, 0), (int(pos[0]), int(pos[1])), 5)  # Green for agents originating from gates
            elif agent.startswith('car') and self.pos[agent] in [self._find_closest_node(self._convert_coords(*coord)) for coord in self.runway_endpoints]:
                pygame.draw.circle(self.screen, (255, 165, 0), (int(pos[0]), int(pos[1])), 5)  # Orange for agents originating from runways  # Reduced size for agents  # Red for agents

        pygame.display.flip()
        self.clock.tick(60)  # Cap at 60 frames per second

# ================================
# Main Function
# ================================
if __name__ == "__main__":
    # Parse KML and Build Graph
    file_path = "reduced_nodes.kml"  # Update this path to your KML file
    taxiways, gates = parse_kml(file_path)
    G, node_positions, convert_coords = build_graph(taxiways, gates, WIDTH, HEIGHT)

    # Initialize Ray
    ray.init(ignore_reinit_error=True, log_to_driver=True)

    # Register the Environment
    from ray.tune.registry import register_env

    def env_creator(env_config):
        return RoadIntersectionEnv(env_config)

    register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

    # RLlib Training Configuration
    config = {
        "env": "RoadIntersectionEnv",
        "env_config": {
            "graph": G,
            "num_agents": 20
        },
        "framework": "torch",
        "num_workers": 1,
        "num_gpus": 1,
        "train_batch_size": 4000,
        "sgd_minibatch_size": 128,
        "lr": 1e-3,
        "gamma": 0.99,
        "log_level": "WARN",
    }

    # Train the model
    tune.run(
        "PPO",
        config=config,
        stop={"training_iteration": 50},
        checkpoint_freq=5,
        checkpoint_at_end=True,
        verbose=1,
        storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints"  # Save checkpoints to this directory
    )
    
    # Load from a checkpoint and evaluate
    checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
    ppo_trainer = PPO(config=config)
    ppo_trainer.restore(checkpoint_path)
    
    # Create environment for evaluation
    env = RoadIntersectionEnv(config["env_config"])
    obs = env.reset()
    done = {"__all__": False}
    while not done["__all__"]:
        action_dict = {}
        for agent_id, agent_obs in obs.items():
            action = ppo_trainer.compute_single_action(agent_obs, policy_id="default_policy")
            action_dict[agent_id] = action
        obs, rewards, dones, truncateds, infos = env.step(action_dict)
        done = dones
    
    # Clean up
    ray.shutdown()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-12-02 23:03:11</td></tr>
# <tr><td>Running for: </td><td>00:07:16.47        </td></tr>
# <tr><td>Memory:      </td><td>17.0/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_7c60e_00000</td><td>RUNNING </td><td>127.0.0.1:34216</td><td style="text-align: right;">     3</td><td style="text-align: right;">         363.828</td><td style="text-align: right;">   0</td><td style="text-align: right;">                    1</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (RolloutWorker pid=3584) 2024-12-02 22:56:25,067	WARNING deprecation.py:50 -- DeprecationWarning: `get_agent_ids` has been deprecated. Use `MultiAgentEnv.possible_agents` instead. This will raise an error in the future!
# (PPO pid=34216) Trainable.setup took 23.817 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=34216) Install gputil for GPU system monitoring.
# (PPO pid=34216) 2024-12-02 22:57:34,266	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (PPO pid=34216) 2024-12-02 22:59:35,605	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (PPO pid=34216) 2024-12-02 23:01:37,385	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2024-12-02 23:03:11,278	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-12-02 23:03:11,308	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-12-02_22-55-54' in 0.0292s.
# 2024-12-02 23:03:20,450	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::PPO.train() (pid=34216, ip=127.0.0.1, actor_id=c2564ed920437468edcefc3c01000000, repr=PPO)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1803, in ray._raylet.execute_task.function_executor
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py", line 328, in train
#     result = self.step()
#              ^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 934, in step
#     train_results, train_iter_ctx = self._run_one_training_iteration()
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 3528, in _run_one_training_iteration
#     training_step_results = self.training_step()
#                             ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 410, in training_step
#     return self._training_step_old_api_stack()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 521, in _training_step_old_api_stack
#     train_batch = synchronous_parallel_sample(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sampled_data = worker_set.foreach_worker(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py", line 909, in foreach_worker
#     FaultTolerantActorManager.handle_remote_call_result_errors(
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 638, in handle_remote_call_result_errors
#     raise result_or_error.get()
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 792, in _fetch_result
#     result = ray.get(ready)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 2745, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 903, in get_objects
#     raise value
# ray.exceptions.ActorDiedError: The actor died unexpectedly before finishing this task.
# 	class_name: RolloutWorker
# 	actor_id: 03f6cbc2754bef6216cd55f301000000
# 	pid: 3584
# 	namespace: a6bdb74e-072c-40bc-af7d-d62ed14f0743
# 	ip: 127.0.0.1
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
# (PPO pid=34216) 2024-12-02 23:03:20,428	ERROR actor_manager.py:804 -- Ray error (The actor died unexpectedly before finishing this task.
# (PPO pid=34216) 	class_name: RolloutWorker
# (PPO pid=34216) 	actor_id: 03f6cbc2754bef6216cd55f301000000
# (PPO pid=34216) 	pid: 3584
# (PPO pid=34216) 	namespace: a6bdb74e-072c-40bc-af7d-d62ed14f0743
# (PPO pid=34216) 	ip: 127.0.0.1
# (PPO pid=34216) The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.), taking actor 1 out of service.
# 2024-12-02 23:03:20,533	INFO tune.py:1041 -- Total run time: 445.81 seconds (436.44 seconds for the tuning loop).
# 2024-12-02 23:03:20,534	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
# (raylet) A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffff03f6cbc2754bef6216cd55f301000000 Worker ID: d18df3174cf3a852925c458a214a450294887c18c5994577275f69f3 Node ID: 7f24177ba8a519b84d016cf27ce48afa2709d031a9b2af7d79d40190 Worker IP address: 127.0.0.1 Worker port: 61442 Worker PID: 3584 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
# (PPO pid=34216) 2024-12-02 23:03:20,526	ERROR env_runner_group.py:825 -- Failed to stop workers!
# (PPO pid=34216) Traceback (most recent call last):
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py", line 821, in stop
# (PPO pid=34216)     self.foreach_worker(
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py", line 909, in foreach_worker
# (PPO pid=34216)     FaultTolerantActorManager.handle_remote_call_result_errors(
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 638, in handle_remote_call_result_errors
# (PPO pid=34216)     raise result_or_error.get()
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 792, in _fetch_result
# (PPO pid=34216)     result = ray.get(ready)
# (PPO pid=34216)              ^^^^^^^^^^^^^^
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (PPO pid=34216)     return fn(*args, **kwargs)
# (PPO pid=34216)            ^^^^^^^^^^^^^^^^^^^
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (PPO pid=34216)     return func(*args, **kwargs)
# (PPO pid=34216)            ^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 2745, in get
# (PPO pid=34216)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (PPO pid=34216)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (PPO pid=34216)   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 903, in get_objects
# (PPO pid=34216)     raise value
# (PPO pid=34216) ray.exceptions.ActorDiedError: The actor died unexpectedly before finishing this task.
# (PPO pid=34216) 	class_name: RolloutWorker
# (PPO pid=34216) 	actor_id: 03f6cbc2754bef6216cd55f301000000
# (PPO pid=34216) 	pid: 3584
# (PPO pid=34216) 	namespace: a6bdb74e-072c-40bc-af7d-d62ed14f0743
# (PPO pid=34216) 	ip: 127.0.0.1
# (PPO pid=34216) The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 375
#     373 # Load from a checkpoint and evaluate
#     374 checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
# --> 375 ppo_trainer = PPO(config=config)
#     376 ppo_trainer.restore(checkpoint_path)
#     378 # Create environment for evaluation
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:584, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     581 # Evaluation EnvRunnerGroup and metrics last returned by `self.evaluate()`.
#     582 self.eval_env_runner_group: Optional[EnvRunnerGroup] = None
# --> 584 super().__init__(
#     585     config=config,
#     586     logger_creator=logger_creator,
#     587     **kwargs,
#     588 )
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py:158, in Trainable.__init__(self, config, logger_creator, storage)
#     154     logger.debug(f"StorageContext on the TRAINABLE:\n{storage}")
#     156 self._open_logfiles(stdout_file, stderr_file)
# --> 158 self.setup(copy.deepcopy(self.config))
#     159 setup_time = time.time() - self._start_time
#     160 if setup_time > SETUP_TIME_THRESHOLD:
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py:670, in Algorithm.setup(self, config)
#     667     self.config.off_policy_estimation_methods = ope_dict
#     669 # Create a set of env runner actors via a EnvRunnerGroup.
# --> 670 self.env_runner_group = EnvRunnerGroup(
#     671     env_creator=self.env_creator,
#     672     validate_env=self.validate_env,
#     673     default_policy_class=self.get_default_policy_class(self.config),
#     674     config=self.config,
#     675     num_env_runners=(
#     676         0
#     677         if (
#     678             self.config.input_
#     679             and (
#     680                 isinstance(self.config.input_, str)
#     681                 or (
#     682                     isinstance(self.config.input_, list)
#     683                     and isinstance(self.config.input_[0], str)
#     684                 )
#     685             )
#     686             and self.config.input_ != "sampler"
#     687             and self.config.enable_rl_module_and_learner
#     688         )
#     689         else self.config.num_env_runners
#     690     ),
#     691     local_env_runner=True,
#     692     logdir=self.logdir,
#     693     tune_trial_id=self.trial_id,
#     694 )
#     696 # If an input path is available and we are on the new API stack generate
#     697 # an `OfflineData` instance.
#     698 if (
#     699     self.config.input_
#     700     and (
#    (...)
#     708     and self.config.enable_rl_module_and_learner
#     709 ):
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py:194, in EnvRunnerGroup.__init__(self, env_creator, validate_env, default_policy_class, config, num_env_runners, local_env_runner, logdir, _setup, tune_trial_id, num_workers, local_worker)
#     192 if _setup:
#     193     try:
# --> 194         self._setup(
#     195             validate_env=validate_env,
#     196             config=config,
#     197             num_env_runners=num_env_runners,
#     198             local_env_runner=local_env_runner,
#     199         )
#     200     # EnvRunnerGroup creation possibly fails, if some (remote) workers cannot
#     201     # be initialized properly (due to some errors in the EnvRunners's
#     202     # constructor).
#     203     except RayActorError as e:
#     204         # In case of an actor (remote worker) init failure, the remote worker
#     205         # may still exist and will be accessible, however, e.g. calling
#     206         # its `sample.remote()` would result in strange "property not found"
#     207         # errors.
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py:264, in EnvRunnerGroup._setup(self, validate_env, config, num_env_runners, local_env_runner)
#     261     self._ds_shards = None
#     263 # Create a number of @ray.remote workers.
# --> 264 self.add_workers(
#     265     num_env_runners,
#     266     validate=config.validate_env_runners_after_construction,
#     267 )
#     269 # If num_env_runners > 0 and we don't have an env on the local worker,
#     270 # get the observation- and action spaces for each policy from
#     271 # the first remote worker (which does have an env).
#     272 if (
#     273     local_env_runner
#     274     and self._worker_manager.num_actors() > 0
#    (...)
#     277     and (not config.observation_space or not config.action_space)
#     278 ):
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py:791, in EnvRunnerGroup.add_workers(self, num_workers, validate)
#     788 # Validate here, whether all remote workers have been constructed properly
#     789 # and are "up and running". Establish initial states.
#     790 if validate:
# --> 791     for result in self._worker_manager.foreach_actor(
#     792         lambda w: w.assert_healthy()
#     793     ):
#     794         # Simiply raise the error, which will get handled by the try-except
#     795         # clause around the _setup().
#     796         if not result.ok:
#     797             e = result.get()
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py:452, in FaultTolerantActorManager.foreach_actor(self, func, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     446 remote_calls = self._call_actors(
#     447     func=func,
#     448     remote_actor_ids=remote_actor_ids,
#     449 )
#     451 # Collect remote request results (if available given timeout and/or errors).
# --> 452 _, remote_results = self._fetch_result(
#     453     remote_actor_ids=remote_actor_ids,
#     454     remote_calls=remote_calls,
#     455     tags=[None] * len(remote_calls),
#     456     timeout_seconds=timeout_seconds,
#     457     return_obj_refs=return_obj_refs,
#     458     mark_healthy=mark_healthy,
#     459 )
#     461 return remote_results
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py:770, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     767 if not remote_calls:
#     768     return [], RemoteCallResults()
# --> 770 readies, _ = ray.wait(
#     771     remote_calls,
#     772     num_returns=len(remote_calls),
#     773     timeout=timeout,
#     774     # Make sure remote results are fetched locally in parallel.
#     775     fetch_local=not return_obj_refs,
#     776 )
#     778 # Remote data should already be fetched to local object store at this point.
#     779 remote_results = RemoteCallResults()
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\_private\auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\_private\client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py:2976, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    2974 timeout = timeout if timeout is not None else 10**6
#    2975 timeout_milliseconds = int(timeout * 1000)
# -> 2976 ready_ids, remaining_ids = worker.core_worker.wait(
#    2977     ray_waitables,
#    2978     num_returns,
#    2979     timeout_milliseconds,
#    2980     worker.current_task_id,
#    2981     fetch_local,
#    2982 )
#    2983 return ready_ids, remaining_ids
#
# File python\ray\_raylet.pyx:3816, in ray._raylet.CoreWorker.wait()
#
# File python\ray\includes/common.pxi:79, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
import numpy as np
import networkx as nx
import gymnasium as gym
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPOConfig, PPO
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import sys
import os
import xml.etree.ElementTree as ET
import re
import pygame

os.environ["CUDA_VISIBLE_DEVICES"] = "0" #To be able to call the GPU later in the code


def distance(p1, p2):
    return np.linalg.norm(p1 - p2)

WIDTH, HEIGHT = 1200, 628

'''
-----------------------------------------------------------------------------------------------------------------------------
PARSING THE KML FILE & BUILDING THE GRAPH: 
-----------------------------------------------------------------------------------------------------------------------------
The below function parses a kml file and gets geographical information. This geographical information is then converted to
pixel coordinates. These pixel coordinates are used to then make points of a graph, generated through networkx, the points
are appended to the graph. This graph now stands for the scaled version of the actual airport floor, it is represented by an
adjacency matrix. All edges in the graph have been assigned a weight of '1' for the sake of computational simplicity. 
-----------------------------------------------------------------------------------------------------------------------------
'''
def parse_kml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {'kml': 'http://www.opengis.net/kml/2.2'}

    taxiways = []
    gates = []

    for placemark in root.findall('.//kml:Placemark', namespace):
        # Extract LineStrings (taxiways and runways)
        line_string = placemark.find('.//kml:LineString/kml:coordinates', namespace)
        if line_string is not None:
            line_coords = line_string.text.strip().split()
            path = []
            for coord in line_coords:
                lon, lat, _ = map(float, coord.split(','))
                path.append((lon, lat))
            taxiway = {'path': path}
            name = placemark.find('kml:name', namespace)
            if name is not None:
                placemark_name = name.text.strip()
                taxiway['name'] = placemark_name
            taxiways.append(taxiway)

        point = placemark.find('.//kml:Point/kml:coordinates', namespace)
        if point is not None:
            coord = point.text.strip().split(',')
            lon, lat, _ = map(float, coord)
            gates.append({'position': (lon, lat)})

    return taxiways, gates


def build_graph(taxiways, gates, width, height):
    all_taxiway_coords = [coord for taxiway in taxiways for coord in taxiway['path']]
    all_gate_coords = [gate['position'] for gate in gates]
    all_coords = all_taxiway_coords + all_gate_coords

    lon_min = min(coord[0] for coord in all_coords)
    lon_max = max(coord[0] for coord in all_coords)
    lat_min = min(coord[1] for coord in all_coords)
    lat_max = max(coord[1] for coord in all_coords)

    margin = 0.05
    lon_range = lon_max - lon_min
    lat_range = lat_max - lat_min
    lon_min -= lon_range * margin
    lon_max += lon_range * margin
    lat_min -= lat_range * margin
    lat_max += lat_range * margin

    def convert_coords(lon, lat):
        x = (lon - lon_min) / (lon_max - lon_min) * width
        y = height - (lat - lat_min) / (lat_max - lat_min) * height
        return np.array([x, y])

    for taxiway in taxiways:
        pixel_path = [convert_coords(lon, lat) for lon, lat in taxiway['path']]
        taxiway['pixel_path'] = pixel_path

    for gate in gates:
        gate['pixel_position'] = convert_coords(*gate['position'])

    G = nx.Graph()
    node_id_counter = 0
    node_positions = {}
    for idx, taxiway in enumerate(taxiways):
        path = taxiway['pixel_path']
        taxiway_name = taxiway.get('name', '')
        taxiway_nodes = []
        for i, point in enumerate(path):
            node_id = node_id_counter
            node_id_counter += 1
            G.add_node(node_id, pos=point)
            G.nodes[node_id]['taxiway_name'] = taxiway_name
            node_positions[node_id] = point
            taxiway_nodes.append(node_id)
            if i > 0:
                prev_node_id = taxiway_nodes[i - 1]
                G.add_edge(prev_node_id, node_id, weight=distance(point, node_positions[prev_node_id]))
        taxiway['node_ids'] = taxiway_nodes

    for edge in G.edges():
        G[edge[0]][edge[1]]['weight'] = 1

    return G, node_positions, convert_coords


'''
-----------------------------------------------------------------------------------------------------------------------------
THE ENVIRONMENT: 
-----------------------------------------------------------------------------------------------------------------------------
Below is the environment that the agents move around in. The environment stores the agent parameters of position,
observation space and action space. Rewards are being assigned for collisions and arrival at destination as 
expected. However, there is a nominal small negative reward to ensure that planes always resort to taking the shortest path. 
Reset function positions the agents at their assigned starting points and they can run another episode. The rendering is done
through pygame here for real time training visualisation.
-----------------------------------------------------------------------------------------------------------------------------
'''
class RoadIntersectionEnv(MultiAgentEnv):
    def __init__(self, config, callback=None):
        super().__init__()
        self.graph = config["graph"]
        self.total_agents = config["num_agents"]
        self.agents = [f"car_{i}" for i in range(self.total_agents)]
        self.pos = {agent: None for agent in self.agents}
        self.distance_travelled = {agent: 0 for agent in self.agents}
        self.destinations = {agent: None for agent in self.agents}
        self.callback = callback
        self.width, self.height = 1200, 628
        self.screen = None
        self.observation_space = spaces.Discrete(len(self.graph.nodes))
        self.action_space = spaces.Discrete(len(self.graph.nodes))

        self.gate_coordinates = [
            (77.71046165300096, 13.20355775032989),
            (77.71066072998956, 13.20166801620613),
            (77.70315360361252, 13.20165318995302),
            (77.71305689010458, 13.201637816132),
            (77.70195813939766, 13.20169406641297),
            (77.71149825860202, 13.20165032306983),
            (77.72279066770344, 13.19968338101175),
            (77.7132055646255, 13.20167917723071),
            (77.7089924860226, 13.20357466411958),
            (77.71648635375834, 13.20336974504588)
        ]

        self.runway_endpoints = [
            (77.68686735208298, 13.20718308006773),
            (77.7222951686759, 13.20687066472886),
            (77.69060216489893, 13.18975920793089),
            (77.72642499411846, 13.18944676842937)
        ]

        pygame.init()
        self.screen = pygame.display.set_mode((self.width, self.height))
        pygame.display.set_caption("Airport Taxiway Management")
        self.clock = pygame.time.Clock()

    def reset(self, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)

        all_coordinates = self.gate_coordinates + self.runway_endpoints

        for agent in self.agents:
            start_coord = all_coordinates[np.random.choice(len(all_coordinates))]
            dest_coord = all_coordinates[np.random.choice(len(all_coordinates))]
            while dest_coord == start_coord:
                dest_coord = all_coordinates[np.random.choice(len(all_coordinates))]


            start_pos = self._convert_coords(*start_coord)
            dest_pos = self._convert_coords(*dest_coord)


            start_node = self._find_closest_node(start_pos)
            dest_node = self._find_closest_node(dest_pos)

            self.pos[agent] = start_node
            self.destinations[agent] = dest_node
            self.distance_travelled[agent] = 0

        self.done_agents = set()
        obs = {agent: self.pos[agent] for agent in self.agents}

        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})


        self.render()

        return obs, {}

    def _convert_coords(self, lon, lat):
        lon_min, lon_max, lat_min, lat_max = self._get_bounds()
        x = (lon - lon_min) / (lon_max - lon_min) * self.width
        y = self.height - (lat - lat_min) / (lat_max - lat_min) * self.height
        return np.array([x, y])

    def _get_bounds(self):
        all_coords = self.gate_coordinates + self.runway_endpoints
        lon_min = min(coord[0] for coord in all_coords)
        lon_max = max(coord[0] for coord in all_coords)
        lat_min = min(coord[1] for coord in all_coords)
        lat_max = max(coord[1] for coord in all_coords)
        return lon_min, lon_max, lat_min, lat_max

    def _find_closest_node(self, pos):
        closest_node = None
        min_distance = float('inf')
        for node, data in self.graph.nodes(data=True):
            node_pos = data['pos']
            dist = np.linalg.norm(pos - node_pos)
            if dist < min_distance:
                closest_node = node
                min_distance = dist
        return closest_node

    def step(self, action_dict):
        rewards = {agent: 0 for agent in self.agents}
        dones = {agent: False for agent in self.agents}
        infos = {}
        truncateds = {agent: False for agent in self.agents}

        for agent, action in action_dict.items():
            if agent in self.done_agents:
                continue

            current_node = self.pos[agent]
            next_node = action

            if current_node in self.graph and next_node in self.graph[current_node]:
                self.pos[agent] = next_node
                self.distance_travelled[agent] += self.graph[current_node][next_node]['weight']

n
                if next_node == self.destinations[agent]:
                    rewards[agent] += 100  
                    dones[agent] = True
                    self.done_agents.add(agent)
                else:
                    rewards[agent] += 1  
                    rewards[agent] -= 0.5  
            else:
                rewards[agent] -= 1  

        occupied_nodes = {}
        for agent in self.agents:
            if agent in self.done_agents:
                continue

            pos = self.pos[agent]
            if pos not in occupied_nodes:
                occupied_nodes[pos] = agent
            else:
                rewards[agent] -= 50  
                other_agent = occupied_nodes[pos]
                rewards[other_agent] -= 50
                dones[agent] = True
                dones[other_agent] = True
                self.done_agents.add(agent)
                self.done_agents.add(other_agent)

        for agent in self.agents:
            if agent not in self.done_agents:
                dones[agent] = False
            else:
                dones[agent] = True
                truncateds[agent] = True

        all_done = len(self.done_agents) == self.total_agents
        dones['__all__'] = all_done
        truncateds['__all__'] = all_done

        obs = {agent: self.pos[agent] for agent in self.agents if agent not in self.done_agents}
        infos = {agent: {} for agent in self.agents if agent not in self.done_agents}

        if self.callback:
            self.callback.update_positions(self.graph, {agent: self.graph.nodes[self.pos[agent]]['pos'] for agent in self.agents})

        self.render()

        return obs, rewards, dones, truncateds, infos

    def render(self):
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        self.screen.fill((0, 0, 0)) 

        for edge in self.graph.edges():
            start_pos = self.graph.nodes[edge[0]]['pos']
            end_pos = self.graph.nodes[edge[1]]['pos']
            pygame.draw.line(self.screen, (0, 0, 255), start_pos, end_pos, 2)  # Blue for edges

        for agent, node_id in self.pos.items():
            if node_id is not None:
                pos = self.graph.nodes[node_id]['pos']
                if agent.startswith('car') and self.pos[agent] in [self._find_closest_node(self._convert_coords(*coord)) for coord in self.gate_coordinates]:
                    pygame.draw.circle(self.screen, (0, 255, 0), (int(pos[0]), int(pos[1])), 5)  # Green for agents originating from gates
            elif agent.startswith('car') and self.pos[agent] in [self._find_closest_node(self._convert_coords(*coord)) for coord in self.runway_endpoints]:
                pygame.draw.circle(self.screen, (255, 165, 0), (int(pos[0]), int(pos[1])), 5)  # Orange for agents originating from runways  # Reduced size for agents  # Red for agents

        # for gate in self.gate_coordinates:
        #     gate_pos = self._convert_coords(*gate)
        #     pygame.draw.rect(self.screen, (255, 20, 147), (gate_pos[0] - 3, gate_pos[1] - 3, 6, 6))  # Pink square for gates
        # for runway in self.runway_endpoints:
        #     runway_pos = self._convert_coords(*runway)
        #     pygame.draw.rect(self.screen, (255, 20, 147), (runway_pos[0] - 3, runway_pos[1] - 3, 6, 6))  # Pink square for runways

        pygame.display.flip()
        self.clock.tick(60)  # Cap at 60 frames per second

'''
-----------------------------------------------------------------------------------------------------------------------------
CONFIGURING THE MODEL AND TRAINING: 
-----------------------------------------------------------------------------------------------------------------------------
In the main function below, the learning algorithm chosen is PPO or proximal policy optimization. The trainer is configured 
to train with certain optimizations and parameters under consideration. This section also loads checkpoints from previous
training instances and proceeds training from there, the trainer is half-immune to change in configurations.
-----------------------------------------------------------------------------------------------------------------------------
'''
if __name__ == "__main__":
    # Parse KML and Build Graph
    file_path = "reduced_nodes.kml"  # Update this path to your KML file
    taxiways, gates = parse_kml(file_path)
    G, node_positions, convert_coords = build_graph(taxiways, gates, WIDTH, HEIGHT)

    # Initialize Ray
    ray.init(ignore_reinit_error=True, log_to_driver=True, num_gpus=1)

    # Register the Environment
    from ray.tune.registry import register_env

    def env_creator(env_config):
        return RoadIntersectionEnv(env_config)

    register_env("RoadIntersectionEnv", lambda env_config: env_creator(env_config))

    # RLlib Training Configuration
    config = {
        "env": "RoadIntersectionEnv",
        "env_config": {
            "graph": G,
            "num_agents": 10
        },
        "framework": "torch",
        "num_workers": 1,
        "num_gpus": 1,
        "train_batch_size": 4000,
        "sgd_minibatch_size": 128,
        "lr": 1e-3,
        "gamma": 0.99,
        "log_level": "WARN",
    }

    # Train the model
    tune.run(
        "PPO",
        config=config,
        stop={"training_iteration": 15},
        checkpoint_freq=5,
        checkpoint_at_end=True,
        verbose=1,
        storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints"  # Save checkpoints to this directory
    )
    
    # Load from a checkpoint and evaluate
    checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
    ppo_trainer = PPO(config=config)
    ppo_trainer.restore(checkpoint_path)
    
    # Create environment for evaluation
    env = RoadIntersectionEnv(config["env_config"])
    obs = env.reset()
    done = {"__all__": False}
    while not done["__all__"]:
        action_dict = {}
        for agent_id, agent_obs in obs.items():
            action = ppo_trainer.compute_single_action(agent_obs, policy_id="default_policy")
            action_dict[agent_id] = action
        obs, rewards, dones, truncateds, infos = env.step(action_dict)
        done = dones
    
    # Clean up
    ray.shutdown()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-12-03 00:14:17</td></tr>
# <tr><td>Running for: </td><td>00:05:05.25        </td></tr>
# <tr><td>Memory:      </td><td>15.7/23.4 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name                         </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_b94b8_00000</td><td style="text-align: right;">           1</td><td>C:/Users/aniru/AppData/Local/Temp/ray/session_2024-12-03_00-04-19_473671_30852/artifacts/2024-12-03_00-09-11/PPO_2024-12-03_00-09-11/driver_artifacts/PPO_RoadIntersectionEnv_b94b8_00000_0_2024-12-03_00-09-12/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                         </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_RoadIntersectionEnv_b94b8_00000</td><td>ERROR   </td><td>127.0.0.1:21000</td><td style="text-align: right;">     2</td><td style="text-align: right;">         242.353</td><td style="text-align: right;">   0</td><td style="text-align: right;">                    1</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (RolloutWorker pid=19192) 2024-12-03 00:09:43,364	WARNING deprecation.py:50 -- DeprecationWarning: `get_agent_ids` has been deprecated. Use `MultiAgentEnv.possible_agents` instead. This will raise an error in the future!
# (PPO pid=21000) Trainable.setup took 21.531 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=21000) Install gputil for GPU system monitoring.
# (PPO pid=21000) 2024-12-03 00:10:50,967	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# (PPO pid=21000) 2024-12-03 00:12:52,202	WARNING rollout_ops.py:115 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2024-12-03 00:14:17,218	ERROR tune_controller.py:1331 -- Trial task failed for trial PPO_RoadIntersectionEnv_b94b8_00000
# Traceback (most recent call last):
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 2745, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 901, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ActorDiedError): ray::PPO.train() (pid=21000, ip=127.0.0.1, actor_id=28cdbe07f32a01d802e61a1601000000, repr=PPO)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1803, in ray._raylet.execute_task.function_executor
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\tune\trainable\trainable.py", line 328, in train
#     result = self.step()
#              ^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 934, in step
#     train_results, train_iter_ctx = self._run_one_training_iteration()
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 3528, in _run_one_training_iteration
#     training_step_results = self.training_step()
#                             ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 410, in training_step
#     return self._training_step_old_api_stack()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 521, in _training_step_old_api_stack
#     train_batch = synchronous_parallel_sample(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sampled_data = worker_set.foreach_worker(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\env\env_runner_group.py", line 909, in foreach_worker
#     FaultTolerantActorManager.handle_remote_call_result_errors(
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 638, in handle_remote_call_result_errors
#     raise result_or_error.get()
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 792, in _fetch_result
#     result = ray.get(ready)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 2745, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\aniru\miniconda3\envs\env1\Lib\site-packages\ray\_private\worker.py", line 903, in get_objects
#     raise value
# ray.exceptions.ActorDiedError: The actor died unexpectedly before finishing this task.
# 	class_name: RolloutWorker
# 	actor_id: c32a4a41b5a80be0c293732b01000000
# 	pid: 19192
# 	namespace: 2d246691-e6c6-477d-a56d-1628a2004bf1
# 	ip: 127.0.0.1
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
# (PPO pid=21000) 2024-12-03 00:14:17,192	ERROR actor_manager.py:804 -- Ray error (The actor died unexpectedly before finishing this task.
# (PPO pid=21000) 	class_name: RolloutWorker
# (PPO pid=21000) 	actor_id: c32a4a41b5a80be0c293732b01000000
# (PPO pid=21000) 	pid: 19192
# (PPO pid=21000) 	namespace: 2d246691-e6c6-477d-a56d-1628a2004bf1
# (PPO pid=21000) 	ip: 127.0.0.1
# (PPO pid=21000) The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.), taking actor 1 out of service.
# 2024-12-03 00:14:17,255	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints/PPO_2024-12-03_00-09-11' in 0.0256s.
# (raylet) A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffffc32a4a41b5a80be0c293732b01000000 Worker ID: da4707a34c84651876eeaf6193a7d694d4d02939a1a76647b191cbc8 Node ID: 01ebf7c62a9468fbda2fc231b02af51c88868f3f05d8285fd4ab2d4d Worker IP address: 127.0.0.1 Worker port: 62701 Worker PID: 19192 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[2], line 373
#     356 config = {
#     357     "env": "RoadIntersectionEnv",
#     358     "env_config": {
#    (...)
#     369     "log_level": "WARN",
#     370 }
#     372 # Train the model
# --> 373 tune.run(
#     374     "PPO",
#     375     config=config,
#     376     stop={"training_iteration": 15},
#     377     checkpoint_freq=5,
#     378     checkpoint_at_end=True,
#     379     verbose=1,
#     380     storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints"  # Save checkpoints to this directory
#     381 )
#     383 # Load from a checkpoint and evaluate
#     384 checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
#
# File ~\miniconda3\envs\env1\Lib\site-packages\ray\tune\tune.py:1035, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1033 if incomplete_trials:
#    1034     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1035         raise TuneError("Trials did not complete", incomplete_trials)
#    1036     else:
#    1037         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [PPO_RoadIntersectionEnv_b94b8_00000])

# %%
# D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints
#D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029


'''
    tune.run(
        "PPO",
        config=config,
        stop={"training_iteration": 50},
        checkpoint_freq=5,
        checkpoint_at_end=True,
        verbose=1,
        storage_path="D:/aniru-windows/Capstone-Implementation/Localrun_ray_checkpoints"  # Save checkpoints to this directory
    )

    # Load from a checkpoint and evaluate
    checkpoint_path = "D:/aniru-windows/Capstone-Implementation/Checkpoints_3agents_reduced_nodes_3000iter/PPO_RoadIntersectionEnv_d18b0_00000_0_2024-11-19_19-45-24/checkpoint_000029"  # Update with your checkpoint path
    ppo_trainer = PPO(config=config)
    ppo_trainer.restore(checkpoint_path)

    # Create environment for evaluation
    env = RoadIntersectionEnv(config["env_config"])
    obs = env.reset()
    done = {"__all__": False}
    while not done["__all__"]:
        action_dict = {}
        for agent_id, agent_obs in obs.items():
            action = ppo_trainer.compute_single_action(agent_obs, policy_id="default_policy")
            action_dict[agent_id] = action
        obs, rewards, dones, truncateds, infos = env.step(action_dict)
        done = dones

    # Clean up
    ray.shutdown()
'''
